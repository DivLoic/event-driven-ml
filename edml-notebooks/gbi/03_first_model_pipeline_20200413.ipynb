# %%
import tensorflow as tf
import numpy as np
from tensorflow_io.bigquery import BigQueryClient
import datetime
print(tf.__version__)
# Out:
# 1.15.2

# %%
import tensorflow_io

# %%
tensorflow_io.__version__
# Out:
# '0.8.1'

# %% [markdown]
# ## Read data

# %%
PROJECT_ID = "event-driven-ml"
DATASET_GCP_PROJECT_ID = "event-driven-ml"
DATASET_ID = "edml_nyc_yellow_taxi_us"
TABLE_ID = "gis_feat_eng"

# %%
INPUT_COLUMNS = ["uuid", "dayofweek", "hourofday", "weekofyear", "pickup_zone_name", "dropoff_zone_name", "passenger_count", "distance", "trip_duration"]
LABEL_COLUMN = "trip_duration"
KEY_COLUMN = "uuid"

# Set default values for each CSV column
DEFAULTS = [['no_key'], [1], [0], [54], [""], [""], [1], [0], []]

NEMBEDS = 10

# %%
VOCABULARY = [
    'Allerton/Pelham Gardens', 'Alphabet City', 'Arden Heights', 'Arrochar/Fort Wadsworth', 
    'Astoria', 'Astoria Park', 'Auburndale', 'Baisley Park', 'Bath Beach', 'Battery Park',
    'Battery Park City', 'Bay Ridge', 'Bay Terrace/Fort Totten', 'Bayside', 'Bedford', 
    'Bedford Park', 'Bellerose', 'Belmont', 'Bensonhurst East', 'Bensonhurst West',
    'Bloomfield/Emerson Hill', 'Bloomingdale', 'Boerum Hill', 'Borough Park', 
    'Breezy Point/Fort Tilden/Riis Beach', 'Briarwood/Jamaica Hills', 'Brighton Beach',
    'Broad Channel', 'Bronx Park', 'Bronxdale', 'Brooklyn Heights', 'Brooklyn Navy Yard', 
    'Brownsville', 'Bushwick North', 'Bushwick South', 'Cambria Heights', 'Canarsie', 'Carroll Gardens',
    'Central Harlem', 'Central Harlem North', 'Central Park', 'Charleston/Tottenville', 'Chinatown',
    'City Island', 'Claremont/Bathgate', 'Clinton East', 'Clinton Hill', 'Clinton West', 'Co-Op City',
    'Cobble Hill', 'College Point', 'Columbia Street', 'Coney Island', 'Corona', 'Country Club', 'Crotona Park',
    'Crotona Park East', 'Crown Heights North', 'Crown Heights South', 'Cypress Hills', 'DUMBO/Vinegar Hill',
    'Douglaston', 'Downtown Brooklyn/MetroTech', 'Dyker Heights', 'East Chelsea', 'East Concourse/Concourse Village',
    'East Elmhurst', 'East Flatbush/Farragut', 'East Flatbush/Remsen Village', 'East Flushing', 'East Harlem North',
    'East Harlem South', 'East New York', 'East New York/Pennsylvania Avenue', 'East Tremont', 'East Village',
    'East Williamsburg', 'Eastchester', 'Elmhurst', 'Elmhurst/Maspeth', "Eltingville/Annadale/Prince's Bay", 'Erasmus',
    'Far Rockaway', 'Financial District North', 'Financial District South', 'Flatbush/Ditmas Park', 'Flatiron',
    'Flatlands', 'Flushing', 'Flushing Meadows-Corona Park', 'Fordham South', 'Forest Hills',
    'Forest Park/Highland Park', 'Fort Greene', 'Fresh Meadows', 'Freshkills Park', 'Garment District', 'Glen Oaks',
    'Glendale', 'Gowanus', 'Gramercy', 'Gravesend', 'Great Kills', 'Great Kills Park', 'Green-Wood Cemetery',
    'Greenpoint', 'Greenwich Village North', 'Greenwich Village South', 'Grymes Hill/Clifton', 'Hamilton Heights',
    'Hammels/Arverne', 'Heartland Village/Todt Hill', 'Highbridge', 'Highbridge Park', 'Hillcrest/Pomonok', 'Hollis',
    'Homecrest', 'Howard Beach', 'Hudson Sq', 'Hunts Point', 'Inwood', 'Inwood Hill Park', 'JFK Airport',
    'Jackson Heights', 'Jamaica', 'Jamaica Bay', 'Jamaica Estates', 'Kensington', 'Kew Gardens', 'Kew Gardens Hills',
    'Kingsbridge Heights', 'Kips Bay', 'LaGuardia Airport', 'Laurelton', 'Lenox Hill East', 'Lenox Hill West',
    'Lincoln Square East', 'Lincoln Square West', 'Little Italy/NoLiTa', 'Long Island City/Hunters Point',
    'Long Island City/Queens Plaza', 'Longwood', 'Lower East Side', 'Madison', 'Manhattan Beach', 'Manhattan Valley',
    'Manhattanville', 'Marble Hill', 'Marine Park/Floyd Bennett Field', 'Marine Park/Mill Basin', 'Mariners Harbor',
    'Maspeth', 'Meatpacking/West Village West', 'Melrose South', 'Middle Village', 'Midtown Center', 'Midtown East',
    'Midtown North', 'Midtown South', 'Midwood', 'Morningside Heights', 'Morrisania/Melrose', 'Mott Haven/Port Morris',
    'Mount Hope', 'Murray Hill', 'Murray Hill-Queens', 'New Dorp/Midland Beach', 'Newark Airport', 'North Corona',
    'Norwood', 'Oakland Gardens', 'Oakwood', 'Ocean Hill', 'Ocean Parkway South', 'Old Astoria', 'Ozone Park',
    'Park Slope', 'Parkchester', 'Pelham Bay', 'Pelham Bay Park', 'Pelham Parkway', 'Penn Station/Madison Sq West',
    'Port Richmond', 'Prospect Heights', 'Prospect Park', 'Prospect-Lefferts Gardens', 'Queens Village',
    'Queensboro Hill', 'Queensbridge/Ravenswood', 'Randalls Island', 'Red Hook', 'Rego Park', 'Richmond Hill',
    'Ridgewood', 'Rikers Island', 'Riverdale/North Riverdale/Fieldston', 'Rockaway Park', 'Roosevelt Island', 'Rosedale',
    'Rossville/Woodrow', 'Saint Albans', 'Saint George/New Brighton', 'Saint Michaels Cemetery/Woodside',
    'Schuylerville/Edgewater Park', 'Seaport', 'Sheepshead Bay', 'SoHo', 'Soundview/Bruckner', 'Soundview/Castle Hill',
    'South Beach/Dongan Hills', 'South Jamaica', 'South Ozone Park', 'South Williamsburg', 'Springfield Gardens North',
    'Springfield Gardens South', 'Spuyten Duyvil/Kingsbridge', 'Stapleton', 'Starrett City', 'Steinway',
    'Stuy Town/Peter Cooper Village', 'Stuyvesant Heights', 'Sunnyside', 'Sunset Park East', 'Sunset Park West',
    'Sutton Place/Turtle Bay North', 'Times Sq/Theatre District', 'TriBeCa/Civic Center', 'Two Bridges/Seward Park',
    'UN/Turtle Bay South', 'Union Sq', 'University Heights/Morris Heights', 'Upper East Side North',
    'Upper East Side South', 'Upper West Side North', 'Upper West Side South', 'Van Cortlandt Park',
    'Van Cortlandt Village', 'Van Nest/Morris Park', 'Washington Heights North', 'Washington Heights South',
    'West Brighton', 'West Chelsea/Hudson Yards', 'West Concourse', 'West Farms/Bronx River', 'West Village',
    'Westchester Village/Unionport', 'Westerleigh', 'Whitestone', 'Willets Point', 'Williamsbridge/Olinville',
    'Williamsburg (North Side)', 'Williamsburg (South Side)', 'Windsor Terrace', 'Woodhaven', 'Woodlawn/Wakefield',
    'Woodside', 'World Trade Center', 'Yorkville East', 'Yorkville West'
]

_CATEGORICAL_STR_VOCAB = {
    "pickup_zone_name": VOCABULARY,
    "dropoff_zone_name": VOCABULARY
}

_CATEGORICAL_NUM_BUCKETS = {
    "dayofweek": 7,
    "hourofday": 24,
    "weekofyear": 53
}

# %%
# Create an input function reading a file using the Dataset API
# Then provide the results to the Estimator API
def read_dataset(suffix, mode, batch_size):
    def _input_fn():
        client = BigQueryClient()
        read_session = client.read_session(
            parent="projects/" + PROJECT_ID,
            project_id=DATASET_GCP_PROJECT_ID,
            table_id="{}_{}".format(TABLE_ID, suffix), 
            dataset_id=DATASET_ID,
            selected_fields=INPUT_COLUMNS,
            output_types=[tf.string, tf.int64, tf.int64, tf.int64, tf.string, tf.string, tf.int64, tf.float64, tf.int64],
            requested_streams=10
        )
        
        def decode_row(records):
            features = records
            label = tf.cast(features.pop(LABEL_COLUMN), tf.float32)
            return features, label
        
        dataset = read_session.parallel_read_rows(sloppy=True).map(decode_row)

        if mode == tf.estimator.ModeKeys.TRAIN:
            num_epochs = None  # indefinitely
            dataset = dataset.shuffle(buffer_size=1000*batch_size, seed=1234)
        else:
            num_epochs = 1  # end-of-input after this

        dataset = dataset.repeat(num_epochs).batch(batch_size)
        return dataset
    return _input_fn

# %% [markdown]
# ## Feature engineering

# %%
def get_wide_deep():
    
    # One hot encode categorical features
    fc_dayofweek = tf.compat.v1.feature_column.categorical_column_with_identity(key="dayofweek",
                                                                                num_buckets=_CATEGORICAL_NUM_BUCKETS["dayofweek"])
    
    fc_hourofday = tf.compat.v1.feature_column.categorical_column_with_identity(key="hourofday",
                                                                                num_buckets=_CATEGORICAL_NUM_BUCKETS["hourofday"])
    
    fc_weekofyear = tf.compat.v1.feature_column.categorical_column_with_identity(key="weekofyear",
                                                                                 num_buckets=_CATEGORICAL_NUM_BUCKETS["weekofyear"])
    
    fc_pickuploc = tf.compat.v1.feature_column.categorical_column_with_vocabulary_list(key="pickup_zone_name",
                                                                                vocabulary_list=_CATEGORICAL_STR_VOCAB["pickup_zone_name"])
    
    fc_dropoffloc = tf.compat.v1.feature_column.categorical_column_with_vocabulary_list(key="dropoff_zone_name",
                                                                            vocabulary_list=_CATEGORICAL_STR_VOCAB["pickup_zone_name"])
    
    wide = [        
        # Sparse columns
        fc_dayofweek, fc_hourofday, fc_weekofyear,
        fc_pickuploc, fc_dropoffloc
    ]
    
    # mettre dans util
    def normalize_distance(col):
        mean = 3387.0
        std = 3891.02
        return (col - mean)/std
    
#     def normalize_passanger_cnt(col):
#         mean = 1.62
#         std = 1.26
#         return (col - mean)/std
    
    # Numerical column passanger_count
    fn_passenger_count = tf.compat.v1.feature_column.numeric_column(key="passenger_count")#, normalizer_fn=normalize_passanger_cnt)
    fn_distance = tf.compat.v1.feature_column.numeric_column(key="distance", normalizer_fn=normalize_distance)
    
    # Embedding_column to "group" together ...
    fc_embed_dayofweek = tf.compat.v1.feature_column.embedding_column(categorical_column=fc_dayofweek, dimension=NEMBEDS)#, max_norm=1)
    fc_embed_hourofday = tf.compat.v1.feature_column.embedding_column(categorical_column=fc_hourofday, dimension=NEMBEDS)#, max_norm=1)
    fc_embed_weekofyear = tf.compat.v1.feature_column.embedding_column(categorical_column=fc_weekofyear, dimension=NEMBEDS)#, max_norm=1)
    fc_embed_pickuploc = tf.compat.v1.feature_column.embedding_column(categorical_column=fc_pickuploc, dimension=NEMBEDS)#, max_norm=1)
    fc_embed_dropoffloc = tf.compat.v1.feature_column.embedding_column(categorical_column=fc_dropoffloc, dimension=NEMBEDS)#, max_norm=1)
    
    deep = [
        fn_passenger_count,
        fn_distance,
        fc_embed_dayofweek,
        fc_embed_hourofday,
        fc_embed_weekofyear,
        fc_embed_pickuploc,
        fc_embed_dropoffloc,
    ]
    
    return wide, deep

# %% [markdown]
# ### Serving input receiver function

# %%
def serving_input_receiver_fn():
    receiver_tensors = {
        'dayofweek': tf.compat.v1.placeholder(dtype=tf.int64, shape=[None], name="dayofweek"),
        'hourofday': tf.compat.v1.placeholder(dtype=tf.int64, shape=[None], name="hourofday"),
        'weekofyear': tf.compat.v1.placeholder(dtype=tf.int64, shape=[None], name="weekofyear"),
        'pickup_zone_name': tf.compat.v1.placeholder(dtype=tf.string, shape=[None], name="pickup_zone_name"),
        'dropoff_zone_name': tf.compat.v1.placeholder(dtype=tf.string, shape=[None], name="dropoff_zone_name"),
        'passenger_count': tf.compat.v1.placeholder(dtype=tf.int64, shape=[None], name="passenger_count"),
        'distance': tf.compat.v1.placeholder(dtype=tf.float64, shape=[None], name="distance"),
        KEY_COLUMN: tf.compat.v1.placeholder_with_default(tf.constant(['no_key']), [None], name="uuid")
    }
    
    features = {
        key: tf.expand_dims(tensor, -1)
        for key, tensor in receiver_tensors.items()
    }
        
    return tf.estimator.export.ServingInputReceiver(features=features, receiver_tensors=receiver_tensors)

# %% [markdown]
# ## Build and train model

# %%
def my_estimator(output_dir, throttle_secs, nnsize, batch_size, train_steps, eval_steps, eval_delay_secs):
    
    run_config = tf.estimator.RunConfig(save_checkpoints_secs=throttle_secs,
                                        tf_random_seed=2810,
                                        keep_checkpoint_max=3)
    
    # Add custom evaluation metric
    def my_rmse(labels, predictions):
        pred_values = tf.squeeze(input=predictions["predictions"], axis=-1)
        return {"rmse": tf.compat.v1.metrics.root_mean_squared_error(labels=labels, predictions=pred_values)}
    
    # Feature engineering
    wide, deep = get_wide_deep()
    
    estimator = tf.estimator.DNNLinearCombinedRegressor(
        model_dir=output_dir,
        linear_feature_columns=wide,
        dnn_feature_columns=deep,
        dnn_hidden_units=nnsize,
        batch_norm=True,
        dnn_dropout=0.1,
        config=run_config)
    
    estimator = tf.contrib.estimator.add_metrics(estimator=estimator, metric_fn=my_rmse)
    
    train_spec = tf.estimator.TrainSpec(
        input_fn=read_dataset('train', tf.estimator.ModeKeys.TRAIN, batch_size),
        max_steps=train_steps)
    
    exporter = tf.estimator.LatestExporter('exporter', serving_input_receiver_fn=serving_input_receiver_fn)
    
    eval_spec = tf.estimator.EvalSpec(
        input_fn=read_dataset('test', tf.estimator.ModeKeys.EVAL, 2**15),
        steps=eval_steps,
        start_delay_secs=eval_delay_secs,  # start evaluating after N seconds
        throttle_secs=throttle_secs,  # evaluate every N seconds
        exporters=exporter)
    
    return estimator, train_spec, eval_spec

# %% [markdown]
# ### Train model

# %%
# Parameters
BUCKET = "edml"
OUTDIR = "gs://{}/ai-platform/models/edml_trainer_{}".format(BUCKET, datetime.datetime.now().strftime("%Y%m%d_%H%M%S"))
THROTTLE_SECS = 300
NNSIZE = [128, 32, 4]
BATCH_SIZE = 128
TRAIN_STEPS = 100000 #5M per fare 3 apochs con batch_size 128 (input size 217M)
EVAL_STEPS = 3
EVAL_DECAY_SECS = 10

# %%
# %%bash
# # gsutil rm gs://bucket/subdir/** will remove all objects under gs://bucket/subdir or any of its subdirectories.
# gsutil rm gs://edml/data/taxi-trips/model_test/** # start fresh each time

# %%
tf.compat.v1.summary.FileWriterCache.clear() # ensure filewriter cache is clear for TensorBoard events file
tf.compat.v1.logging.set_verbosity(v = tf.logging.INFO) # so loss is printed during training

# %%
estimator, train_spec, eval_spec = my_estimator(output_dir=OUTDIR, throttle_secs=THROTTLE_SECS, nnsize=NNSIZE, batch_size=BATCH_SIZE, train_steps=TRAIN_STEPS,
                                                eval_steps=EVAL_STEPS, eval_delay_secs=EVAL_DECAY_SECS)
# Out:
# INFO:tensorflow:Using config: {'_model_dir': 'gs://edml/ai-platform/models/edml_trainer_20200421_110923', '_tf_random_seed': 2810, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 300, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 3, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7fa1dc122150>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Using config: {'_model_dir': 'gs://edml/ai-platform/models/edml_trainer_20200421_110923', '_tf_random_seed': 2810, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 300, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 3, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7fa1dc122710>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %%
tf.estimator.train_and_evaluate(estimator, train_spec, eval_spec)
# Out:
# INFO:tensorflow:Not using Distribute Coordinator.
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps None or save_checkpoints_secs 300.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into gs://edml/ai-platform/models/edml_trainer_20200421_110923/model.ckpt.
# INFO:tensorflow:loss = 4233677.5, step = 0
# INFO:tensorflow:global_step/sec: 28.2264
# INFO:tensorflow:loss = 48058.49, step = 100 (3.544 sec)
# INFO:tensorflow:global_step/sec: 35.7912
# INFO:tensorflow:loss = 39977.812, step = 200 (2.794 sec)
# INFO:tensorflow:global_step/sec: 36.0534
# INFO:tensorflow:loss = 39349.91, step = 300 (2.774 sec)
# INFO:tensorflow:global_step/sec: 36.0856
# INFO:tensorflow:loss = 40537.555, step = 400 (2.771 sec)
# INFO:tensorflow:global_step/sec: 35.8781
# INFO:tensorflow:loss = 45758.914, step = 500 (2.787 sec)
# INFO:tensorflow:global_step/sec: 35.8993
# INFO:tensorflow:loss = 26745.385, step = 600 (2.786 sec)
# INFO:tensorflow:global_step/sec: 35.7201
# INFO:tensorflow:loss = 29092.605, step = 700 (2.800 sec)
# INFO:tensorflow:global_step/sec: 35.7592
# INFO:tensorflow:loss = 2034501.1, step = 800 (2.798 sec)
# INFO:tensorflow:global_step/sec: 35.7814
# INFO:tensorflow:loss = 33903.387, step = 900 (2.793 sec)
# INFO:tensorflow:global_step/sec: 35.956
# INFO:tensorflow:loss = 45596.562, step = 1000 (2.781 sec)
# INFO:tensorflow:global_step/sec: 35.7246
# INFO:tensorflow:loss = 33650.773, step = 1100 (2.799 sec)
# INFO:tensorflow:global_step/sec: 35.9582
# INFO:tensorflow:loss = 1953170.5, step = 1200 (2.781 sec)
# INFO:tensorflow:global_step/sec: 35.3035
# INFO:tensorflow:loss = 29424.664, step = 1300 (2.833 sec)
# INFO:tensorflow:global_step/sec: 35.1086
# INFO:tensorflow:loss = 37321.312, step = 1400 (2.851 sec)
# INFO:tensorflow:global_step/sec: 35.3745
# INFO:tensorflow:loss = 36382.086, step = 1500 (2.824 sec)
# INFO:tensorflow:global_step/sec: 35.4154
# INFO:tensorflow:loss = 41923.387, step = 1600 (2.824 sec)
# INFO:tensorflow:global_step/sec: 35.1441
# INFO:tensorflow:loss = 26561.89, step = 1700 (2.845 sec)
# INFO:tensorflow:global_step/sec: 35.6545
# INFO:tensorflow:loss = 43171.016, step = 1800 (2.805 sec)
# INFO:tensorflow:global_step/sec: 35.0881
# INFO:tensorflow:loss = 36636.156, step = 1900 (2.851 sec)
# INFO:tensorflow:global_step/sec: 35.248
# INFO:tensorflow:loss = 25822.305, step = 2000 (2.836 sec)
# INFO:tensorflow:global_step/sec: 35.1612
# INFO:tensorflow:loss = 28593.729, step = 2100 (2.844 sec)
# INFO:tensorflow:global_step/sec: 35.3469
# INFO:tensorflow:loss = 729379.25, step = 2200 (2.829 sec)
# INFO:tensorflow:global_step/sec: 35.9818
# INFO:tensorflow:loss = 6141772.0, step = 2300 (2.779 sec)
# INFO:tensorflow:global_step/sec: 35.3066
# INFO:tensorflow:loss = 2071475.6, step = 2400 (2.832 sec)
# INFO:tensorflow:global_step/sec: 35.513
# INFO:tensorflow:loss = 32878.055, step = 2500 (2.816 sec)
# INFO:tensorflow:global_step/sec: 35.4036
# INFO:tensorflow:loss = 3945744.8, step = 2600 (2.825 sec)
# INFO:tensorflow:global_step/sec: 35.1818
# INFO:tensorflow:loss = 27905.633, step = 2700 (2.842 sec)
# INFO:tensorflow:global_step/sec: 34.2502
# INFO:tensorflow:loss = 31352.875, step = 2800 (2.920 sec)
# INFO:tensorflow:global_step/sec: 35.442
# INFO:tensorflow:loss = 36579.57, step = 2900 (2.822 sec)
# INFO:tensorflow:global_step/sec: 34.8159
# INFO:tensorflow:loss = 38336.89, step = 3000 (4.099 sec)
# INFO:tensorflow:global_step/sec: 24.227
# INFO:tensorflow:loss = 32352.69, step = 3100 (2.901 sec)
# INFO:tensorflow:global_step/sec: 35.2299
# INFO:tensorflow:loss = 33263.9, step = 3200 (2.839 sec)
# INFO:tensorflow:global_step/sec: 35.4263
# INFO:tensorflow:loss = 30263.402, step = 3300 (2.823 sec)
# INFO:tensorflow:global_step/sec: 34.4122
# INFO:tensorflow:loss = 2066304.1, step = 3400 (2.906 sec)
# INFO:tensorflow:global_step/sec: 34.6568
# INFO:tensorflow:loss = 2086737.1, step = 3500 (2.885 sec)
# INFO:tensorflow:global_step/sec: 35.5363
# INFO:tensorflow:loss = 34072.113, step = 3600 (2.814 sec)
# INFO:tensorflow:global_step/sec: 34.8516
# INFO:tensorflow:loss = 34638.11, step = 3700 (2.869 sec)
# INFO:tensorflow:global_step/sec: 34.9864
# INFO:tensorflow:loss = 50644.6, step = 3800 (2.859 sec)
# INFO:tensorflow:global_step/sec: 35.2155
# INFO:tensorflow:loss = 34488.215, step = 3900 (2.839 sec)
# INFO:tensorflow:global_step/sec: 35.3909
# INFO:tensorflow:loss = 1794804.4, step = 4000 (2.826 sec)
# INFO:tensorflow:global_step/sec: 35.6909
# INFO:tensorflow:loss = 34046.9, step = 4100 (2.802 sec)
# INFO:tensorflow:global_step/sec: 35.8061
# INFO:tensorflow:loss = 2100877.2, step = 4200 (2.793 sec)
# INFO:tensorflow:global_step/sec: 35.3902
# INFO:tensorflow:loss = 31078.746, step = 4300 (2.826 sec)
# INFO:tensorflow:global_step/sec: 35.5493
# INFO:tensorflow:loss = 25962.602, step = 4400 (2.813 sec)
# INFO:tensorflow:global_step/sec: 35.2886
# INFO:tensorflow:loss = 31505.727, step = 4500 (2.834 sec)
# INFO:tensorflow:global_step/sec: 35.5985
# INFO:tensorflow:loss = 23490.602, step = 4600 (2.809 sec)
# INFO:tensorflow:global_step/sec: 35.9236
# INFO:tensorflow:loss = 30213.914, step = 4700 (2.783 sec)
# INFO:tensorflow:global_step/sec: 35.2883
# INFO:tensorflow:loss = 405640.53, step = 4800 (2.834 sec)
# INFO:tensorflow:global_step/sec: 35.2626
# INFO:tensorflow:loss = 36966.08, step = 4900 (2.836 sec)
# INFO:tensorflow:global_step/sec: 34.8356
# INFO:tensorflow:loss = 35459.375, step = 5000 (2.871 sec)
# INFO:tensorflow:global_step/sec: 35.7506
# INFO:tensorflow:loss = 33993.375, step = 5100 (2.797 sec)
# INFO:tensorflow:global_step/sec: 35.4927
# INFO:tensorflow:loss = 37884.895, step = 5200 (2.818 sec)
# INFO:tensorflow:global_step/sec: 35.4286
# INFO:tensorflow:loss = 24143.379, step = 5300 (2.823 sec)
# INFO:tensorflow:global_step/sec: 35.5899
# INFO:tensorflow:loss = 22580.61, step = 5400 (2.810 sec)
# INFO:tensorflow:global_step/sec: 35.0544
# INFO:tensorflow:loss = 18936.678, step = 5500 (2.852 sec)
# INFO:tensorflow:global_step/sec: 35.4947
# INFO:tensorflow:loss = 42944.02, step = 5600 (2.818 sec)
# INFO:tensorflow:global_step/sec: 35.4783
# INFO:tensorflow:loss = 31820.826, step = 5700 (2.818 sec)
# INFO:tensorflow:global_step/sec: 34.8868
# INFO:tensorflow:loss = 30140.346, step = 5800 (2.867 sec)
# INFO:tensorflow:global_step/sec: 35.213
# INFO:tensorflow:loss = 33019.082, step = 5900 (2.840 sec)
# INFO:tensorflow:global_step/sec: 35.7624
# INFO:tensorflow:loss = 2074333.2, step = 6000 (2.796 sec)
# INFO:tensorflow:global_step/sec: 35.6653
# INFO:tensorflow:loss = 30413.502, step = 6100 (2.804 sec)
# INFO:tensorflow:global_step/sec: 35.3372
# INFO:tensorflow:loss = 16074.076, step = 6200 (2.830 sec)
# INFO:tensorflow:global_step/sec: 35.3269
# INFO:tensorflow:loss = 39272.45, step = 6300 (2.831 sec)
# INFO:tensorflow:global_step/sec: 35.4907
# INFO:tensorflow:loss = 29069.53, step = 6400 (2.818 sec)
# INFO:tensorflow:global_step/sec: 35.4365
# INFO:tensorflow:loss = 32144.186, step = 6500 (2.822 sec)
# INFO:tensorflow:global_step/sec: 35.5618
# INFO:tensorflow:loss = 23583.148, step = 6600 (2.812 sec)
# INFO:tensorflow:global_step/sec: 35.6464
# INFO:tensorflow:loss = 2086788.8, step = 6700 (2.805 sec)
# INFO:tensorflow:global_step/sec: 35.525
# INFO:tensorflow:loss = 40376.547, step = 6800 (2.815 sec)
# INFO:tensorflow:global_step/sec: 35.9646
# INFO:tensorflow:loss = 26159.68, step = 6900 (2.781 sec)
# INFO:tensorflow:global_step/sec: 35.2953
# INFO:tensorflow:loss = 33859.168, step = 7000 (2.832 sec)
# INFO:tensorflow:global_step/sec: 36.1417
# INFO:tensorflow:loss = 3933657.5, step = 7100 (2.767 sec)
# INFO:tensorflow:global_step/sec: 35.6271
# INFO:tensorflow:loss = 25433.379, step = 7200 (2.807 sec)
# INFO:tensorflow:global_step/sec: 35.7757
# INFO:tensorflow:loss = 24100.9, step = 7300 (3.880 sec)
# INFO:tensorflow:global_step/sec: 25.4282
# INFO:tensorflow:loss = 32061.057, step = 7400 (2.848 sec)
# INFO:tensorflow:global_step/sec: 29.2536
# INFO:tensorflow:loss = 22532.953, step = 7500 (3.419 sec)
# INFO:tensorflow:global_step/sec: 29.1644
# INFO:tensorflow:loss = 29726.432, step = 7600 (3.429 sec)
# INFO:tensorflow:global_step/sec: 29.3556
# INFO:tensorflow:loss = 820543.0, step = 7700 (3.406 sec)
# INFO:tensorflow:global_step/sec: 34.7253
# INFO:tensorflow:loss = 2084834.2, step = 7800 (2.880 sec)
# INFO:tensorflow:global_step/sec: 35.7754
# INFO:tensorflow:loss = 18158.82, step = 7900 (2.795 sec)
# INFO:tensorflow:global_step/sec: 35.6042
# INFO:tensorflow:loss = 32215.805, step = 8000 (2.809 sec)
# INFO:tensorflow:global_step/sec: 35.0988
# INFO:tensorflow:loss = 1949847.0, step = 8100 (2.849 sec)
# INFO:tensorflow:global_step/sec: 35.2283
# INFO:tensorflow:loss = 35020.516, step = 8200 (2.839 sec)
# INFO:tensorflow:global_step/sec: 36.0188
# INFO:tensorflow:loss = 4076270.5, step = 8300 (2.777 sec)
# INFO:tensorflow:global_step/sec: 35.2414
# INFO:tensorflow:loss = 21348.695, step = 8400 (2.837 sec)
# INFO:tensorflow:global_step/sec: 35.6403
# INFO:tensorflow:loss = 19268.602, step = 8500 (2.806 sec)
# INFO:tensorflow:global_step/sec: 35.024
# INFO:tensorflow:loss = 1943926.9, step = 8600 (2.855 sec)
# INFO:tensorflow:global_step/sec: 35.3545
# INFO:tensorflow:loss = 30619.78, step = 8700 (2.828 sec)
# INFO:tensorflow:global_step/sec: 35.6534
# INFO:tensorflow:loss = 28619.867, step = 8800 (2.806 sec)
# INFO:tensorflow:global_step/sec: 35.4792
# INFO:tensorflow:loss = 23245.17, step = 8900 (2.820 sec)
# INFO:tensorflow:global_step/sec: 35.4597
# INFO:tensorflow:loss = 25759.197, step = 9000 (2.820 sec)
# INFO:tensorflow:global_step/sec: 35.4037
# INFO:tensorflow:loss = 1965059.4, step = 9100 (2.823 sec)
# INFO:tensorflow:global_step/sec: 34.9523
# INFO:tensorflow:loss = 20590.104, step = 9200 (2.861 sec)
# INFO:tensorflow:global_step/sec: 35.4723
# INFO:tensorflow:loss = 1946280.2, step = 9300 (2.819 sec)
# INFO:tensorflow:global_step/sec: 35.4256
# INFO:tensorflow:loss = 29940.383, step = 9400 (2.823 sec)
# INFO:tensorflow:global_step/sec: 35.5619
# INFO:tensorflow:loss = 18892.018, step = 9500 (2.812 sec)
# INFO:tensorflow:global_step/sec: 35.5355
# INFO:tensorflow:loss = 2083103.4, step = 9600 (2.814 sec)
# INFO:tensorflow:global_step/sec: 35.1745
# INFO:tensorflow:loss = 2002868.6, step = 9700 (2.843 sec)
# INFO:tensorflow:global_step/sec: 34.6573
# INFO:tensorflow:loss = 31639.357, step = 9800 (2.885 sec)
# INFO:tensorflow:global_step/sec: 35.4389
# INFO:tensorflow:loss = 2072321.1, step = 9900 (2.822 sec)
# INFO:tensorflow:Saving checkpoints for 9972 into gs://edml/ai-platform/models/edml_trainer_20200421_110923/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-04-21T11:15:19Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from gs://edml/ai-platform/models/edml_trainer_20200421_110923/model.ckpt-9972
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/3]
# INFO:tensorflow:Evaluation [2/3]
# INFO:tensorflow:Evaluation [3/3]
# INFO:tensorflow:Finished evaluation at 2020-04-21-11:15:37
# INFO:tensorflow:Saving dict for global step 9972: average_loss = 4660.733, global_step = 9972, label/mean = 18.20279, loss = 152722900.0, prediction/mean = 3.3045132, rmse = 68.26956
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 9972: gs://edml/ai-platform/models/edml_trainer_20200421_110923/model.ckpt-9972
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['predict']
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Signatures EXCLUDED from export because they cannot be be served via TensorFlow Serving APIs:
# INFO:tensorflow:'serving_default' : Regression input must be a single string Tensor; got {'dayofweek': <tf.Tensor 'dayofweek:0' shape=(?,) dtype=int64>, 'hourofday': <tf.Tensor 'hourofday:0' shape=(?,) dtype=int64>, 'weekofyear': <tf.Tensor 'weekofyear:0' shape=(?,) dtype=int64>, 'pickup_zone_name': <tf.Tensor 'pickup_zone_name:0' shape=(?,) dtype=string>, 'dropoff_zone_name': <tf.Tensor 'dropoff_zone_name:0' shape=(?,) dtype=string>, 'passenger_count': <tf.Tensor 'passenger_count:0' shape=(?,) dtype=int64>, 'distance': <tf.Tensor 'distance:0' shape=(?,) dtype=float64>, 'uuid': <tf.Tensor 'uuid:0' shape=(?,) dtype=string>}
# INFO:tensorflow:'regression' : Regression input must be a single string Tensor; got {'dayofweek': <tf.Tensor 'dayofweek:0' shape=(?,) dtype=int64>, 'hourofday': <tf.Tensor 'hourofday:0' shape=(?,) dtype=int64>, 'weekofyear': <tf.Tensor 'weekofyear:0' shape=(?,) dtype=int64>, 'pickup_zone_name': <tf.Tensor 'pickup_zone_name:0' shape=(?,) dtype=string>, 'dropoff_zone_name': <tf.Tensor 'dropoff_zone_name:0' shape=(?,) dtype=string>, 'passenger_count': <tf.Tensor 'passenger_count:0' shape=(?,) dtype=int64>, 'distance': <tf.Tensor 'distance:0' shape=(?,) dtype=float64>, 'uuid': <tf.Tensor 'uuid:0' shape=(?,) dtype=string>}
# WARNING:tensorflow:Export includes no default signature!
# INFO:tensorflow:Restoring parameters from gs://edml/ai-platform/models/edml_trainer_20200421_110923/model.ckpt-9972
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: gs://edml/ai-platform/models/edml_trainer_20200421_110923/export/exporter/temp-b'1587467743'/saved_model.pb
# INFO:tensorflow:global_step/sec: 1.37208
# INFO:tensorflow:loss = 23177.29, step = 10000 (74.450 sec)
# INFO:tensorflow:global_step/sec: 22.7518
# INFO:tensorflow:loss = 25139.066, step = 10100 (2.827 sec)
# INFO:tensorflow:global_step/sec: 35.1871
# INFO:tensorflow:loss = 1963491.6, step = 10200 (2.842 sec)
# INFO:tensorflow:global_step/sec: 35.4732
# INFO:tensorflow:loss = 3991047.8, step = 10300 (2.819 sec)
# INFO:tensorflow:global_step/sec: 35.4366
# INFO:tensorflow:loss = 965501.0, step = 10400 (2.822 sec)
# INFO:tensorflow:global_step/sec: 35.7528
# INFO:tensorflow:loss = 26766.85, step = 10500 (2.797 sec)
# INFO:tensorflow:global_step/sec: 35.1388
# INFO:tensorflow:loss = 2053070.6, step = 10600 (2.846 sec)
# INFO:tensorflow:global_step/sec: 35.817
# INFO:tensorflow:loss = 2077519.2, step = 10700 (2.792 sec)
# INFO:tensorflow:global_step/sec: 35.3214
# INFO:tensorflow:loss = 23995.31, step = 10800 (2.832 sec)
# INFO:tensorflow:global_step/sec: 35.4837
# INFO:tensorflow:loss = 33935.297, step = 10900 (2.818 sec)
# INFO:tensorflow:global_step/sec: 35.1186
# INFO:tensorflow:loss = 2055904.6, step = 11000 (2.847 sec)
# INFO:tensorflow:global_step/sec: 35.2619
# INFO:tensorflow:loss = 22058.56, step = 11100 (2.836 sec)
# INFO:tensorflow:global_step/sec: 35.4089
# INFO:tensorflow:loss = 28084.262, step = 11200 (2.824 sec)
# INFO:tensorflow:global_step/sec: 35.1733
# INFO:tensorflow:loss = 31673.771, step = 11300 (2.843 sec)
# INFO:tensorflow:global_step/sec: 34.5306
# INFO:tensorflow:loss = 1988411.0, step = 11400 (2.896 sec)
# INFO:tensorflow:global_step/sec: 35.8399
# INFO:tensorflow:loss = 20296.848, step = 11500 (2.790 sec)
# INFO:tensorflow:global_step/sec: 35.1767
# INFO:tensorflow:loss = 23299.174, step = 11600 (2.843 sec)
# INFO:tensorflow:global_step/sec: 35.687
# INFO:tensorflow:loss = 26420.398, step = 11700 (2.802 sec)
# INFO:tensorflow:global_step/sec: 35.1125
# INFO:tensorflow:loss = 2084214.4, step = 11800 (2.848 sec)
# INFO:tensorflow:global_step/sec: 34.8541
# INFO:tensorflow:loss = 31812.203, step = 11900 (2.869 sec)
# INFO:tensorflow:global_step/sec: 35.5287
# INFO:tensorflow:loss = 23874.264, step = 12000 (2.814 sec)
# INFO:tensorflow:global_step/sec: 35.5661
# INFO:tensorflow:loss = 1960468.1, step = 12100 (2.812 sec)
# INFO:tensorflow:global_step/sec: 35.6917
# INFO:tensorflow:loss = 31815.92, step = 12200 (2.802 sec)
# INFO:tensorflow:global_step/sec: 35.5547
# INFO:tensorflow:loss = 41984.73, step = 12300 (2.812 sec)
# INFO:tensorflow:global_step/sec: 35.5194
# INFO:tensorflow:loss = 25151.834, step = 12400 (2.815 sec)
# INFO:tensorflow:global_step/sec: 35.9131
# INFO:tensorflow:loss = 28141.098, step = 12500 (2.785 sec)
# INFO:tensorflow:global_step/sec: 34.6231
# INFO:tensorflow:loss = 34964.36, step = 12600 (2.888 sec)
# INFO:tensorflow:global_step/sec: 35.6414
# INFO:tensorflow:loss = 22382.6, step = 12700 (2.806 sec)
# INFO:tensorflow:global_step/sec: 35.6928
# INFO:tensorflow:loss = 24245.74, step = 12800 (2.802 sec)
# INFO:tensorflow:global_step/sec: 35.3737
# INFO:tensorflow:loss = 37941.78, step = 12900 (2.827 sec)
# INFO:tensorflow:global_step/sec: 35.4175
# INFO:tensorflow:loss = 19011.66, step = 13000 (2.823 sec)
# INFO:tensorflow:global_step/sec: 35.8846
# INFO:tensorflow:loss = 27184.055, step = 13100 (2.787 sec)
# INFO:tensorflow:global_step/sec: 35.4688
# INFO:tensorflow:loss = 18871.084, step = 13200 (2.819 sec)
# INFO:tensorflow:global_step/sec: 36.137
# INFO:tensorflow:loss = 31158.414, step = 13300 (2.767 sec)
# INFO:tensorflow:global_step/sec: 35.3432
# INFO:tensorflow:loss = 34430.844, step = 13400 (2.829 sec)
# INFO:tensorflow:global_step/sec: 35.2559
# INFO:tensorflow:loss = 25857.227, step = 13500 (2.837 sec)
# INFO:tensorflow:global_step/sec: 35.3816
# INFO:tensorflow:loss = 2406407.2, step = 13600 (2.826 sec)
# INFO:tensorflow:global_step/sec: 35.8591
# INFO:tensorflow:loss = 23470.871, step = 13700 (2.788 sec)
# INFO:tensorflow:global_step/sec: 35.4661
# INFO:tensorflow:loss = 27672.965, step = 13800 (2.820 sec)
# INFO:tensorflow:global_step/sec: 35.3498
# INFO:tensorflow:loss = 19664.139, step = 13900 (2.829 sec)
# INFO:tensorflow:global_step/sec: 35.1429
# INFO:tensorflow:loss = 149919.5, step = 14000 (2.846 sec)
# INFO:tensorflow:global_step/sec: 35.3909
# INFO:tensorflow:loss = 1988879.5, step = 14100 (2.826 sec)
# INFO:tensorflow:global_step/sec: 35.4413
# INFO:tensorflow:loss = 27315.514, step = 14200 (4.576 sec)
# INFO:tensorflow:global_step/sec: 22.0957
# INFO:tensorflow:loss = 25887.416, step = 14300 (2.774 sec)
# INFO:tensorflow:global_step/sec: 35.693
# INFO:tensorflow:loss = 2092243.8, step = 14400 (2.799 sec)
# INFO:tensorflow:global_step/sec: 35.6901
# INFO:tensorflow:loss = 25370.816, step = 14500 (2.802 sec)
# INFO:tensorflow:global_step/sec: 35.2161
# INFO:tensorflow:loss = 27854.01, step = 14600 (2.840 sec)
# INFO:tensorflow:global_step/sec: 35.1548
# INFO:tensorflow:loss = 1602930.6, step = 14700 (2.845 sec)
# INFO:tensorflow:global_step/sec: 35.4324
# INFO:tensorflow:loss = 21575.297, step = 14800 (2.823 sec)
# INFO:tensorflow:global_step/sec: 35.4796
# INFO:tensorflow:loss = 2033247.6, step = 14900 (2.818 sec)
# INFO:tensorflow:global_step/sec: 35.2682
# INFO:tensorflow:loss = 32789.6, step = 15000 (2.835 sec)
# INFO:tensorflow:global_step/sec: 36.164
# INFO:tensorflow:loss = 22051.055, step = 15100 (2.768 sec)
# INFO:tensorflow:global_step/sec: 35.1814
# INFO:tensorflow:loss = 36914.93, step = 15200 (2.840 sec)
# INFO:tensorflow:global_step/sec: 34.885
# INFO:tensorflow:loss = 22778.428, step = 15300 (2.867 sec)
# INFO:tensorflow:global_step/sec: 35.6483
# INFO:tensorflow:loss = 29557.914, step = 15400 (2.805 sec)
# INFO:tensorflow:global_step/sec: 35.4806
# INFO:tensorflow:loss = 2047407.4, step = 15500 (2.818 sec)
# INFO:tensorflow:global_step/sec: 35.2132
# INFO:tensorflow:loss = 24300.547, step = 15600 (2.842 sec)
# INFO:tensorflow:global_step/sec: 35.7122
# INFO:tensorflow:loss = 17808.67, step = 15700 (2.798 sec)
# INFO:tensorflow:global_step/sec: 30.9098
# INFO:tensorflow:loss = 1878723.9, step = 15800 (3.236 sec)
# INFO:tensorflow:global_step/sec: 29.0951
# INFO:tensorflow:loss = 31964.97, step = 15900 (3.437 sec)
# INFO:tensorflow:global_step/sec: 28.7253
# INFO:tensorflow:loss = 32434.936, step = 16000 (3.481 sec)
# INFO:tensorflow:global_step/sec: 32.5199
# INFO:tensorflow:loss = 27451.414, step = 16100 (3.074 sec)
# INFO:tensorflow:global_step/sec: 35.1942
# INFO:tensorflow:loss = 17879.734, step = 16200 (2.841 sec)
# INFO:tensorflow:global_step/sec: 35.706
# INFO:tensorflow:loss = 18418.818, step = 16300 (2.801 sec)
# INFO:tensorflow:global_step/sec: 35.5641
# INFO:tensorflow:loss = 25542.414, step = 16400 (2.812 sec)
# INFO:tensorflow:global_step/sec: 35.9349
# INFO:tensorflow:loss = 26149.277, step = 16500 (2.783 sec)
# INFO:tensorflow:global_step/sec: 35.3669
# INFO:tensorflow:loss = 18917.81, step = 16600 (2.828 sec)
# INFO:tensorflow:global_step/sec: 36.1194
# INFO:tensorflow:loss = 20398.3, step = 16700 (2.769 sec)
# INFO:tensorflow:global_step/sec: 35.5369
# INFO:tensorflow:loss = 30639.76, step = 16800 (2.814 sec)
# INFO:tensorflow:global_step/sec: 35.3236
# INFO:tensorflow:loss = 25096.004, step = 16900 (2.831 sec)
# INFO:tensorflow:global_step/sec: 35.5433
# INFO:tensorflow:loss = 34268.996, step = 17000 (2.813 sec)
# INFO:tensorflow:global_step/sec: 35.656
# INFO:tensorflow:loss = 28498.55, step = 17100 (2.804 sec)
# INFO:tensorflow:global_step/sec: 35.5025
# INFO:tensorflow:loss = 2092996.9, step = 17200 (2.817 sec)
# INFO:tensorflow:global_step/sec: 35.6285
# INFO:tensorflow:loss = 24166.527, step = 17300 (2.807 sec)
# INFO:tensorflow:global_step/sec: 35.7122
# INFO:tensorflow:loss = 21817.865, step = 17400 (2.800 sec)
# INFO:tensorflow:global_step/sec: 35.703
# INFO:tensorflow:loss = 28070.332, step = 17500 (2.801 sec)
# INFO:tensorflow:global_step/sec: 35.4311
# INFO:tensorflow:loss = 33446.84, step = 17600 (2.822 sec)
# INFO:tensorflow:global_step/sec: 35.6035
# INFO:tensorflow:loss = 18023.018, step = 17700 (2.809 sec)
# INFO:tensorflow:global_step/sec: 35.6002
# INFO:tensorflow:loss = 23373.059, step = 17800 (2.809 sec)
# INFO:tensorflow:global_step/sec: 35.5463
# INFO:tensorflow:loss = 23289.008, step = 17900 (2.813 sec)
# INFO:tensorflow:Saving checkpoints for 17943 into gs://edml/ai-platform/models/edml_trainer_20200421_110923/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-04-21T11:20:21Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from gs://edml/ai-platform/models/edml_trainer_20200421_110923/model.ckpt-17943
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/3]
# INFO:tensorflow:Evaluation [2/3]
# INFO:tensorflow:Evaluation [3/3]
# INFO:tensorflow:Finished evaluation at 2020-04-21-11:20:37
# INFO:tensorflow:Saving dict for global step 17943: average_loss = 4661.332, global_step = 17943, label/mean = 18.23884, loss = 152742530.0, prediction/mean = 4.380567, rmse = 68.27395
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 17943: gs://edml/ai-platform/models/edml_trainer_20200421_110923/model.ckpt-17943
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['predict']
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Signatures EXCLUDED from export because they cannot be be served via TensorFlow Serving APIs:
# INFO:tensorflow:'serving_default' : Regression input must be a single string Tensor; got {'dayofweek': <tf.Tensor 'dayofweek:0' shape=(?,) dtype=int64>, 'hourofday': <tf.Tensor 'hourofday:0' shape=(?,) dtype=int64>, 'weekofyear': <tf.Tensor 'weekofyear:0' shape=(?,) dtype=int64>, 'pickup_zone_name': <tf.Tensor 'pickup_zone_name:0' shape=(?,) dtype=string>, 'dropoff_zone_name': <tf.Tensor 'dropoff_zone_name:0' shape=(?,) dtype=string>, 'passenger_count': <tf.Tensor 'passenger_count:0' shape=(?,) dtype=int64>, 'distance': <tf.Tensor 'distance:0' shape=(?,) dtype=float64>, 'uuid': <tf.Tensor 'uuid:0' shape=(?,) dtype=string>}
# INFO:tensorflow:'regression' : Regression input must be a single string Tensor; got {'dayofweek': <tf.Tensor 'dayofweek:0' shape=(?,) dtype=int64>, 'hourofday': <tf.Tensor 'hourofday:0' shape=(?,) dtype=int64>, 'weekofyear': <tf.Tensor 'weekofyear:0' shape=(?,) dtype=int64>, 'pickup_zone_name': <tf.Tensor 'pickup_zone_name:0' shape=(?,) dtype=string>, 'dropoff_zone_name': <tf.Tensor 'dropoff_zone_name:0' shape=(?,) dtype=string>, 'passenger_count': <tf.Tensor 'passenger_count:0' shape=(?,) dtype=int64>, 'distance': <tf.Tensor 'distance:0' shape=(?,) dtype=float64>, 'uuid': <tf.Tensor 'uuid:0' shape=(?,) dtype=string>}
# WARNING:tensorflow:Export includes no default signature!
# INFO:tensorflow:Restoring parameters from gs://edml/ai-platform/models/edml_trainer_20200421_110923/model.ckpt-17943
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: gs://edml/ai-platform/models/edml_trainer_20200421_110923/export/exporter/temp-b'1587468040'/saved_model.pb
# INFO:tensorflow:global_step/sec: 1.48468
# INFO:tensorflow:loss = 1969901.5, step = 18000 (67.355 sec)
# INFO:tensorflow:global_step/sec: 35.8232
# INFO:tensorflow:loss = 48640.758, step = 18100 (2.791 sec)
# INFO:tensorflow:global_step/sec: 34.9575
# INFO:tensorflow:loss = 2070890.8, step = 18200 (2.861 sec)
# INFO:tensorflow:global_step/sec: 35.616
# INFO:tensorflow:loss = 32047.375, step = 18300 (2.807 sec)
# INFO:tensorflow:global_step/sec: 35.7708
# INFO:tensorflow:loss = 29597.453, step = 18400 (2.796 sec)
# INFO:tensorflow:global_step/sec: 35.5394
# INFO:tensorflow:loss = 35934.965, step = 18500 (2.814 sec)
# INFO:tensorflow:global_step/sec: 35.1592
# INFO:tensorflow:loss = 2055897.6, step = 18600 (2.844 sec)
# INFO:tensorflow:global_step/sec: 35.0762
# INFO:tensorflow:loss = 20264.117, step = 18700 (2.851 sec)
# INFO:tensorflow:global_step/sec: 35.0534
# INFO:tensorflow:loss = 27173.324, step = 18800 (2.853 sec)
# INFO:tensorflow:global_step/sec: 35.2165
# INFO:tensorflow:loss = 21694.58, step = 18900 (2.840 sec)
# INFO:tensorflow:global_step/sec: 35.2585
# INFO:tensorflow:loss = 20001.047, step = 19000 (2.836 sec)
# INFO:tensorflow:global_step/sec: 34.8333
# INFO:tensorflow:loss = 20202.572, step = 19100 (2.871 sec)
# INFO:tensorflow:global_step/sec: 35.4745
# INFO:tensorflow:loss = 34723.883, step = 19200 (2.819 sec)
# INFO:tensorflow:global_step/sec: 35.4969
# INFO:tensorflow:loss = 1981525.9, step = 19300 (2.817 sec)
# INFO:tensorflow:global_step/sec: 34.8054
# INFO:tensorflow:loss = 33424.066, step = 19400 (2.873 sec)
# INFO:tensorflow:global_step/sec: 35.1455
# INFO:tensorflow:loss = 26444.371, step = 19500 (2.845 sec)
# INFO:tensorflow:global_step/sec: 35.6305
# INFO:tensorflow:loss = 4115271.5, step = 19600 (2.807 sec)
# INFO:tensorflow:global_step/sec: 35.6881
# INFO:tensorflow:loss = 24842.012, step = 19700 (2.802 sec)
# INFO:tensorflow:global_step/sec: 35.4718
# INFO:tensorflow:loss = 23955.918, step = 19800 (2.819 sec)
# INFO:tensorflow:global_step/sec: 35.5865
# INFO:tensorflow:loss = 19885.164, step = 19900 (2.810 sec)
# INFO:tensorflow:global_step/sec: 35.0142
# INFO:tensorflow:loss = 25999.207, step = 20000 (2.856 sec)
# INFO:tensorflow:global_step/sec: 35.5157
# INFO:tensorflow:loss = 29841.598, step = 20100 (2.815 sec)
# INFO:tensorflow:global_step/sec: 35.0603
# INFO:tensorflow:loss = 26303.57, step = 20200 (2.852 sec)
# INFO:tensorflow:global_step/sec: 35.8887
# INFO:tensorflow:loss = 25305.572, step = 20300 (2.786 sec)
# INFO:tensorflow:global_step/sec: 35.2124
# INFO:tensorflow:loss = 31487.74, step = 20400 (2.840 sec)
# INFO:tensorflow:global_step/sec: 35.1234
# INFO:tensorflow:loss = 23185.807, step = 20500 (4.347 sec)
# INFO:tensorflow:global_step/sec: 23.1837
# INFO:tensorflow:loss = 23485.352, step = 20600 (2.813 sec)
# INFO:tensorflow:global_step/sec: 35.75
# INFO:tensorflow:loss = 2050623.2, step = 20700 (2.797 sec)
# INFO:tensorflow:global_step/sec: 35.4288
# INFO:tensorflow:loss = 26823.633, step = 20800 (2.823 sec)
# INFO:tensorflow:global_step/sec: 35.8356
# INFO:tensorflow:loss = 18125.684, step = 20900 (2.791 sec)
# INFO:tensorflow:global_step/sec: 35.3731
# INFO:tensorflow:loss = 21356.156, step = 21000 (2.827 sec)
# INFO:tensorflow:global_step/sec: 35.5555
# INFO:tensorflow:loss = 26254.996, step = 21100 (2.813 sec)
# INFO:tensorflow:global_step/sec: 35.6868
# INFO:tensorflow:loss = 19166.195, step = 21200 (2.802 sec)
# INFO:tensorflow:global_step/sec: 35.3763
# INFO:tensorflow:loss = 19096.506, step = 21300 (2.827 sec)
# INFO:tensorflow:global_step/sec: 35.4999
# INFO:tensorflow:loss = 27051.562, step = 21400 (2.817 sec)
# INFO:tensorflow:global_step/sec: 35.4141
# INFO:tensorflow:loss = 23315.998, step = 21500 (2.824 sec)
# INFO:tensorflow:global_step/sec: 35.6756
# INFO:tensorflow:loss = 38857.832, step = 21600 (2.803 sec)
# INFO:tensorflow:global_step/sec: 35.9455
# INFO:tensorflow:loss = 1743060.5, step = 21700 (2.782 sec)
# INFO:tensorflow:global_step/sec: 35.1121
# INFO:tensorflow:loss = 24123.79, step = 21800 (2.848 sec)
# INFO:tensorflow:global_step/sec: 35.7336
# INFO:tensorflow:loss = 13734.481, step = 21900 (2.798 sec)
# INFO:tensorflow:global_step/sec: 35.6817
# INFO:tensorflow:loss = 27572.902, step = 22000 (2.803 sec)
# INFO:tensorflow:global_step/sec: 35.4142
# INFO:tensorflow:loss = 27903.475, step = 22100 (2.824 sec)
# INFO:tensorflow:global_step/sec: 35.5499
# INFO:tensorflow:loss = 19519.164, step = 22200 (2.813 sec)
# INFO:tensorflow:global_step/sec: 35.9694
# INFO:tensorflow:loss = 19012.457, step = 22300 (2.780 sec)
# INFO:tensorflow:global_step/sec: 35.2738
# INFO:tensorflow:loss = 23096.05, step = 22400 (2.835 sec)
# INFO:tensorflow:global_step/sec: 35.9002
# INFO:tensorflow:loss = 21859.66, step = 22500 (2.785 sec)
# INFO:tensorflow:global_step/sec: 35.678
# INFO:tensorflow:loss = 4063296.8, step = 22600 (2.803 sec)
# INFO:tensorflow:global_step/sec: 35.8445
# INFO:tensorflow:loss = 2027691.0, step = 22700 (2.790 sec)
# INFO:tensorflow:global_step/sec: 35.326
# INFO:tensorflow:loss = 20412.348, step = 22800 (2.831 sec)
# INFO:tensorflow:global_step/sec: 35.8252
# INFO:tensorflow:loss = 14437.21, step = 22900 (2.791 sec)
# INFO:tensorflow:global_step/sec: 35.867
# INFO:tensorflow:loss = 20659.984, step = 23000 (2.788 sec)
# INFO:tensorflow:global_step/sec: 35.771
# INFO:tensorflow:loss = 23053.523, step = 23100 (2.796 sec)
# INFO:tensorflow:global_step/sec: 35.6585
# INFO:tensorflow:loss = 44174.492, step = 23200 (2.804 sec)
# INFO:tensorflow:global_step/sec: 35.7176
# INFO:tensorflow:loss = 1942179.5, step = 23300 (2.802 sec)
# INFO:tensorflow:global_step/sec: 35.6266
# INFO:tensorflow:loss = 19926.82, step = 23400 (2.805 sec)
# INFO:tensorflow:global_step/sec: 35.6084
# INFO:tensorflow:loss = 21775.828, step = 23500 (2.809 sec)
# INFO:tensorflow:global_step/sec: 35.738
# INFO:tensorflow:loss = 20355.398, step = 23600 (2.798 sec)
# INFO:tensorflow:global_step/sec: 35.6439
# INFO:tensorflow:loss = 23337.07, step = 23700 (2.805 sec)
# INFO:tensorflow:global_step/sec: 35.0726
# INFO:tensorflow:loss = 13224.176, step = 23800 (2.852 sec)
# INFO:tensorflow:global_step/sec: 35.3586
# INFO:tensorflow:loss = 890822.1, step = 23900 (2.828 sec)
# INFO:tensorflow:global_step/sec: 35.1481
# INFO:tensorflow:loss = 21572.553, step = 24000 (2.845 sec)
# INFO:tensorflow:global_step/sec: 35.5683
# INFO:tensorflow:loss = 31014.246, step = 24100 (2.811 sec)
# INFO:tensorflow:global_step/sec: 34.9749
# INFO:tensorflow:loss = 21866.047, step = 24200 (2.859 sec)
# INFO:tensorflow:global_step/sec: 35.5094
# INFO:tensorflow:loss = 57526.727, step = 24300 (2.816 sec)
# INFO:tensorflow:global_step/sec: 33.2429
# INFO:tensorflow:loss = 18730.914, step = 24400 (3.008 sec)
# INFO:tensorflow:global_step/sec: 29.0069
# INFO:tensorflow:loss = 23922.781, step = 24500 (3.447 sec)
# INFO:tensorflow:global_step/sec: 29.1407
# INFO:tensorflow:loss = 23034.959, step = 24600 (3.432 sec)
# INFO:tensorflow:global_step/sec: 30.6493
# INFO:tensorflow:loss = 21509.14, step = 24700 (4.423 sec)
# INFO:tensorflow:global_step/sec: 25.295
# INFO:tensorflow:loss = 37760.188, step = 24800 (2.793 sec)
# INFO:tensorflow:global_step/sec: 35.9479
# INFO:tensorflow:loss = 26860.49, step = 24900 (2.781 sec)
# INFO:tensorflow:global_step/sec: 35.7044
# INFO:tensorflow:loss = 19846.02, step = 25000 (2.801 sec)
# INFO:tensorflow:global_step/sec: 35.9364
# INFO:tensorflow:loss = 18518.445, step = 25100 (2.783 sec)
# INFO:tensorflow:global_step/sec: 35.596
# INFO:tensorflow:loss = 24613.562, step = 25200 (2.810 sec)
# INFO:tensorflow:global_step/sec: 35.4774
# INFO:tensorflow:loss = 21092.285, step = 25300 (2.819 sec)
# INFO:tensorflow:global_step/sec: 35.2352
# INFO:tensorflow:loss = 2064984.4, step = 25400 (2.838 sec)
# INFO:tensorflow:global_step/sec: 35.6113
# INFO:tensorflow:loss = 2057175.1, step = 25500 (2.808 sec)
# INFO:tensorflow:global_step/sec: 35.3653
# INFO:tensorflow:loss = 25951.084, step = 25600 (2.828 sec)
# INFO:tensorflow:global_step/sec: 35.2213
# INFO:tensorflow:loss = 20463.352, step = 25700 (2.839 sec)
# INFO:tensorflow:global_step/sec: 35.1426
# INFO:tensorflow:loss = 17152.244, step = 25800 (2.845 sec)
# INFO:tensorflow:global_step/sec: 34.9703
# INFO:tensorflow:loss = 18980.754, step = 25900 (2.859 sec)
# INFO:tensorflow:global_step/sec: 34.5393
# INFO:tensorflow:loss = 2089416.6, step = 26000 (2.895 sec)
# INFO:tensorflow:global_step/sec: 35.316
# INFO:tensorflow:loss = 15805.457, step = 26100 (2.832 sec)
# INFO:tensorflow:Saving checkpoints for 26132 into gs://edml/ai-platform/models/edml_trainer_20200421_110923/model.ckpt.
# WARNING:tensorflow:From /opt/conda/lib/python3.7/site-packages/tensorflow_core/python/training/saver.py:963: remove_checkpoint (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to delete files with this prefix.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-04-21T11:25:21Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from gs://edml/ai-platform/models/edml_trainer_20200421_110923/model.ckpt-26132
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/3]
# INFO:tensorflow:Evaluation [2/3]
# INFO:tensorflow:Evaluation [3/3]
# INFO:tensorflow:Finished evaluation at 2020-04-21-11:25:39
# INFO:tensorflow:Saving dict for global step 26132: average_loss = 4610.0117, global_step = 26132, label/mean = 18.122202, loss = 151060860.0, prediction/mean = 5.2658577, rmse = 67.897064
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 26132: gs://edml/ai-platform/models/edml_trainer_20200421_110923/model.ckpt-26132
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['predict']
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Signatures EXCLUDED from export because they cannot be be served via TensorFlow Serving APIs:
# INFO:tensorflow:'serving_default' : Regression input must be a single string Tensor; got {'dayofweek': <tf.Tensor 'dayofweek:0' shape=(?,) dtype=int64>, 'hourofday': <tf.Tensor 'hourofday:0' shape=(?,) dtype=int64>, 'weekofyear': <tf.Tensor 'weekofyear:0' shape=(?,) dtype=int64>, 'pickup_zone_name': <tf.Tensor 'pickup_zone_name:0' shape=(?,) dtype=string>, 'dropoff_zone_name': <tf.Tensor 'dropoff_zone_name:0' shape=(?,) dtype=string>, 'passenger_count': <tf.Tensor 'passenger_count:0' shape=(?,) dtype=int64>, 'distance': <tf.Tensor 'distance:0' shape=(?,) dtype=float64>, 'uuid': <tf.Tensor 'uuid:0' shape=(?,) dtype=string>}
# INFO:tensorflow:'regression' : Regression input must be a single string Tensor; got {'dayofweek': <tf.Tensor 'dayofweek:0' shape=(?,) dtype=int64>, 'hourofday': <tf.Tensor 'hourofday:0' shape=(?,) dtype=int64>, 'weekofyear': <tf.Tensor 'weekofyear:0' shape=(?,) dtype=int64>, 'pickup_zone_name': <tf.Tensor 'pickup_zone_name:0' shape=(?,) dtype=string>, 'dropoff_zone_name': <tf.Tensor 'dropoff_zone_name:0' shape=(?,) dtype=string>, 'passenger_count': <tf.Tensor 'passenger_count:0' shape=(?,) dtype=int64>, 'distance': <tf.Tensor 'distance:0' shape=(?,) dtype=float64>, 'uuid': <tf.Tensor 'uuid:0' shape=(?,) dtype=string>}
# WARNING:tensorflow:Export includes no default signature!
# INFO:tensorflow:Restoring parameters from gs://edml/ai-platform/models/edml_trainer_20200421_110923/model.ckpt-26132
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: gs://edml/ai-platform/models/edml_trainer_20200421_110923/export/exporter/temp-b'1587468342'/saved_model.pb
# INFO:tensorflow:global_step/sec: 1.44225
# INFO:tensorflow:loss = 15875.797, step = 26200 (69.336 sec)
# INFO:tensorflow:global_step/sec: 35.8332
# INFO:tensorflow:loss = 17994.521, step = 26300 (2.791 sec)
# INFO:tensorflow:global_step/sec: 35.031
# INFO:tensorflow:loss = 23446.973, step = 26400 (2.854 sec)
# INFO:tensorflow:global_step/sec: 35.0921
# INFO:tensorflow:loss = 21300.504, step = 26500 (2.850 sec)
# INFO:tensorflow:global_step/sec: 34.9871
# INFO:tensorflow:loss = 26998.6, step = 26600 (4.462 sec)
# INFO:tensorflow:global_step/sec: 22.4971
# INFO:tensorflow:loss = 18173.062, step = 26700 (2.841 sec)
# INFO:tensorflow:global_step/sec: 35.4067
# INFO:tensorflow:loss = 26486.977, step = 26800 (2.824 sec)
# INFO:tensorflow:global_step/sec: 35.5913
# INFO:tensorflow:loss = 24493.0, step = 26900 (2.810 sec)
# INFO:tensorflow:global_step/sec: 34.8841
# INFO:tensorflow:loss = 26632.078, step = 27000 (2.867 sec)
# INFO:tensorflow:global_step/sec: 35.1497
# INFO:tensorflow:loss = 185357.73, step = 27100 (2.844 sec)
# INFO:tensorflow:global_step/sec: 35.2931
# INFO:tensorflow:loss = 15760.187, step = 27200 (2.834 sec)
# INFO:tensorflow:global_step/sec: 35.704
# INFO:tensorflow:loss = 14429.58, step = 27300 (2.801 sec)
# INFO:tensorflow:global_step/sec: 35.4426
# INFO:tensorflow:loss = 17153.383, step = 27400 (2.821 sec)
# INFO:tensorflow:global_step/sec: 35.3491
# INFO:tensorflow:loss = 17840.621, step = 27500 (2.829 sec)
# INFO:tensorflow:global_step/sec: 35.487
# INFO:tensorflow:loss = 21245.197, step = 27600 (2.818 sec)
# INFO:tensorflow:global_step/sec: 35.3526
# INFO:tensorflow:loss = 24324.275, step = 27700 (2.829 sec)
# INFO:tensorflow:global_step/sec: 34.3824
# INFO:tensorflow:loss = 4034924.2, step = 27800 (2.908 sec)
# INFO:tensorflow:global_step/sec: 35.4118
# INFO:tensorflow:loss = 21644.48, step = 27900 (2.824 sec)
# INFO:tensorflow:global_step/sec: 35.2559
# INFO:tensorflow:loss = 24151.596, step = 28000 (2.836 sec)
# INFO:tensorflow:global_step/sec: 35.4128
# INFO:tensorflow:loss = 25081.732, step = 28100 (2.824 sec)
# INFO:tensorflow:global_step/sec: 35.237
# INFO:tensorflow:loss = 20985.734, step = 28200 (2.838 sec)
# INFO:tensorflow:global_step/sec: 35.3885
# INFO:tensorflow:loss = 13960.432, step = 28300 (2.828 sec)
# INFO:tensorflow:global_step/sec: 35.43
# INFO:tensorflow:loss = 15957.891, step = 28400 (2.821 sec)
# INFO:tensorflow:global_step/sec: 35.9625
# INFO:tensorflow:loss = 16747.55, step = 28500 (2.781 sec)
# INFO:tensorflow:global_step/sec: 35.5421
# INFO:tensorflow:loss = 19032.602, step = 28600 (2.814 sec)
# INFO:tensorflow:global_step/sec: 35.4645
# INFO:tensorflow:loss = 2053700.0, step = 28700 (2.820 sec)
# INFO:tensorflow:global_step/sec: 35.6327
# INFO:tensorflow:loss = 19922.684, step = 28800 (2.806 sec)
# INFO:tensorflow:global_step/sec: 36.0487
# INFO:tensorflow:loss = 19840.719, step = 28900 (2.774 sec)
# INFO:tensorflow:global_step/sec: 35.6237
# INFO:tensorflow:loss = 16575.207, step = 29000 (2.807 sec)
# INFO:tensorflow:global_step/sec: 35.5714
# INFO:tensorflow:loss = 15265.328, step = 29100 (2.811 sec)
# INFO:tensorflow:global_step/sec: 35.5004
# INFO:tensorflow:loss = 29168.426, step = 29200 (2.817 sec)
# INFO:tensorflow:global_step/sec: 35.6786
# INFO:tensorflow:loss = 1926245.0, step = 29300 (2.803 sec)
# INFO:tensorflow:global_step/sec: 35.4477
# INFO:tensorflow:loss = 17532.748, step = 29400 (2.821 sec)
# INFO:tensorflow:global_step/sec: 35.7706
# INFO:tensorflow:loss = 4123881.5, step = 29500 (2.796 sec)
# INFO:tensorflow:global_step/sec: 34.9124
# INFO:tensorflow:loss = 28922.93, step = 29600 (2.864 sec)
# INFO:tensorflow:global_step/sec: 35.4738
# INFO:tensorflow:loss = 36647.355, step = 29700 (2.819 sec)
# INFO:tensorflow:global_step/sec: 35.3932
# INFO:tensorflow:loss = 25627.547, step = 29800 (2.825 sec)
# INFO:tensorflow:global_step/sec: 35.7106
# INFO:tensorflow:loss = 21687.508, step = 29900 (2.800 sec)
# INFO:tensorflow:global_step/sec: 35.4026
# INFO:tensorflow:loss = 18529.387, step = 30000 (2.825 sec)
# INFO:tensorflow:global_step/sec: 36.0194
# INFO:tensorflow:loss = 2067087.6, step = 30100 (2.777 sec)
# INFO:tensorflow:global_step/sec: 35.0306
# INFO:tensorflow:loss = 19966.969, step = 30200 (2.854 sec)
# INFO:tensorflow:global_step/sec: 35.9158
# INFO:tensorflow:loss = 26460.742, step = 30300 (2.785 sec)
# INFO:tensorflow:global_step/sec: 35.7509
# INFO:tensorflow:loss = 34890.227, step = 30400 (2.797 sec)
# INFO:tensorflow:global_step/sec: 35.5882
# INFO:tensorflow:loss = 24398.086, step = 30500 (2.810 sec)
# INFO:tensorflow:global_step/sec: 35.7928
# INFO:tensorflow:loss = 21181.955, step = 30600 (2.794 sec)
# INFO:tensorflow:global_step/sec: 35.4875
# INFO:tensorflow:loss = 2060815.8, step = 30700 (2.818 sec)
# INFO:tensorflow:global_step/sec: 35.7585
# INFO:tensorflow:loss = 14865.863, step = 30800 (3.943 sec)
# INFO:tensorflow:global_step/sec: 25.2677
# INFO:tensorflow:loss = 15067.17, step = 30900 (2.811 sec)
# INFO:tensorflow:global_step/sec: 35.1679
# INFO:tensorflow:loss = 2061872.8, step = 31000 (2.844 sec)
# INFO:tensorflow:global_step/sec: 35.6818
# INFO:tensorflow:loss = 39478.805, step = 31100 (2.803 sec)
# INFO:tensorflow:global_step/sec: 35.4932
# INFO:tensorflow:loss = 21577.756, step = 31200 (2.817 sec)
# INFO:tensorflow:global_step/sec: 35.2568
# INFO:tensorflow:loss = 20686.75, step = 31300 (2.837 sec)
# INFO:tensorflow:global_step/sec: 34.4822
# INFO:tensorflow:loss = 26061.703, step = 31400 (2.900 sec)
# INFO:tensorflow:global_step/sec: 35.5453
# INFO:tensorflow:loss = 17107.05, step = 31500 (2.813 sec)
# INFO:tensorflow:global_step/sec: 35.9152
# INFO:tensorflow:loss = 16391.164, step = 31600 (2.784 sec)
# INFO:tensorflow:global_step/sec: 35.4386
# INFO:tensorflow:loss = 20086.611, step = 31700 (2.822 sec)
# INFO:tensorflow:global_step/sec: 35.5764
# INFO:tensorflow:loss = 14025.633, step = 31800 (2.811 sec)
# INFO:tensorflow:global_step/sec: 35.6093
# INFO:tensorflow:loss = 21876.703, step = 31900 (2.808 sec)
# INFO:tensorflow:global_step/sec: 35.4149
# INFO:tensorflow:loss = 15873.557, step = 32000 (2.824 sec)
# INFO:tensorflow:global_step/sec: 35.1297
# INFO:tensorflow:loss = 20868.848, step = 32100 (2.847 sec)
# INFO:tensorflow:global_step/sec: 35.5007
# INFO:tensorflow:loss = 22616.285, step = 32200 (2.817 sec)
# INFO:tensorflow:global_step/sec: 35.8211
# INFO:tensorflow:loss = 14667.319, step = 32300 (2.792 sec)
# INFO:tensorflow:global_step/sec: 35.2085
# INFO:tensorflow:loss = 19456.15, step = 32400 (2.840 sec)
# INFO:tensorflow:global_step/sec: 35.9757
# INFO:tensorflow:loss = 27081.996, step = 32500 (2.780 sec)
# INFO:tensorflow:global_step/sec: 35.4151
# INFO:tensorflow:loss = 12401.447, step = 32600 (2.824 sec)
# INFO:tensorflow:global_step/sec: 35.8313
# INFO:tensorflow:loss = 2049777.4, step = 32700 (2.791 sec)
# INFO:tensorflow:global_step/sec: 35.8483
# INFO:tensorflow:loss = 18485.037, step = 32800 (2.790 sec)
# INFO:tensorflow:global_step/sec: 31.02
# INFO:tensorflow:loss = 1952234.8, step = 32900 (3.224 sec)
# INFO:tensorflow:global_step/sec: 29.42
# INFO:tensorflow:loss = 1921879.2, step = 33000 (3.399 sec)
# INFO:tensorflow:global_step/sec: 29.2097
# INFO:tensorflow:loss = 12197.636, step = 33100 (3.424 sec)
# INFO:tensorflow:global_step/sec: 33.7323
# INFO:tensorflow:loss = 2067027.0, step = 33200 (2.964 sec)
# INFO:tensorflow:global_step/sec: 35.6095
# INFO:tensorflow:loss = 1957558.2, step = 33300 (2.809 sec)
# INFO:tensorflow:global_step/sec: 35.4178
# INFO:tensorflow:loss = 2067473.2, step = 33400 (2.823 sec)
# INFO:tensorflow:global_step/sec: 35.7714
# INFO:tensorflow:loss = 1991319.9, step = 33500 (2.795 sec)
# INFO:tensorflow:global_step/sec: 35.5069
# INFO:tensorflow:loss = 19723.75, step = 33600 (2.816 sec)
# INFO:tensorflow:global_step/sec: 35.6613
# INFO:tensorflow:loss = 1983481.6, step = 33700 (2.804 sec)
# INFO:tensorflow:global_step/sec: 35.2194
# INFO:tensorflow:loss = 21759.488, step = 33800 (2.840 sec)
# INFO:tensorflow:global_step/sec: 35.7154
# INFO:tensorflow:loss = 21002.748, step = 33900 (2.800 sec)
# INFO:tensorflow:global_step/sec: 35.7838
# INFO:tensorflow:loss = 25394.182, step = 34000 (2.795 sec)
# INFO:tensorflow:global_step/sec: 35.7515
# INFO:tensorflow:loss = 21689.941, step = 34100 (2.797 sec)
# INFO:tensorflow:global_step/sec: 35.3086
# INFO:tensorflow:loss = 18352.693, step = 34200 (2.832 sec)
# INFO:tensorflow:Saving checkpoints for 34257 into gs://edml/ai-platform/models/edml_trainer_20200421_110923/model.ckpt.
# INFO:tensorflow:Skip the current checkpoint eval due to throttle secs (300 secs).
# INFO:tensorflow:global_step/sec: 4.86367
# INFO:tensorflow:loss = 31564.629, step = 34300 (20.561 sec)
# INFO:tensorflow:global_step/sec: 35.3905
# INFO:tensorflow:loss = 30899.055, step = 34400 (3.800 sec)
# INFO:tensorflow:global_step/sec: 26.534
# INFO:tensorflow:loss = 25597.354, step = 34500 (2.794 sec)
# INFO:tensorflow:global_step/sec: 35.5726
# INFO:tensorflow:loss = 17604.998, step = 34600 (2.811 sec)
# INFO:tensorflow:global_step/sec: 29.0078
# INFO:tensorflow:loss = 15209.583, step = 34700 (3.447 sec)
# INFO:tensorflow:global_step/sec: 30.7471
# INFO:tensorflow:loss = 493847.44, step = 34800 (3.252 sec)
# INFO:tensorflow:global_step/sec: 35.427
# INFO:tensorflow:loss = 17387.287, step = 34900 (2.823 sec)
# INFO:tensorflow:global_step/sec: 35.4768
# INFO:tensorflow:loss = 1989952.2, step = 35000 (2.819 sec)
# INFO:tensorflow:global_step/sec: 35.562
# INFO:tensorflow:loss = 15936.1455, step = 35100 (2.812 sec)
# INFO:tensorflow:global_step/sec: 35.6933
# INFO:tensorflow:loss = 20382.453, step = 35200 (2.801 sec)
# INFO:tensorflow:global_step/sec: 35.152
# INFO:tensorflow:loss = 21789.066, step = 35300 (2.845 sec)
# INFO:tensorflow:global_step/sec: 35.2073
# INFO:tensorflow:loss = 13869.589, step = 35400 (2.840 sec)
# INFO:tensorflow:global_step/sec: 35.0387
# INFO:tensorflow:loss = 2004868.6, step = 35500 (2.854 sec)
# INFO:tensorflow:global_step/sec: 35.3898
# INFO:tensorflow:loss = 17715.701, step = 35600 (2.826 sec)
# INFO:tensorflow:global_step/sec: 35.4477
# INFO:tensorflow:loss = 12889.922, step = 35700 (2.821 sec)
# INFO:tensorflow:global_step/sec: 35.786
# INFO:tensorflow:loss = 12926.481, step = 35800 (2.794 sec)
# INFO:tensorflow:global_step/sec: 35.4456
# INFO:tensorflow:loss = 24391.592, step = 35900 (2.821 sec)
# INFO:tensorflow:global_step/sec: 35.6019
# INFO:tensorflow:loss = 17241.16, step = 36000 (2.809 sec)
# INFO:tensorflow:global_step/sec: 35.8599
# INFO:tensorflow:loss = 1968700.8, step = 36100 (2.789 sec)
# INFO:tensorflow:global_step/sec: 35.4055
# INFO:tensorflow:loss = 18406.207, step = 36200 (2.824 sec)
# INFO:tensorflow:global_step/sec: 35.8598
# INFO:tensorflow:loss = 1924233.2, step = 36300 (2.789 sec)
# INFO:tensorflow:global_step/sec: 35.9844
# INFO:tensorflow:loss = 25067.73, step = 36400 (2.779 sec)
# INFO:tensorflow:global_step/sec: 35.7539
# INFO:tensorflow:loss = 14434.464, step = 36500 (2.797 sec)
# INFO:tensorflow:global_step/sec: 35.6861
# INFO:tensorflow:loss = 2057796.5, step = 36600 (2.802 sec)
# INFO:tensorflow:global_step/sec: 36.247
# INFO:tensorflow:loss = 2047889.6, step = 36700 (2.759 sec)
# INFO:tensorflow:global_step/sec: 35.6878
# INFO:tensorflow:loss = 18643.646, step = 36800 (2.802 sec)
# INFO:tensorflow:global_step/sec: 35.6314
# INFO:tensorflow:loss = 1931798.1, step = 36900 (2.807 sec)
# INFO:tensorflow:global_step/sec: 35.3777
# INFO:tensorflow:loss = 24995.787, step = 37000 (2.827 sec)
# ...
# WARNING:tensorflow:Export includes no default signature!
# INFO:tensorflow:Restoring parameters from gs://edml/ai-platform/models/edml_trainer_20200421_110923/model.ckpt-88238
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: gs://edml/ai-platform/models/edml_trainer_20200421_110923/export/exporter/temp-b'1587470444'/saved_model.pb
# INFO:tensorflow:global_step/sec: 1.36059
# INFO:tensorflow:loss = 14547.17, step = 88300 (73.497 sec)
# INFO:tensorflow:global_step/sec: 35.5002
# INFO:tensorflow:loss = 15909.194, step = 88400 (2.817 sec)
# INFO:tensorflow:global_step/sec: 35.8646
# INFO:tensorflow:loss = 21377.441, step = 88500 (2.788 sec)
# INFO:tensorflow:global_step/sec: 35.7695
# INFO:tensorflow:loss = 995228.9, step = 88600 (2.796 sec)
# INFO:tensorflow:global_step/sec: 35.9011
# INFO:tensorflow:loss = 2032198.4, step = 88700 (4.093 sec)
# INFO:tensorflow:global_step/sec: 24.4285
# INFO:tensorflow:loss = 11698.072, step = 88800 (2.787 sec)
# INFO:tensorflow:global_step/sec: 35.7554
# INFO:tensorflow:loss = 11756.948, step = 88900 (2.797 sec)
# INFO:tensorflow:global_step/sec: 35.4605
# INFO:tensorflow:loss = 14391.803, step = 89000 (2.820 sec)
# INFO:tensorflow:global_step/sec: 35.4577
# INFO:tensorflow:loss = 12073.119, step = 89100 (2.820 sec)
# INFO:tensorflow:global_step/sec: 35.3179
# INFO:tensorflow:loss = 3990146.0, step = 89200 (2.831 sec)
# INFO:tensorflow:global_step/sec: 35.6232
# INFO:tensorflow:loss = 1938108.4, step = 89300 (2.807 sec)
# INFO:tensorflow:global_step/sec: 35.5902
# INFO:tensorflow:loss = 16780.215, step = 89400 (2.810 sec)
# INFO:tensorflow:global_step/sec: 35.6486
# INFO:tensorflow:loss = 14285.177, step = 89500 (2.805 sec)
# INFO:tensorflow:global_step/sec: 35.764
# INFO:tensorflow:loss = 2011325.6, step = 89600 (2.796 sec)
# INFO:tensorflow:global_step/sec: 35.691
# INFO:tensorflow:loss = 19339.754, step = 89700 (2.802 sec)
# INFO:tensorflow:global_step/sec: 35.646
# INFO:tensorflow:loss = 27803.746, step = 89800 (2.806 sec)
# INFO:tensorflow:global_step/sec: 35.7911
# INFO:tensorflow:loss = 13612.114, step = 89900 (2.794 sec)
# INFO:tensorflow:global_step/sec: 35.5072
# INFO:tensorflow:loss = 18833.395, step = 90000 (2.816 sec)
# INFO:tensorflow:global_step/sec: 36.1577
# INFO:tensorflow:loss = 13554.01, step = 90100 (2.766 sec)
# INFO:tensorflow:global_step/sec: 35.4991
# INFO:tensorflow:loss = 24042.586, step = 90200 (2.817 sec)
# INFO:tensorflow:global_step/sec: 35.6533
# INFO:tensorflow:loss = 7909.3643, step = 90300 (2.805 sec)
# INFO:tensorflow:global_step/sec: 35.4998
# INFO:tensorflow:loss = 23183.451, step = 90400 (2.817 sec)
# INFO:tensorflow:global_step/sec: 35.687
# INFO:tensorflow:loss = 8056.658, step = 90500 (2.802 sec)
# INFO:tensorflow:global_step/sec: 35.6188
# INFO:tensorflow:loss = 17708.416, step = 90600 (2.808 sec)
# INFO:tensorflow:global_step/sec: 35.8654
# INFO:tensorflow:loss = 10785.499, step = 90700 (2.788 sec)
# INFO:tensorflow:global_step/sec: 35.6775
# INFO:tensorflow:loss = 9394.494, step = 90800 (2.803 sec)
# INFO:tensorflow:global_step/sec: 35.6412
# INFO:tensorflow:loss = 14694.84, step = 90900 (2.806 sec)
# INFO:tensorflow:global_step/sec: 35.4509
# INFO:tensorflow:loss = 10723.532, step = 91000 (2.821 sec)
# INFO:tensorflow:global_step/sec: 35.833
# INFO:tensorflow:loss = 19171.793, step = 91100 (2.791 sec)
# INFO:tensorflow:global_step/sec: 35.6252
# INFO:tensorflow:loss = 15972.235, step = 91200 (2.807 sec)
# INFO:tensorflow:global_step/sec: 35.9477
# INFO:tensorflow:loss = 10454.13, step = 91300 (2.782 sec)
# INFO:tensorflow:global_step/sec: 35.417
# INFO:tensorflow:loss = 20456.7, step = 91400 (2.823 sec)
# INFO:tensorflow:global_step/sec: 35.7858
# INFO:tensorflow:loss = 6370.4966, step = 91500 (2.794 sec)
# INFO:tensorflow:global_step/sec: 35.5415
# INFO:tensorflow:loss = 8014.1826, step = 91600 (2.814 sec)
# INFO:tensorflow:global_step/sec: 35.3523
# INFO:tensorflow:loss = 2057101.9, step = 91700 (2.829 sec)
# INFO:tensorflow:global_step/sec: 35.4492
# INFO:tensorflow:loss = 26885.98, step = 91800 (2.821 sec)
# INFO:tensorflow:global_step/sec: 35.6665
# INFO:tensorflow:loss = 17213.973, step = 91900 (2.804 sec)
# INFO:tensorflow:global_step/sec: 35.5527
# INFO:tensorflow:loss = 9619.487, step = 92000 (2.813 sec)
# INFO:tensorflow:global_step/sec: 35.2814
# INFO:tensorflow:loss = 3946764.5, step = 92100 (2.835 sec)
# INFO:tensorflow:global_step/sec: 35.328
# INFO:tensorflow:loss = 16526.996, step = 92200 (2.830 sec)
# INFO:tensorflow:global_step/sec: 35.6886
# INFO:tensorflow:loss = 2048712.8, step = 92300 (2.802 sec)
# INFO:tensorflow:global_step/sec: 35.0809
# INFO:tensorflow:loss = 10998.637, step = 92400 (2.851 sec)
# INFO:tensorflow:global_step/sec: 35.3828
# INFO:tensorflow:loss = 2053628.8, step = 92500 (2.826 sec)
# INFO:tensorflow:global_step/sec: 35.4688
# INFO:tensorflow:loss = 1953329.8, step = 92600 (2.819 sec)
# INFO:tensorflow:global_step/sec: 35.3027
# INFO:tensorflow:loss = 1963965.2, step = 92700 (2.833 sec)
# INFO:tensorflow:global_step/sec: 35.3633
# INFO:tensorflow:loss = 26051.441, step = 92800 (2.828 sec)
# INFO:tensorflow:global_step/sec: 35.4889
# INFO:tensorflow:loss = 17166.195, step = 92900 (2.818 sec)
# INFO:tensorflow:global_step/sec: 35.5504
# INFO:tensorflow:loss = 13547.193, step = 93000 (4.097 sec)
# INFO:tensorflow:global_step/sec: 24.3744
# INFO:tensorflow:loss = 14411.959, step = 93100 (2.818 sec)
# INFO:tensorflow:global_step/sec: 35.8008
# INFO:tensorflow:loss = 10715.082, step = 93200 (2.793 sec)
# INFO:tensorflow:global_step/sec: 35.6597
# INFO:tensorflow:loss = 7727.917, step = 93300 (2.804 sec)
# INFO:tensorflow:global_step/sec: 34.914
# INFO:tensorflow:loss = 10501.484, step = 93400 (2.865 sec)
# INFO:tensorflow:global_step/sec: 35.1938
# INFO:tensorflow:loss = 14935.773, step = 93500 (2.841 sec)
# INFO:tensorflow:global_step/sec: 35.3247
# INFO:tensorflow:loss = 12445.277, step = 93600 (2.831 sec)
# INFO:tensorflow:global_step/sec: 35.5096
# INFO:tensorflow:loss = 16627.57, step = 93700 (2.816 sec)
# INFO:tensorflow:global_step/sec: 35.2173
# INFO:tensorflow:loss = 3882705.0, step = 93800 (2.839 sec)
# INFO:tensorflow:global_step/sec: 35.4294
# INFO:tensorflow:loss = 2034720.4, step = 93900 (2.823 sec)
# INFO:tensorflow:global_step/sec: 35.6908
# INFO:tensorflow:loss = 3884299.2, step = 94000 (2.802 sec)
# INFO:tensorflow:global_step/sec: 34.8765
# INFO:tensorflow:loss = 2040647.8, step = 94100 (2.867 sec)
# INFO:tensorflow:global_step/sec: 34.8192
# INFO:tensorflow:loss = 223235.22, step = 94200 (2.872 sec)
# INFO:tensorflow:global_step/sec: 35.7364
# INFO:tensorflow:loss = 14790.076, step = 94300 (2.799 sec)
# INFO:tensorflow:global_step/sec: 35.4051
# INFO:tensorflow:loss = 13866.756, step = 94400 (2.824 sec)
# INFO:tensorflow:global_step/sec: 35.7404
# INFO:tensorflow:loss = 323592.66, step = 94500 (2.798 sec)
# INFO:tensorflow:global_step/sec: 35.3679
# INFO:tensorflow:loss = 472108.94, step = 94600 (2.828 sec)
# INFO:tensorflow:global_step/sec: 35.6327
# INFO:tensorflow:loss = 9750.701, step = 94700 (2.807 sec)
# INFO:tensorflow:global_step/sec: 35.3955
# INFO:tensorflow:loss = 8861.254, step = 94800 (2.825 sec)
# INFO:tensorflow:global_step/sec: 35.9147
# INFO:tensorflow:loss = 9537.85, step = 94900 (2.785 sec)
# INFO:tensorflow:global_step/sec: 35.6859
# INFO:tensorflow:loss = 15895.608, step = 95000 (2.803 sec)
# INFO:tensorflow:global_step/sec: 35.4732
# INFO:tensorflow:loss = 15612.078, step = 95100 (2.818 sec)
# INFO:tensorflow:global_step/sec: 35.9034
# INFO:tensorflow:loss = 1915191.4, step = 95200 (2.786 sec)
# INFO:tensorflow:global_step/sec: 35.7007
# INFO:tensorflow:loss = 15043.022, step = 95300 (2.801 sec)
# INFO:tensorflow:global_step/sec: 35.7429
# INFO:tensorflow:loss = 2068761.5, step = 95400 (2.797 sec)
# INFO:tensorflow:global_step/sec: 35.5748
# INFO:tensorflow:loss = 14271.357, step = 95500 (2.811 sec)
# INFO:tensorflow:global_step/sec: 35.8558
# INFO:tensorflow:loss = 4574552.0, step = 95600 (2.791 sec)
# INFO:tensorflow:global_step/sec: 35.8126
# INFO:tensorflow:loss = 14968.049, step = 95700 (2.791 sec)
# INFO:tensorflow:global_step/sec: 35.3035
# INFO:tensorflow:loss = 2008520.2, step = 95800 (2.832 sec)
# INFO:tensorflow:global_step/sec: 35.6482
# INFO:tensorflow:loss = 17040.633, step = 95900 (2.806 sec)
# INFO:tensorflow:global_step/sec: 35.4252
# INFO:tensorflow:loss = 9516.527, step = 96000 (2.822 sec)
# INFO:tensorflow:global_step/sec: 35.5467
# INFO:tensorflow:loss = 8138.2544, step = 96100 (2.813 sec)
# INFO:tensorflow:global_step/sec: 35.2431
# INFO:tensorflow:loss = 1919979.5, step = 96200 (2.837 sec)
# INFO:tensorflow:Saving checkpoints for 96300 into gs://edml/ai-platform/models/edml_trainer_20200421_110923/model.ckpt.
# INFO:tensorflow:Skip the current checkpoint eval due to throttle secs (300 secs).
# INFO:tensorflow:global_step/sec: 4.89593
# INFO:tensorflow:loss = 4008541.2, step = 96300 (20.425 sec)
# INFO:tensorflow:global_step/sec: 35.644
# INFO:tensorflow:loss = 11814.842, step = 96400 (2.805 sec)
# INFO:tensorflow:global_step/sec: 35.6574
# INFO:tensorflow:loss = 14485.524, step = 96500 (2.805 sec)
# INFO:tensorflow:global_step/sec: 35.4459
# INFO:tensorflow:loss = 2037254.0, step = 96600 (4.809 sec)
# INFO:tensorflow:global_step/sec: 20.9238
# INFO:tensorflow:loss = 15042.472, step = 96700 (2.791 sec)
# INFO:tensorflow:global_step/sec: 35.8524
# INFO:tensorflow:loss = 19108.674, step = 96800 (2.789 sec)
# INFO:tensorflow:global_step/sec: 29.1531
# INFO:tensorflow:loss = 2040675.1, step = 96900 (3.431 sec)
# INFO:tensorflow:global_step/sec: 29.0817
# INFO:tensorflow:loss = 15074.889, step = 97000 (3.438 sec)
# INFO:tensorflow:global_step/sec: 29.3878
# INFO:tensorflow:loss = 9377.35, step = 97100 (3.403 sec)
# INFO:tensorflow:global_step/sec: 35.556
# INFO:tensorflow:loss = 8460.375, step = 97200 (2.812 sec)
# INFO:tensorflow:global_step/sec: 35.6863
# INFO:tensorflow:loss = 4013533.0, step = 97300 (2.804 sec)
# INFO:tensorflow:global_step/sec: 35.3293
# INFO:tensorflow:loss = 6888.6367, step = 97400 (2.829 sec)
# INFO:tensorflow:global_step/sec: 35.2109
# INFO:tensorflow:loss = 16274.91, step = 97500 (2.840 sec)
# INFO:tensorflow:global_step/sec: 35.4822
# INFO:tensorflow:loss = 7234.513, step = 97600 (2.818 sec)
# INFO:tensorflow:global_step/sec: 34.9663
# INFO:tensorflow:loss = 3981050.8, step = 97700 (2.860 sec)
# INFO:tensorflow:global_step/sec: 35.289
# INFO:tensorflow:loss = 1930065.8, step = 97800 (2.834 sec)
# INFO:tensorflow:global_step/sec: 35.2523
# INFO:tensorflow:loss = 98002.88, step = 97900 (2.836 sec)
# INFO:tensorflow:global_step/sec: 34.3045
# INFO:tensorflow:loss = 2045673.6, step = 98000 (2.915 sec)
# INFO:tensorflow:global_step/sec: 28.6207
# INFO:tensorflow:loss = 20004.172, step = 98100 (3.494 sec)
# INFO:tensorflow:global_step/sec: 32.2636
# INFO:tensorflow:loss = 18412.807, step = 98200 (3.099 sec)
# INFO:tensorflow:global_step/sec: 35.665
# INFO:tensorflow:loss = 7766.737, step = 98300 (2.804 sec)
# INFO:tensorflow:global_step/sec: 35.2516
# INFO:tensorflow:loss = 15451.837, step = 98400 (2.837 sec)
# INFO:tensorflow:global_step/sec: 35.6918
# INFO:tensorflow:loss = 12639.608, step = 98500 (2.801 sec)
# INFO:tensorflow:global_step/sec: 35.3641
# INFO:tensorflow:loss = 6915.615, step = 98600 (2.828 sec)
# INFO:tensorflow:global_step/sec: 35.2648
# INFO:tensorflow:loss = 7391.843, step = 98700 (2.838 sec)
# INFO:tensorflow:global_step/sec: 35.5148
# INFO:tensorflow:loss = 9247.954, step = 98800 (2.814 sec)
# INFO:tensorflow:global_step/sec: 35.2868
# INFO:tensorflow:loss = 16195.891, step = 98900 (2.834 sec)
# INFO:tensorflow:global_step/sec: 35.3656
# INFO:tensorflow:loss = 18749.324, step = 99000 (2.827 sec)
# INFO:tensorflow:global_step/sec: 35.4546
# INFO:tensorflow:loss = 10752.706, step = 99100 (2.821 sec)
# INFO:tensorflow:global_step/sec: 35.5097
# INFO:tensorflow:loss = 12104.283, step = 99200 (2.818 sec)
# INFO:tensorflow:global_step/sec: 35.6297
# INFO:tensorflow:loss = 11351.739, step = 99300 (2.805 sec)
# INFO:tensorflow:global_step/sec: 35.5574
# INFO:tensorflow:loss = 8791.668, step = 99400 (2.814 sec)
# INFO:tensorflow:global_step/sec: 35.3651
# INFO:tensorflow:loss = 8184.68, step = 99500 (2.826 sec)
# INFO:tensorflow:global_step/sec: 35.2432
# INFO:tensorflow:loss = 2015999.2, step = 99600 (2.838 sec)
# INFO:tensorflow:global_step/sec: 35.4966
# INFO:tensorflow:loss = 9176.719, step = 99700 (2.817 sec)
# INFO:tensorflow:global_step/sec: 35.2743
# INFO:tensorflow:loss = 10290.482, step = 99800 (2.835 sec)
# INFO:tensorflow:global_step/sec: 35.5681
# INFO:tensorflow:loss = 17268.682, step = 99900 (2.812 sec)
# INFO:tensorflow:Saving checkpoints for 100000 into gs://edml/ai-platform/models/edml_trainer_20200421_110923/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-04-21T12:07:28Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from gs://edml/ai-platform/models/edml_trainer_20200421_110923/model.ckpt-100000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/3]
# INFO:tensorflow:Evaluation [2/3]
# INFO:tensorflow:Evaluation [3/3]
# INFO:tensorflow:Finished evaluation at 2020-04-21-12:07:44
# INFO:tensorflow:Saving dict for global step 100000: average_loss = 4553.305, global_step = 100000, label/mean = 18.21163, loss = 149202700.0, prediction/mean = 9.8668375, rmse = 67.47818
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 100000: gs://edml/ai-platform/models/edml_trainer_20200421_110923/model.ckpt-100000
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['predict']
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Signatures EXCLUDED from export because they cannot be be served via TensorFlow Serving APIs:
# INFO:tensorflow:'serving_default' : Regression input must be a single string Tensor; got {'dayofweek': <tf.Tensor 'dayofweek:0' shape=(?,) dtype=int64>, 'hourofday': <tf.Tensor 'hourofday:0' shape=(?,) dtype=int64>, 'weekofyear': <tf.Tensor 'weekofyear:0' shape=(?,) dtype=int64>, 'pickup_zone_name': <tf.Tensor 'pickup_zone_name:0' shape=(?,) dtype=string>, 'dropoff_zone_name': <tf.Tensor 'dropoff_zone_name:0' shape=(?,) dtype=string>, 'passenger_count': <tf.Tensor 'passenger_count:0' shape=(?,) dtype=int64>, 'distance': <tf.Tensor 'distance:0' shape=(?,) dtype=float64>, 'uuid': <tf.Tensor 'uuid:0' shape=(?,) dtype=string>}
# INFO:tensorflow:'regression' : Regression input must be a single string Tensor; got {'dayofweek': <tf.Tensor 'dayofweek:0' shape=(?,) dtype=int64>, 'hourofday': <tf.Tensor 'hourofday:0' shape=(?,) dtype=int64>, 'weekofyear': <tf.Tensor 'weekofyear:0' shape=(?,) dtype=int64>, 'pickup_zone_name': <tf.Tensor 'pickup_zone_name:0' shape=(?,) dtype=string>, 'dropoff_zone_name': <tf.Tensor 'dropoff_zone_name:0' shape=(?,) dtype=string>, 'passenger_count': <tf.Tensor 'passenger_count:0' shape=(?,) dtype=int64>, 'distance': <tf.Tensor 'distance:0' shape=(?,) dtype=float64>, 'uuid': <tf.Tensor 'uuid:0' shape=(?,) dtype=string>}
# WARNING:tensorflow:Export includes no default signature!
# INFO:tensorflow:Restoring parameters from gs://edml/ai-platform/models/edml_trainer_20200421_110923/model.ckpt-100000
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: gs://edml/ai-platform/models/edml_trainer_20200421_110923/export/exporter/temp-b'1587470867'/saved_model.pb
# INFO:tensorflow:Loss for final step: 8329.212.
# ({'average_loss': 4553.305,
#   'label/mean': 18.21163,
#   'loss': 149202700.0,
#   'prediction/mean': 9.8668375,
#   'rmse': 67.47818,
#   'global_step': 100000},
#  [b'gs://edml/ai-platform/models/edml_trainer_20200421_110923/export/exporter/1587470867'])

# %%
# ({'average_loss': 4725.116,
#   'label/mean': 18.190115,
#   'loss': 154832600.0,
#   'prediction/mean': 0.98749757,
#   'rmse': 68.73948,
#   'global_step': 1000},
#  [b'gs://edml/ai-platform/models/edml_trainer_20200421_103536/export/exporter/1587465469'])
