# %%
import tensorflow as tf
import numpy as np
from tensorflow_io.bigquery import BigQueryClient
import datetime
print(tf.__version__)
# Out:
# 1.15.2-dlenv_tfe

# %%
import tensorflow_io

# %%
tensorflow_io.__version__
# Out:
# '0.8.1'

# %% [markdown]
# ## Read data

# %%
PROJECT_ID = "event-driven-ml"
DATASET_GCP_PROJECT_ID = "event-driven-ml"
DATASET_ID = "edml_nyc_yellow_taxi_us"
TABLE_ID = "gis_feat_eng"

# %%
INPUT_COLUMNS = ["uuid", "dayofweek", "hourofday", "weekofyear", "pickup_zone_name", "dropoff_zone_name", "passenger_count", "distance", "trip_duration"]
LABEL_COLUMN = "trip_duration"
KEY_COLUMN = "uuid"

# Set default values for each CSV column
DEFAULTS = [['no_key'], [1], [0], [54], [""], [""], [1], [0], []]

NEMBEDS = 5

# %%
VOCABULARY = [
    'Allerton/Pelham Gardens', 'Alphabet City', 'Arden Heights', 'Arrochar/Fort Wadsworth', 
    'Astoria', 'Astoria Park', 'Auburndale', 'Baisley Park', 'Bath Beach', 'Battery Park',
    'Battery Park City', 'Bay Ridge', 'Bay Terrace/Fort Totten', 'Bayside', 'Bedford', 
    'Bedford Park', 'Bellerose', 'Belmont', 'Bensonhurst East', 'Bensonhurst West',
    'Bloomfield/Emerson Hill', 'Bloomingdale', 'Boerum Hill', 'Borough Park', 
    'Breezy Point/Fort Tilden/Riis Beach', 'Briarwood/Jamaica Hills', 'Brighton Beach',
    'Broad Channel', 'Bronx Park', 'Bronxdale', 'Brooklyn Heights', 'Brooklyn Navy Yard', 
    'Brownsville', 'Bushwick North', 'Bushwick South', 'Cambria Heights', 'Canarsie', 'Carroll Gardens',
    'Central Harlem', 'Central Harlem North', 'Central Park', 'Charleston/Tottenville', 'Chinatown',
    'City Island', 'Claremont/Bathgate', 'Clinton East', 'Clinton Hill', 'Clinton West', 'Co-Op City',
    'Cobble Hill', 'College Point', 'Columbia Street', 'Coney Island', 'Corona', 'Country Club', 'Crotona Park',
    'Crotona Park East', 'Crown Heights North', 'Crown Heights South', 'Cypress Hills', 'DUMBO/Vinegar Hill',
    'Douglaston', 'Downtown Brooklyn/MetroTech', 'Dyker Heights', 'East Chelsea', 'East Concourse/Concourse Village',
    'East Elmhurst', 'East Flatbush/Farragut', 'East Flatbush/Remsen Village', 'East Flushing', 'East Harlem North',
    'East Harlem South', 'East New York', 'East New York/Pennsylvania Avenue', 'East Tremont', 'East Village',
    'East Williamsburg', 'Eastchester', 'Elmhurst', 'Elmhurst/Maspeth', "Eltingville/Annadale/Prince's Bay", 'Erasmus',
    'Far Rockaway', 'Financial District North', 'Financial District South', 'Flatbush/Ditmas Park', 'Flatiron',
    'Flatlands', 'Flushing', 'Flushing Meadows-Corona Park', 'Fordham South', 'Forest Hills',
    'Forest Park/Highland Park', 'Fort Greene', 'Fresh Meadows', 'Freshkills Park', 'Garment District', 'Glen Oaks',
    'Glendale', 'Gowanus', 'Gramercy', 'Gravesend', 'Great Kills', 'Great Kills Park', 'Green-Wood Cemetery',
    'Greenpoint', 'Greenwich Village North', 'Greenwich Village South', 'Grymes Hill/Clifton', 'Hamilton Heights',
    'Hammels/Arverne', 'Heartland Village/Todt Hill', 'Highbridge', 'Highbridge Park', 'Hillcrest/Pomonok', 'Hollis',
    'Homecrest', 'Howard Beach', 'Hudson Sq', 'Hunts Point', 'Inwood', 'Inwood Hill Park', 'JFK Airport',
    'Jackson Heights', 'Jamaica', 'Jamaica Bay', 'Jamaica Estates', 'Kensington', 'Kew Gardens', 'Kew Gardens Hills',
    'Kingsbridge Heights', 'Kips Bay', 'LaGuardia Airport', 'Laurelton', 'Lenox Hill East', 'Lenox Hill West',
    'Lincoln Square East', 'Lincoln Square West', 'Little Italy/NoLiTa', 'Long Island City/Hunters Point',
    'Long Island City/Queens Plaza', 'Longwood', 'Lower East Side', 'Madison', 'Manhattan Beach', 'Manhattan Valley',
    'Manhattanville', 'Marble Hill', 'Marine Park/Floyd Bennett Field', 'Marine Park/Mill Basin', 'Mariners Harbor',
    'Maspeth', 'Meatpacking/West Village West', 'Melrose South', 'Middle Village', 'Midtown Center', 'Midtown East',
    'Midtown North', 'Midtown South', 'Midwood', 'Morningside Heights', 'Morrisania/Melrose', 'Mott Haven/Port Morris',
    'Mount Hope', 'Murray Hill', 'Murray Hill-Queens', 'New Dorp/Midland Beach', 'Newark Airport', 'North Corona',
    'Norwood', 'Oakland Gardens', 'Oakwood', 'Ocean Hill', 'Ocean Parkway South', 'Old Astoria', 'Ozone Park',
    'Park Slope', 'Parkchester', 'Pelham Bay', 'Pelham Bay Park', 'Pelham Parkway', 'Penn Station/Madison Sq West',
    'Port Richmond', 'Prospect Heights', 'Prospect Park', 'Prospect-Lefferts Gardens', 'Queens Village',
    'Queensboro Hill', 'Queensbridge/Ravenswood', 'Randalls Island', 'Red Hook', 'Rego Park', 'Richmond Hill',
    'Ridgewood', 'Rikers Island', 'Riverdale/North Riverdale/Fieldston', 'Rockaway Park', 'Roosevelt Island', 'Rosedale',
    'Rossville/Woodrow', 'Saint Albans', 'Saint George/New Brighton', 'Saint Michaels Cemetery/Woodside',
    'Schuylerville/Edgewater Park', 'Seaport', 'Sheepshead Bay', 'SoHo', 'Soundview/Bruckner', 'Soundview/Castle Hill',
    'South Beach/Dongan Hills', 'South Jamaica', 'South Ozone Park', 'South Williamsburg', 'Springfield Gardens North',
    'Springfield Gardens South', 'Spuyten Duyvil/Kingsbridge', 'Stapleton', 'Starrett City', 'Steinway',
    'Stuy Town/Peter Cooper Village', 'Stuyvesant Heights', 'Sunnyside', 'Sunset Park East', 'Sunset Park West',
    'Sutton Place/Turtle Bay North', 'Times Sq/Theatre District', 'TriBeCa/Civic Center', 'Two Bridges/Seward Park',
    'UN/Turtle Bay South', 'Union Sq', 'University Heights/Morris Heights', 'Upper East Side North',
    'Upper East Side South', 'Upper West Side North', 'Upper West Side South', 'Van Cortlandt Park',
    'Van Cortlandt Village', 'Van Nest/Morris Park', 'Washington Heights North', 'Washington Heights South',
    'West Brighton', 'West Chelsea/Hudson Yards', 'West Concourse', 'West Farms/Bronx River', 'West Village',
    'Westchester Village/Unionport', 'Westerleigh', 'Whitestone', 'Willets Point', 'Williamsbridge/Olinville',
    'Williamsburg (North Side)', 'Williamsburg (South Side)', 'Windsor Terrace', 'Woodhaven', 'Woodlawn/Wakefield',
    'Woodside', 'World Trade Center', 'Yorkville East', 'Yorkville West'
]

_CATEGORICAL_STR_VOCAB = {
    "pickup_zone_name": VOCABULARY,
    "dropoff_zone_name": VOCABULARY
}

_CATEGORICAL_NUM_BUCKETS = {
    "dayofweek": 7,
    "hourofday": 24,
    "weekofyear": 53
}

# %%
# Create an input function reading a file using the Dataset API
# Then provide the results to the Estimator API
def read_dataset(suffix, mode, batch_size):
    def _input_fn():
        client = BigQueryClient()
        read_session = client.read_session(
            parent="projects/" + PROJECT_ID,
            project_id=DATASET_GCP_PROJECT_ID,
            table_id="{}_{}".format(TABLE_ID, suffix), 
            dataset_id=DATASET_ID,
            selected_fields=INPUT_COLUMNS,
            output_types=[tf.string, tf.int64, tf.int64, tf.int64, tf.string, tf.string, tf.int64, tf.float64, tf.int64],
            requested_streams=10
        )
        
        def decode_row(records):
            features = records
            label = tf.cast(features.pop(LABEL_COLUMN), tf.float32)
            return features, label
        
        dataset = read_session.parallel_read_rows(sloppy=True).map(decode_row)

        if mode == tf.estimator.ModeKeys.TRAIN:
            num_epochs = None  # indefinitely
            dataset = dataset.shuffle(buffer_size=1000*batch_size, seed=1234)
        else:
            num_epochs = 1  # end-of-input after this

        dataset = dataset.repeat(num_epochs).batch(batch_size)
        return dataset
    return _input_fn

# %% [markdown]
# ## Feature engineering

# %%
def get_wide_deep():
    
    # One hot encode categorical features
    fc_dayofweek = tf.compat.v1.feature_column.categorical_column_with_identity(key="dayofweek",
                                                                                num_buckets=_CATEGORICAL_NUM_BUCKETS["dayofweek"])
    
    fc_hourofday = tf.compat.v1.feature_column.categorical_column_with_identity(key="hourofday",
                                                                                num_buckets=_CATEGORICAL_NUM_BUCKETS["hourofday"])
    
    fc_weekofyear = tf.compat.v1.feature_column.categorical_column_with_identity(key="weekofyear",
                                                                                 num_buckets=_CATEGORICAL_NUM_BUCKETS["weekofyear"])
    
    fc_pickuploc = tf.compat.v1.feature_column.categorical_column_with_vocabulary_list(key="pickup_zone_name",
                                                                                vocabulary_list=_CATEGORICAL_STR_VOCAB["pickup_zone_name"])
    
    fc_dropoffloc = tf.compat.v1.feature_column.categorical_column_with_vocabulary_list(key="dropoff_zone_name",
                                                                            vocabulary_list=_CATEGORICAL_STR_VOCAB["pickup_zone_name"])
    
    # Cross features to get combination of day and hour and pickup-dropoff locations
    fc_crossed_day_hr = tf.feature_column.crossed_column(keys = [fc_dayofweek, fc_hourofday], hash_bucket_size = 24*7)
    fc_crossed_pd_pair = tf.feature_column.crossed_column(keys = [fc_pickuploc, fc_dropoffloc], hash_bucket_size = 259*260)
    
    wide = [        
        # Sparse columns
        fc_crossed_day_hr, fc_crossed_pd_pair, 
        fc_dayofweek, fc_hourofday, fc_weekofyear, fc_pickuploc, fc_dropoffloc
    ]
    
    # mettre dans util
    def normalize_distance(col):
        mean = 3387.0
        std = 3891.02
        return (col - mean)/std
    
#     def normalize_passanger_cnt(col):
#         mean = 1.62
#         std = 1.26
#         return (col - mean)/std
    
    # Numerical column passanger_count
    fn_passenger_count = tf.compat.v1.feature_column.numeric_column(key="passenger_count")#, normalizer_fn=normalize_passanger_cnt)
    fn_distance = tf.compat.v1.feature_column.numeric_column(key="distance", normalizer_fn=normalize_distance)
    
    # Embedding_column to "group" together ...
    fc_embed_dayofweek = tf.compat.v1.feature_column.embedding_column(categorical_column=fc_dayofweek, dimension=NEMBEDS)#, max_norm=1)
    fc_embed_hourofday = tf.compat.v1.feature_column.embedding_column(categorical_column=fc_hourofday, dimension=NEMBEDS)#, max_norm=1)
    fc_embed_weekofyear = tf.compat.v1.feature_column.embedding_column(categorical_column=fc_weekofyear, dimension=NEMBEDS)#, max_norm=1)
    fc_embed_pickuploc = tf.compat.v1.feature_column.embedding_column(categorical_column=fc_pickuploc, dimension=NEMBEDS)#, max_norm=1)
    fc_embed_dropoffloc = tf.compat.v1.feature_column.embedding_column(categorical_column=fc_dropoffloc, dimension=NEMBEDS)#, max_norm=1)
    
    deep = [
        fn_passenger_count,
        fn_distance,
        fc_embed_dayofweek,
        fc_embed_hourofday,
        fc_embed_weekofyear,
        fc_embed_pickuploc,
        fc_embed_dropoffloc,
    ]
    
    return wide, deep

# %% [markdown]
# ### Serving input receiver function

# %%
def serving_input_receiver_fn():
    receiver_tensors = {
        'dayofweek': tf.compat.v1.placeholder(dtype=tf.int64, shape=[None], name="dayofweek"),
        'hourofday': tf.compat.v1.placeholder(dtype=tf.int64, shape=[None], name="hourofday"),
        'weekofyear': tf.compat.v1.placeholder(dtype=tf.int64, shape=[None], name="weekofyear"),
        'pickup_zone_name': tf.compat.v1.placeholder(dtype=tf.string, shape=[None], name="pickup_zone_name"),
        'dropoff_zone_name': tf.compat.v1.placeholder(dtype=tf.string, shape=[None], name="dropoff_zone_name"),
        'passenger_count': tf.compat.v1.placeholder(dtype=tf.int64, shape=[None], name="passenger_count"),
        'distance': tf.compat.v1.placeholder(dtype=tf.float64, shape=[None], name="distance"),
        KEY_COLUMN: tf.compat.v1.placeholder_with_default(tf.constant(['no_key']), [None], name="uuid")
    }
    
    features = {
        key: tf.expand_dims(tensor, -1) for key, tensor in receiver_tensors.items()
    }
        
    return tf.estimator.export.ServingInputReceiver(features=features, receiver_tensors=receiver_tensors)

# %% [markdown]
# ## Build and train model

# %%
def my_estimator(output_dir, throttle_secs, nnsize, batch_size, train_steps, eval_steps, eval_delay_secs):
    
    run_config = tf.estimator.RunConfig(save_checkpoints_secs=throttle_secs,
                                        tf_random_seed=2810,
                                        keep_checkpoint_max=3)
    
    # Add custom evaluation metric
    def my_rmse(labels, predictions):
        pred_values = tf.squeeze(input=predictions["predictions"], axis=-1)
        return {"rmse": tf.compat.v1.metrics.root_mean_squared_error(labels=labels, predictions=pred_values)}
    
    # Feature engineering
    wide, deep = get_wide_deep()
    
    estimator = tf.estimator.DNNLinearCombinedRegressor(
        model_dir=output_dir,
        linear_feature_columns=wide,
        dnn_feature_columns=deep,
        dnn_hidden_units=nnsize,
#         dnn_activation_fn=tf.nn.leaky_relu(alpha=0.2),
        batch_norm=True,
        dnn_dropout=0.2,
        config=run_config)
    
    estimator = tf.contrib.estimator.add_metrics(estimator=estimator, metric_fn=my_rmse)
    
    train_spec = tf.estimator.TrainSpec(
        input_fn=read_dataset('train', tf.estimator.ModeKeys.TRAIN, batch_size),
        max_steps=train_steps)
    
    exporter = tf.estimator.LatestExporter('exporter', serving_input_receiver_fn=serving_input_receiver_fn)
    
    eval_spec = tf.estimator.EvalSpec(
        input_fn=read_dataset('test', tf.estimator.ModeKeys.EVAL, 2**15),
        steps=eval_steps,
        start_delay_secs=eval_delay_secs,  # start evaluating after N seconds
        throttle_secs=throttle_secs,  # evaluate every N seconds
        exporters=exporter)
    
    return estimator, train_spec, eval_spec

# %% [markdown]
# ### Train model

# %%
# Parameters
BUCKET = "edml"
OUTDIR = "gs://{}/ai-platform/models/edml_trainer_{}".format(BUCKET, datetime.datetime.now().strftime("%Y%m%d_%H%M%S"))
THROTTLE_SECS = 300
NNSIZE = [20, 10, 5]
BATCH_SIZE = 128
TRAIN_STEPS = 100000 #5M per fare 3 apochs con batch_size 128 (input size 217M)
EVAL_STEPS = 3
EVAL_DECAY_SECS = 10

# %%
# %%bash
# # gsutil rm gs://bucket/subdir/** will remove all objects under gs://bucket/subdir or any of its subdirectories.
# gsutil rm gs://edml/data/taxi-trips/model_test/** # start fresh each time

# %%
tf.compat.v1.summary.FileWriterCache.clear() # ensure filewriter cache is clear for TensorBoard events file
tf.compat.v1.logging.set_verbosity(v = tf.logging.INFO) # so loss is printed during training

# %%
estimator, train_spec, eval_spec = my_estimator(output_dir=OUTDIR, throttle_secs=THROTTLE_SECS, nnsize=NNSIZE, batch_size=BATCH_SIZE, train_steps=TRAIN_STEPS,
                                                eval_steps=EVAL_STEPS, eval_delay_secs=EVAL_DECAY_SECS)
# Out:
# INFO:tensorflow:Using config: {'_model_dir': 'gs://edml/ai-platform/models/edml_trainer_20200425_221104', '_tf_random_seed': 2810, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 300, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 3, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7ff47884fb10>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# INFO:tensorflow:Using config: {'_model_dir': 'gs://edml/ai-platform/models/edml_trainer_20200425_221104', '_tf_random_seed': 2810, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 300, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 3, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7ff47884fd10>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %%
tf.estimator.train_and_evaluate(estimator, train_spec, eval_spec)
# Out:
# INFO:tensorflow:Not using Distribute Coordinator.
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps None or save_checkpoints_secs 300.
# WARNING:tensorflow:From /opt/conda/lib/python3.7/site-packages/tensorflow_core/python/training/training_util.py:236: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# WARNING:tensorflow:From /opt/conda/lib/python3.7/site-packages/tensorflow_io/bigquery/python/ops/bigquery_api.py:214: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.experimental.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.experimental_determinstic`.
# WARNING:tensorflow:From /opt/conda/lib/python3.7/site-packages/tensorflow_core/python/data/util/random_seed.py:58: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:From /opt/conda/lib/python3.7/site-packages/tensorflow_core/python/feature_column/feature_column_v2.py:3079: IdentityCategoricalColumn._num_buckets (from tensorflow.python.feature_column.feature_column_v2) is deprecated and will be removed in a future version.
# Instructions for updating:
# The old _FeatureColumn APIs are being deprecated. Please use the new FeatureColumn APIs instead.
# WARNING:tensorflow:From /opt/conda/lib/python3.7/site-packages/tensorflow_core/python/feature_column/feature_column_v2.py:305: Layer.add_variable (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.add_weight` method instead.
# WARNING:tensorflow:From /opt/conda/lib/python3.7/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /opt/conda/lib/python3.7/site-packages/tensorflow_core/python/feature_column/feature_column_v2.py:3079: VocabularyListCategoricalColumn._num_buckets (from tensorflow.python.feature_column.feature_column_v2) is deprecated and will be removed in a future version.
# Instructions for updating:
# The old _FeatureColumn APIs are being deprecated. Please use the new FeatureColumn APIs instead.
# WARNING:tensorflow:From /opt/conda/lib/python3.7/site-packages/tensorflow_estimator/python/estimator/canned/linear.py:308: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# WARNING:tensorflow:From /opt/conda/lib/python3.7/site-packages/tensorflow_core/python/training/adagrad.py:76: calling Constant.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into gs://edml/ai-platform/models/edml_trainer_20200425_221104/model.ckpt.
# INFO:tensorflow:loss = 41570.67, step = 0
# INFO:tensorflow:global_step/sec: 25.9425
# INFO:tensorflow:loss = 1960882.8, step = 100 (3.856 sec)
# INFO:tensorflow:global_step/sec: 32.4035
# INFO:tensorflow:loss = 42922.4, step = 200 (3.086 sec)
# INFO:tensorflow:global_step/sec: 33.0538
# INFO:tensorflow:loss = 44457.68, step = 300 (3.026 sec)
# INFO:tensorflow:global_step/sec: 32.3613
# INFO:tensorflow:loss = 54788.992, step = 400 (3.090 sec)
# INFO:tensorflow:global_step/sec: 32.7669
# INFO:tensorflow:loss = 32428.242, step = 500 (3.052 sec)
# INFO:tensorflow:global_step/sec: 32.7569
# INFO:tensorflow:loss = 354885.8, step = 600 (3.053 sec)
# INFO:tensorflow:global_step/sec: 32.5914
# INFO:tensorflow:loss = 59496.016, step = 700 (3.068 sec)
# INFO:tensorflow:global_step/sec: 33.0494
# INFO:tensorflow:loss = 4049356.8, step = 800 (3.026 sec)
# INFO:tensorflow:global_step/sec: 32.8901
# INFO:tensorflow:loss = 40815.992, step = 900 (3.040 sec)
# INFO:tensorflow:global_step/sec: 32.6895
# INFO:tensorflow:loss = 34514.75, step = 1000 (3.059 sec)
# INFO:tensorflow:global_step/sec: 32.7694
# INFO:tensorflow:loss = 45050.426, step = 1100 (3.051 sec)
# INFO:tensorflow:global_step/sec: 32.4538
# INFO:tensorflow:loss = 36852.766, step = 1200 (3.081 sec)
# INFO:tensorflow:global_step/sec: 33.0282
# INFO:tensorflow:loss = 2068535.0, step = 1300 (3.028 sec)
# INFO:tensorflow:global_step/sec: 32.7115
# INFO:tensorflow:loss = 38127.46, step = 1400 (3.057 sec)
# INFO:tensorflow:global_step/sec: 32.2444
# INFO:tensorflow:loss = 47351.188, step = 1500 (3.101 sec)
# INFO:tensorflow:global_step/sec: 32.6932
# INFO:tensorflow:loss = 41093.36, step = 1600 (3.059 sec)
# INFO:tensorflow:global_step/sec: 32.731
# INFO:tensorflow:loss = 42508.72, step = 1700 (3.055 sec)
# INFO:tensorflow:global_step/sec: 32.7247
# INFO:tensorflow:loss = 28362.648, step = 1800 (3.056 sec)
# INFO:tensorflow:global_step/sec: 32.6055
# INFO:tensorflow:loss = 27539.193, step = 1900 (3.067 sec)
# INFO:tensorflow:global_step/sec: 32.8448
# INFO:tensorflow:loss = 22648.352, step = 2000 (3.044 sec)
# INFO:tensorflow:global_step/sec: 31.9047
# INFO:tensorflow:loss = 27235.754, step = 2100 (3.134 sec)
# INFO:tensorflow:global_step/sec: 32.6111
# INFO:tensorflow:loss = 2106513.8, step = 2200 (3.066 sec)
# INFO:tensorflow:global_step/sec: 32.2754
# INFO:tensorflow:loss = 27842.656, step = 2300 (3.098 sec)
# INFO:tensorflow:global_step/sec: 32.521
# INFO:tensorflow:loss = 32385.021, step = 2400 (3.075 sec)
# INFO:tensorflow:global_step/sec: 32.5261
# INFO:tensorflow:loss = 2082764.8, step = 2500 (3.074 sec)
# INFO:tensorflow:global_step/sec: 32.1609
# INFO:tensorflow:loss = 27021.646, step = 2600 (4.203 sec)
# INFO:tensorflow:global_step/sec: 24.1653
# INFO:tensorflow:loss = 24345.258, step = 2700 (3.045 sec)
# INFO:tensorflow:global_step/sec: 32.5856
# INFO:tensorflow:loss = 29557.229, step = 2800 (3.069 sec)
# INFO:tensorflow:global_step/sec: 32.583
# INFO:tensorflow:loss = 24042.84, step = 2900 (3.070 sec)
# INFO:tensorflow:global_step/sec: 32.4102
# INFO:tensorflow:loss = 1997714.8, step = 3000 (3.085 sec)
# INFO:tensorflow:global_step/sec: 32.5471
# INFO:tensorflow:loss = 30425.688, step = 3100 (3.072 sec)
# INFO:tensorflow:global_step/sec: 32.2009
# INFO:tensorflow:loss = 24195.799, step = 3200 (3.106 sec)
# INFO:tensorflow:global_step/sec: 32.5132
# INFO:tensorflow:loss = 26939.973, step = 3300 (3.076 sec)
# INFO:tensorflow:global_step/sec: 32.6369
# INFO:tensorflow:loss = 2033303.1, step = 3400 (3.064 sec)
# INFO:tensorflow:global_step/sec: 32.4948
# INFO:tensorflow:loss = 31275.691, step = 3500 (3.077 sec)
# INFO:tensorflow:global_step/sec: 32.385
# INFO:tensorflow:loss = 25681.352, step = 3600 (3.088 sec)
# INFO:tensorflow:global_step/sec: 32.4701
# INFO:tensorflow:loss = 28876.781, step = 3700 (3.080 sec)
# INFO:tensorflow:global_step/sec: 32.4527
# INFO:tensorflow:loss = 41467.758, step = 3800 (3.084 sec)
# INFO:tensorflow:global_step/sec: 32.4897
# INFO:tensorflow:loss = 38663.242, step = 3900 (3.076 sec)
# INFO:tensorflow:global_step/sec: 32.5697
# INFO:tensorflow:loss = 32600.027, step = 4000 (3.071 sec)
# INFO:tensorflow:global_step/sec: 32.5307
# INFO:tensorflow:loss = 19397.13, step = 4100 (3.075 sec)
# INFO:tensorflow:global_step/sec: 32.7567
# INFO:tensorflow:loss = 27170.889, step = 4200 (3.052 sec)
# INFO:tensorflow:global_step/sec: 32.7202
# INFO:tensorflow:loss = 34001.086, step = 4300 (3.056 sec)
# INFO:tensorflow:global_step/sec: 32.448
# INFO:tensorflow:loss = 2092969.1, step = 4400 (3.082 sec)
# INFO:tensorflow:global_step/sec: 32.4496
# INFO:tensorflow:loss = 30184.059, step = 4500 (3.081 sec)
# INFO:tensorflow:global_step/sec: 28.1478
# INFO:tensorflow:loss = 40339.586, step = 4600 (3.553 sec)
# INFO:tensorflow:global_step/sec: 27.7717
# INFO:tensorflow:loss = 32621.102, step = 4700 (3.601 sec)
# INFO:tensorflow:global_step/sec: 27.3928
# INFO:tensorflow:loss = 18520.434, step = 4800 (3.650 sec)
# INFO:tensorflow:global_step/sec: 32.7703
# INFO:tensorflow:loss = 33196.36, step = 4900 (3.052 sec)
# INFO:tensorflow:global_step/sec: 32.3983
# INFO:tensorflow:loss = 39719.71, step = 5000 (3.086 sec)
# INFO:tensorflow:global_step/sec: 32.9626
# INFO:tensorflow:loss = 27548.883, step = 5100 (3.034 sec)
# INFO:tensorflow:global_step/sec: 32.6572
# INFO:tensorflow:loss = 1985965.4, step = 5200 (3.062 sec)
# INFO:tensorflow:global_step/sec: 32.4311
# INFO:tensorflow:loss = 2028576.6, step = 5300 (3.083 sec)
# INFO:tensorflow:global_step/sec: 32.3294
# INFO:tensorflow:loss = 26306.762, step = 5400 (3.093 sec)
# INFO:tensorflow:global_step/sec: 32.8658
# INFO:tensorflow:loss = 2075352.6, step = 5500 (3.043 sec)
# INFO:tensorflow:global_step/sec: 32.5465
# INFO:tensorflow:loss = 20932.004, step = 5600 (3.072 sec)
# INFO:tensorflow:global_step/sec: 32.9669
# INFO:tensorflow:loss = 20665.379, step = 5700 (3.033 sec)
# INFO:tensorflow:global_step/sec: 32.1943
# INFO:tensorflow:loss = 2100350.8, step = 5800 (3.106 sec)
# INFO:tensorflow:global_step/sec: 32.2943
# INFO:tensorflow:loss = 36227.535, step = 5900 (3.097 sec)
# INFO:tensorflow:global_step/sec: 32.4001
# INFO:tensorflow:loss = 32124.705, step = 6000 (3.087 sec)
# INFO:tensorflow:global_step/sec: 32.7021
# INFO:tensorflow:loss = 2087874.6, step = 6100 (3.058 sec)
# INFO:tensorflow:global_step/sec: 32.4994
# INFO:tensorflow:loss = 26169.574, step = 6200 (3.078 sec)
# INFO:tensorflow:global_step/sec: 32.6385
# INFO:tensorflow:loss = 39156.94, step = 6300 (3.062 sec)
# INFO:tensorflow:global_step/sec: 32.4498
# INFO:tensorflow:loss = 19697.22, step = 6400 (3.082 sec)
# INFO:tensorflow:global_step/sec: 32.6363
# INFO:tensorflow:loss = 15434.07, step = 6500 (4.067 sec)
# INFO:tensorflow:global_step/sec: 24.4722
# INFO:tensorflow:loss = 30506.44, step = 6600 (3.084 sec)
# INFO:tensorflow:global_step/sec: 32.6638
# INFO:tensorflow:loss = 17076.115, step = 6700 (3.061 sec)
# INFO:tensorflow:global_step/sec: 32.1486
# INFO:tensorflow:loss = 29056.328, step = 6800 (3.111 sec)
# INFO:tensorflow:global_step/sec: 32.2642
# INFO:tensorflow:loss = 31832.383, step = 6900 (3.099 sec)
# INFO:tensorflow:global_step/sec: 32.666
# INFO:tensorflow:loss = 36294.023, step = 7000 (3.061 sec)
# INFO:tensorflow:global_step/sec: 32.4223
# INFO:tensorflow:loss = 32814.5, step = 7100 (3.085 sec)
# INFO:tensorflow:global_step/sec: 32.5884
# INFO:tensorflow:loss = 25537.957, step = 7200 (3.068 sec)
# INFO:tensorflow:global_step/sec: 32.3637
# INFO:tensorflow:loss = 25135.66, step = 7300 (3.092 sec)
# INFO:tensorflow:global_step/sec: 32.7047
# INFO:tensorflow:loss = 1790868.9, step = 7400 (3.055 sec)
# INFO:tensorflow:global_step/sec: 32.4944
# INFO:tensorflow:loss = 31901.787, step = 7500 (3.077 sec)
# INFO:tensorflow:global_step/sec: 32.2414
# INFO:tensorflow:loss = 2029706.5, step = 7600 (3.102 sec)
# INFO:tensorflow:global_step/sec: 32.1428
# INFO:tensorflow:loss = 24105.012, step = 7700 (3.111 sec)
# INFO:tensorflow:global_step/sec: 32.6096
# INFO:tensorflow:loss = 26925.29, step = 7800 (3.067 sec)
# INFO:tensorflow:global_step/sec: 32.7686
# INFO:tensorflow:loss = 29721.738, step = 7900 (3.052 sec)
# INFO:tensorflow:global_step/sec: 32.3843
# INFO:tensorflow:loss = 26342.002, step = 8000 (3.088 sec)
# INFO:tensorflow:global_step/sec: 32.7052
# INFO:tensorflow:loss = 25780.188, step = 8100 (3.057 sec)
# INFO:tensorflow:global_step/sec: 32.5917
# INFO:tensorflow:loss = 20365.7, step = 8200 (3.070 sec)
# INFO:tensorflow:global_step/sec: 32.7337
# INFO:tensorflow:loss = 4025535.8, step = 8300 (3.053 sec)
# INFO:tensorflow:global_step/sec: 32.5234
# INFO:tensorflow:loss = 33493.1, step = 8400 (3.075 sec)
# INFO:tensorflow:global_step/sec: 32.8855
# INFO:tensorflow:loss = 23390.732, step = 8500 (3.041 sec)
# INFO:tensorflow:global_step/sec: 32.6431
# INFO:tensorflow:loss = 25912.1, step = 8600 (3.063 sec)
# INFO:tensorflow:global_step/sec: 32.5533
# INFO:tensorflow:loss = 2091055.6, step = 8700 (3.072 sec)
# INFO:tensorflow:global_step/sec: 32.3757
# INFO:tensorflow:loss = 2025374.1, step = 8800 (3.089 sec)
# INFO:tensorflow:global_step/sec: 32.6753
# INFO:tensorflow:loss = 2080429.2, step = 8900 (3.061 sec)
# INFO:tensorflow:global_step/sec: 32.5189
# INFO:tensorflow:loss = 2066236.2, step = 9000 (3.075 sec)
# INFO:tensorflow:global_step/sec: 32.5458
# INFO:tensorflow:loss = 22073.23, step = 9100 (3.072 sec)
# INFO:tensorflow:Saving checkpoints for 9172 into gs://edml/ai-platform/models/edml_trainer_20200425_221104/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-04-25T22:17:02Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from gs://edml/ai-platform/models/edml_trainer_20200425_221104/model.ckpt-9172
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/3]
# INFO:tensorflow:Evaluation [2/3]
# INFO:tensorflow:Evaluation [3/3]
# INFO:tensorflow:Finished evaluation at 2020-04-25-22:17:19
# INFO:tensorflow:Saving dict for global step 9172: average_loss = 4583.774, global_step = 9172, label/mean = 18.12681, loss = 150201100.0, prediction/mean = 3.632088, rmse = 67.703575
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 9172: gs://edml/ai-platform/models/edml_trainer_20200425_221104/model.ckpt-9172
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# WARNING:tensorflow:From /opt/conda/lib/python3.7/site-packages/tensorflow_core/python/saved_model/signature_def_utils_impl.py:201: build_tensor_info (from tensorflow.python.saved_model.utils_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This function will only be available through the v1 compatibility library as tf.compat.v1.saved_model.utils.build_tensor_info or tf.compat.v1.saved_model.build_tensor_info.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['predict']
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Signatures EXCLUDED from export because they cannot be be served via TensorFlow Serving APIs:
# INFO:tensorflow:'serving_default' : Regression input must be a single string Tensor; got {'dayofweek': <tf.Tensor 'dayofweek:0' shape=(?,) dtype=int64>, 'hourofday': <tf.Tensor 'hourofday:0' shape=(?,) dtype=int64>, 'weekofyear': <tf.Tensor 'weekofyear:0' shape=(?,) dtype=int64>, 'pickup_zone_name': <tf.Tensor 'pickup_zone_name:0' shape=(?,) dtype=string>, 'dropoff_zone_name': <tf.Tensor 'dropoff_zone_name:0' shape=(?,) dtype=string>, 'passenger_count': <tf.Tensor 'passenger_count:0' shape=(?,) dtype=int64>, 'distance': <tf.Tensor 'distance:0' shape=(?,) dtype=float64>, 'uuid': <tf.Tensor 'uuid:0' shape=(?,) dtype=string>}
# INFO:tensorflow:'regression' : Regression input must be a single string Tensor; got {'dayofweek': <tf.Tensor 'dayofweek:0' shape=(?,) dtype=int64>, 'hourofday': <tf.Tensor 'hourofday:0' shape=(?,) dtype=int64>, 'weekofyear': <tf.Tensor 'weekofyear:0' shape=(?,) dtype=int64>, 'pickup_zone_name': <tf.Tensor 'pickup_zone_name:0' shape=(?,) dtype=string>, 'dropoff_zone_name': <tf.Tensor 'dropoff_zone_name:0' shape=(?,) dtype=string>, 'passenger_count': <tf.Tensor 'passenger_count:0' shape=(?,) dtype=int64>, 'distance': <tf.Tensor 'distance:0' shape=(?,) dtype=float64>, 'uuid': <tf.Tensor 'uuid:0' shape=(?,) dtype=string>}
# WARNING:tensorflow:Export includes no default signature!
# INFO:tensorflow:Restoring parameters from gs://edml/ai-platform/models/edml_trainer_20200425_221104/model.ckpt-9172
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: gs://edml/ai-platform/models/edml_trainer_20200425_221104/export/exporter/temp-b'1587853045'/saved_model.pb
# INFO:tensorflow:global_step/sec: 1.37024
# INFO:tensorflow:loss = 4099970.5, step = 9200 (73.963 sec)
# INFO:tensorflow:global_step/sec: 24.4647
# INFO:tensorflow:loss = 19870.168, step = 9300 (3.106 sec)
# INFO:tensorflow:global_step/sec: 32.4763
# INFO:tensorflow:loss = 34728.77, step = 9400 (3.077 sec)
# INFO:tensorflow:global_step/sec: 31.5161
# INFO:tensorflow:loss = 22680.738, step = 9500 (3.173 sec)
# INFO:tensorflow:global_step/sec: 32.255
# INFO:tensorflow:loss = 24068.73, step = 9600 (3.100 sec)
# INFO:tensorflow:global_step/sec: 32.7988
# INFO:tensorflow:loss = 23107.234, step = 9700 (3.049 sec)
# INFO:tensorflow:global_step/sec: 32.281
# INFO:tensorflow:loss = 2094421.9, step = 9800 (3.098 sec)
# INFO:tensorflow:global_step/sec: 32.6698
# INFO:tensorflow:loss = 26845.688, step = 9900 (3.061 sec)
# INFO:tensorflow:global_step/sec: 32.5578
# INFO:tensorflow:loss = 25648.664, step = 10000 (3.071 sec)
# INFO:tensorflow:global_step/sec: 32.5293
# INFO:tensorflow:loss = 31717.195, step = 10100 (3.074 sec)
# INFO:tensorflow:global_step/sec: 32.7328
# INFO:tensorflow:loss = 26881.848, step = 10200 (3.055 sec)
# INFO:tensorflow:global_step/sec: 32.6079
# INFO:tensorflow:loss = 18238.531, step = 10300 (3.067 sec)
# INFO:tensorflow:global_step/sec: 32.5124
# INFO:tensorflow:loss = 38078.887, step = 10400 (3.075 sec)
# INFO:tensorflow:global_step/sec: 32.4157
# INFO:tensorflow:loss = 28475.613, step = 10500 (3.085 sec)
# INFO:tensorflow:global_step/sec: 32.3772
# INFO:tensorflow:loss = 21344.076, step = 10600 (3.088 sec)
# INFO:tensorflow:global_step/sec: 32.4111
# INFO:tensorflow:loss = 2073617.9, step = 10700 (3.085 sec)
# INFO:tensorflow:global_step/sec: 32.5057
# INFO:tensorflow:loss = 14504.887, step = 10800 (3.077 sec)
# INFO:tensorflow:global_step/sec: 32.3911
# INFO:tensorflow:loss = 2081182.1, step = 10900 (3.087 sec)
# INFO:tensorflow:global_step/sec: 32.1119
# INFO:tensorflow:loss = 35316.39, step = 11000 (3.114 sec)
# INFO:tensorflow:global_step/sec: 32.5968
# INFO:tensorflow:loss = 28880.352, step = 11100 (3.068 sec)
# INFO:tensorflow:global_step/sec: 32.4046
# INFO:tensorflow:loss = 20221.543, step = 11200 (3.086 sec)
# INFO:tensorflow:global_step/sec: 32.1398
# INFO:tensorflow:loss = 32639.297, step = 11300 (3.112 sec)
# INFO:tensorflow:global_step/sec: 32.2472
# INFO:tensorflow:loss = 17630.732, step = 11400 (3.101 sec)
# INFO:tensorflow:global_step/sec: 32.4205
# INFO:tensorflow:loss = 18439.29, step = 11500 (3.084 sec)
# INFO:tensorflow:global_step/sec: 32.6396
# INFO:tensorflow:loss = 19059.283, step = 11600 (3.064 sec)
# INFO:tensorflow:global_step/sec: 32.1561
# INFO:tensorflow:loss = 26062.379, step = 11700 (3.110 sec)
# INFO:tensorflow:global_step/sec: 32.5356
# INFO:tensorflow:loss = 24948.428, step = 11800 (3.073 sec)
# INFO:tensorflow:global_step/sec: 32.829
# INFO:tensorflow:loss = 21204.568, step = 11900 (3.046 sec)
# INFO:tensorflow:global_step/sec: 32.3002
# INFO:tensorflow:loss = 30316.986, step = 12000 (3.096 sec)
# INFO:tensorflow:global_step/sec: 32.1938
# INFO:tensorflow:loss = 20906.375, step = 12100 (3.106 sec)
# INFO:tensorflow:global_step/sec: 32.4727
# INFO:tensorflow:loss = 24012.156, step = 12200 (3.079 sec)
# INFO:tensorflow:global_step/sec: 28.7055
# INFO:tensorflow:loss = 34663.65, step = 12300 (3.484 sec)
# INFO:tensorflow:global_step/sec: 27.3895
# INFO:tensorflow:loss = 577159.0, step = 12400 (3.651 sec)
# INFO:tensorflow:global_step/sec: 27.5413
# INFO:tensorflow:loss = 2069264.5, step = 12500 (3.631 sec)
# INFO:tensorflow:global_step/sec: 31.8898
# INFO:tensorflow:loss = 35016.9, step = 12600 (3.136 sec)
# INFO:tensorflow:global_step/sec: 32.6193
# INFO:tensorflow:loss = 22436.486, step = 12700 (3.066 sec)
# INFO:tensorflow:global_step/sec: 32.6592
# INFO:tensorflow:loss = 24090.988, step = 12800 (3.062 sec)
# INFO:tensorflow:global_step/sec: 32.005
# INFO:tensorflow:loss = 23458.008, step = 12900 (3.124 sec)
# INFO:tensorflow:global_step/sec: 32.5461
# INFO:tensorflow:loss = 21230.275, step = 13000 (3.073 sec)
# INFO:tensorflow:global_step/sec: 32.5367
# INFO:tensorflow:loss = 28022.623, step = 13100 (4.411 sec)
# INFO:tensorflow:global_step/sec: 22.4666
# INFO:tensorflow:loss = 47024.51, step = 13200 (3.113 sec)
# INFO:tensorflow:global_step/sec: 32.3099
# INFO:tensorflow:loss = 32351.133, step = 13300 (3.095 sec)
# INFO:tensorflow:global_step/sec: 32.3471
# INFO:tensorflow:loss = 24265.578, step = 13400 (3.091 sec)
# INFO:tensorflow:global_step/sec: 32.7344
# INFO:tensorflow:loss = 22815.63, step = 13500 (3.055 sec)
# INFO:tensorflow:global_step/sec: 32.5929
# INFO:tensorflow:loss = 3931850.8, step = 13600 (3.068 sec)
# INFO:tensorflow:global_step/sec: 32.3684
# INFO:tensorflow:loss = 22648.686, step = 13700 (3.089 sec)
# INFO:tensorflow:global_step/sec: 32.5964
# INFO:tensorflow:loss = 34136.11, step = 13800 (3.068 sec)
# INFO:tensorflow:global_step/sec: 32.7144
# INFO:tensorflow:loss = 23323.596, step = 13900 (3.057 sec)
# INFO:tensorflow:global_step/sec: 32.2483
# INFO:tensorflow:loss = 28030.312, step = 14000 (3.101 sec)
# INFO:tensorflow:global_step/sec: 32.7751
# INFO:tensorflow:loss = 21264.156, step = 14100 (3.051 sec)
# INFO:tensorflow:global_step/sec: 32.8107
# INFO:tensorflow:loss = 26316.793, step = 14200 (3.048 sec)
# INFO:tensorflow:global_step/sec: 32.7538
# INFO:tensorflow:loss = 21406.025, step = 14300 (3.053 sec)
# INFO:tensorflow:global_step/sec: 32.5498
# INFO:tensorflow:loss = 16836.365, step = 14400 (3.072 sec)
# INFO:tensorflow:global_step/sec: 32.1741
# INFO:tensorflow:loss = 1979507.8, step = 14500 (3.108 sec)
# INFO:tensorflow:global_step/sec: 32.5593
# INFO:tensorflow:loss = 23477.748, step = 14600 (3.072 sec)
# INFO:tensorflow:global_step/sec: 32.2699
# INFO:tensorflow:loss = 27412.79, step = 14700 (3.099 sec)
# INFO:tensorflow:global_step/sec: 32.8584
# INFO:tensorflow:loss = 25540.562, step = 14800 (3.043 sec)
# INFO:tensorflow:global_step/sec: 32.4602
# INFO:tensorflow:loss = 20225.31, step = 14900 (3.081 sec)
# INFO:tensorflow:global_step/sec: 32.2554
# INFO:tensorflow:loss = 1962794.5, step = 15000 (3.100 sec)
# INFO:tensorflow:global_step/sec: 32.9736
# INFO:tensorflow:loss = 26358.98, step = 15100 (3.033 sec)
# INFO:tensorflow:global_step/sec: 32.1991
# INFO:tensorflow:loss = 1961784.1, step = 15200 (3.108 sec)
# INFO:tensorflow:global_step/sec: 33.1112
# INFO:tensorflow:loss = 2090526.9, step = 15300 (3.018 sec)
# INFO:tensorflow:global_step/sec: 32.561
# INFO:tensorflow:loss = 25213.574, step = 15400 (3.072 sec)
# INFO:tensorflow:global_step/sec: 32.8148
# INFO:tensorflow:loss = 32617.95, step = 15500 (3.047 sec)
# INFO:tensorflow:global_step/sec: 32.6829
# INFO:tensorflow:loss = 44066.004, step = 15600 (3.060 sec)
# INFO:tensorflow:global_step/sec: 32.5903
# INFO:tensorflow:loss = 1969449.0, step = 15700 (3.068 sec)
# INFO:tensorflow:global_step/sec: 32.7515
# INFO:tensorflow:loss = 18404.48, step = 15800 (3.053 sec)
# INFO:tensorflow:global_step/sec: 32.8466
# INFO:tensorflow:loss = 4128208.5, step = 15900 (3.045 sec)
# INFO:tensorflow:global_step/sec: 32.1445
# INFO:tensorflow:loss = 21488.547, step = 16000 (3.111 sec)
# INFO:tensorflow:global_step/sec: 32.1705
# INFO:tensorflow:loss = 16997.8, step = 16100 (3.108 sec)
# INFO:tensorflow:global_step/sec: 33.0304
# INFO:tensorflow:loss = 1840095.4, step = 16200 (3.027 sec)
# INFO:tensorflow:global_step/sec: 33.1184
# INFO:tensorflow:loss = 24653.074, step = 16300 (3.020 sec)
# INFO:tensorflow:global_step/sec: 32.5721
# INFO:tensorflow:loss = 1969368.6, step = 16400 (3.070 sec)
# INFO:tensorflow:global_step/sec: 32.5478
# INFO:tensorflow:loss = 19051.76, step = 16500 (3.072 sec)
# INFO:tensorflow:Saving checkpoints for 16522 into gs://edml/ai-platform/models/edml_trainer_20200425_221104/model.ckpt.
# INFO:tensorflow:Skip the current checkpoint eval due to throttle secs (300 secs).
# INFO:tensorflow:global_step/sec: 4.9106
# INFO:tensorflow:loss = 2018906.4, step = 16600 (20.364 sec)
# INFO:tensorflow:global_step/sec: 32.8731
# INFO:tensorflow:loss = 19945.146, step = 16700 (3.042 sec)
# INFO:tensorflow:global_step/sec: 32.846
# INFO:tensorflow:loss = 22172.629, step = 16800 (3.044 sec)
# INFO:tensorflow:global_step/sec: 33.0369
# INFO:tensorflow:loss = 32593.91, step = 16900 (3.029 sec)
# INFO:tensorflow:global_step/sec: 32.9465
# INFO:tensorflow:loss = 19850.89, step = 17000 (3.033 sec)
# INFO:tensorflow:global_step/sec: 32.85
# INFO:tensorflow:loss = 1938480.8, step = 17100 (3.044 sec)
# INFO:tensorflow:global_step/sec: 32.491
# INFO:tensorflow:loss = 25773.33, step = 17200 (3.078 sec)
# INFO:tensorflow:global_step/sec: 32.7498
# INFO:tensorflow:loss = 34323.242, step = 17300 (3.054 sec)
# INFO:tensorflow:global_step/sec: 32.803
# INFO:tensorflow:loss = 28341.957, step = 17400 (3.048 sec)
# INFO:tensorflow:global_step/sec: 32.4996
# INFO:tensorflow:loss = 22730.678, step = 17500 (3.077 sec)
# INFO:tensorflow:global_step/sec: 32.7076
# INFO:tensorflow:loss = 35724.848, step = 17600 (3.058 sec)
# INFO:tensorflow:global_step/sec: 32.6844
# INFO:tensorflow:loss = 19916.342, step = 17700 (3.060 sec)
# INFO:tensorflow:global_step/sec: 32.5545
# INFO:tensorflow:loss = 24006.615, step = 17800 (3.071 sec)
# INFO:tensorflow:global_step/sec: 32.3913
# INFO:tensorflow:loss = 2030450.4, step = 17900 (3.088 sec)
# INFO:tensorflow:global_step/sec: 32.9027
# INFO:tensorflow:loss = 2018859.1, step = 18000 (3.039 sec)
# INFO:tensorflow:global_step/sec: 32.5399
# INFO:tensorflow:loss = 2024167.1, step = 18100 (3.073 sec)
# INFO:tensorflow:global_step/sec: 32.4393
# INFO:tensorflow:loss = 32781.094, step = 18200 (3.083 sec)
# INFO:tensorflow:global_step/sec: 32.4774
# INFO:tensorflow:loss = 21479.129, step = 18300 (3.079 sec)
# INFO:tensorflow:global_step/sec: 32.4575
# INFO:tensorflow:loss = 25630.318, step = 18400 (3.081 sec)
# INFO:tensorflow:global_step/sec: 32.2356
# INFO:tensorflow:loss = 30199.934, step = 18500 (3.102 sec)
# INFO:tensorflow:global_step/sec: 32.6948
# INFO:tensorflow:loss = 16717.797, step = 18600 (3.059 sec)
# INFO:tensorflow:global_step/sec: 32.4973
# INFO:tensorflow:loss = 2073269.5, step = 18700 (3.079 sec)
# INFO:tensorflow:global_step/sec: 32.4295
# INFO:tensorflow:loss = 13754.297, step = 18800 (3.081 sec)
# INFO:tensorflow:global_step/sec: 32.8714
# INFO:tensorflow:loss = 19052.691, step = 18900 (3.042 sec)
# INFO:tensorflow:global_step/sec: 32.605
# INFO:tensorflow:loss = 2041750.6, step = 19000 (3.067 sec)
# INFO:tensorflow:global_step/sec: 32.1004
# INFO:tensorflow:loss = 18285.715, step = 19100 (3.115 sec)
# INFO:tensorflow:global_step/sec: 32.8006
# INFO:tensorflow:loss = 22598.201, step = 19200 (3.049 sec)
# INFO:tensorflow:global_step/sec: 33.009
# INFO:tensorflow:loss = 34424.785, step = 19300 (3.030 sec)
# INFO:tensorflow:global_step/sec: 32.4173
# INFO:tensorflow:loss = 12931.572, step = 19400 (3.085 sec)
# INFO:tensorflow:global_step/sec: 32.6044
# INFO:tensorflow:loss = 2082450.0, step = 19500 (3.067 sec)
# INFO:tensorflow:global_step/sec: 32.2926
# INFO:tensorflow:loss = 20649.787, step = 19600 (3.097 sec)
# INFO:tensorflow:global_step/sec: 32.7196
# INFO:tensorflow:loss = 2047834.4, step = 19700 (3.057 sec)
# INFO:tensorflow:global_step/sec: 32.8108
# INFO:tensorflow:loss = 16124.658, step = 19800 (3.048 sec)
# INFO:tensorflow:global_step/sec: 32.4756
# INFO:tensorflow:loss = 1981040.2, step = 19900 (3.079 sec)
# INFO:tensorflow:global_step/sec: 32.4462
# INFO:tensorflow:loss = 23343.328, step = 20000 (3.082 sec)
# INFO:tensorflow:global_step/sec: 32.4785
# INFO:tensorflow:loss = 2062981.8, step = 20100 (3.079 sec)
# INFO:tensorflow:global_step/sec: 33.1723
# INFO:tensorflow:loss = 2091282.9, step = 20200 (3.015 sec)
# INFO:tensorflow:global_step/sec: 32.5591
# INFO:tensorflow:loss = 19181.48, step = 20300 (3.071 sec)
# INFO:tensorflow:global_step/sec: 32.6031
# INFO:tensorflow:loss = 16801.979, step = 20400 (4.154 sec)
# INFO:tensorflow:global_step/sec: 23.9506
# INFO:tensorflow:loss = 25484.816, step = 20500 (3.089 sec)
# INFO:tensorflow:global_step/sec: 32.4257
# INFO:tensorflow:loss = 23240.09, step = 20600 (3.084 sec)
# INFO:tensorflow:global_step/sec: 32.5731
# INFO:tensorflow:loss = 13239.8125, step = 20700 (3.070 sec)
# INFO:tensorflow:global_step/sec: 32.0451
# INFO:tensorflow:loss = 2062475.0, step = 20800 (3.121 sec)
# INFO:tensorflow:global_step/sec: 32.166
# INFO:tensorflow:loss = 22263.637, step = 20900 (3.109 sec)
# INFO:tensorflow:global_step/sec: 32.2552
# INFO:tensorflow:loss = 21754.19, step = 21000 (3.100 sec)
# INFO:tensorflow:global_step/sec: 32.9897
# INFO:tensorflow:loss = 32755.416, step = 21100 (3.031 sec)
# INFO:tensorflow:global_step/sec: 32.4569
# INFO:tensorflow:loss = 21500.926, step = 21200 (3.081 sec)
# INFO:tensorflow:global_step/sec: 32.6034
# INFO:tensorflow:loss = 30344.55, step = 21300 (3.067 sec)
# INFO:tensorflow:global_step/sec: 32.8738
# INFO:tensorflow:loss = 2071983.9, step = 21400 (3.044 sec)
# INFO:tensorflow:global_step/sec: 32.6249
# INFO:tensorflow:loss = 16322.213, step = 21500 (3.063 sec)
# INFO:tensorflow:global_step/sec: 32.2451
# INFO:tensorflow:loss = 20704.973, step = 21600 (3.101 sec)
# INFO:tensorflow:global_step/sec: 30.4315
# INFO:tensorflow:loss = 2083442.0, step = 21700 (3.286 sec)
# INFO:tensorflow:global_step/sec: 27.1603
# INFO:tensorflow:loss = 26883.09, step = 21800 (3.682 sec)
# INFO:tensorflow:global_step/sec: 27.159
# INFO:tensorflow:loss = 21330.293, step = 21900 (3.682 sec)
# INFO:tensorflow:global_step/sec: 30.7444
# INFO:tensorflow:loss = 9202.003, step = 22000 (3.253 sec)
# INFO:tensorflow:global_step/sec: 32.571
# INFO:tensorflow:loss = 26751.68, step = 22100 (3.070 sec)
# INFO:tensorflow:global_step/sec: 32.6229
# INFO:tensorflow:loss = 15927.086, step = 22200 (3.065 sec)
# INFO:tensorflow:global_step/sec: 32.555
# INFO:tensorflow:loss = 25003.674, step = 22300 (3.072 sec)
# INFO:tensorflow:global_step/sec: 32.4168
# INFO:tensorflow:loss = 18322.246, step = 22400 (3.085 sec)
# INFO:tensorflow:global_step/sec: 32.2118
# INFO:tensorflow:loss = 1930860.9, step = 22500 (3.104 sec)
# INFO:tensorflow:global_step/sec: 32.6411
# INFO:tensorflow:loss = 17741.861, step = 22600 (3.064 sec)
# INFO:tensorflow:global_step/sec: 32.6393
# INFO:tensorflow:loss = 1919168.5, step = 22700 (3.064 sec)
# INFO:tensorflow:global_step/sec: 32.8047
# INFO:tensorflow:loss = 18206.34, step = 22800 (3.049 sec)
# INFO:tensorflow:global_step/sec: 32.5816
# INFO:tensorflow:loss = 19405.906, step = 22900 (3.069 sec)
# INFO:tensorflow:global_step/sec: 32.8881
# INFO:tensorflow:loss = 16013.36, step = 23000 (3.041 sec)
# INFO:tensorflow:global_step/sec: 32.5104
# INFO:tensorflow:loss = 21083.883, step = 23100 (3.076 sec)
# INFO:tensorflow:global_step/sec: 32.4221
# INFO:tensorflow:loss = 19323.166, step = 23200 (3.084 sec)
# INFO:tensorflow:global_step/sec: 32.1917
# INFO:tensorflow:loss = 21098.436, step = 23300 (3.107 sec)
# INFO:tensorflow:global_step/sec: 32.1777
# INFO:tensorflow:loss = 32728.092, step = 23400 (3.108 sec)
# INFO:tensorflow:global_step/sec: 32.2565
# INFO:tensorflow:loss = 18631.996, step = 23500 (3.101 sec)
# INFO:tensorflow:global_step/sec: 32.3524
# INFO:tensorflow:loss = 26065.557, step = 23600 (3.090 sec)
# INFO:tensorflow:global_step/sec: 32.8157
# INFO:tensorflow:loss = 2047152.0, step = 23700 (3.047 sec)
# INFO:tensorflow:global_step/sec: 32.7565
# INFO:tensorflow:loss = 2048661.1, step = 23800 (3.053 sec)
# INFO:tensorflow:global_step/sec: 32.5029
# INFO:tensorflow:loss = 3948251.0, step = 23900 (3.077 sec)
# INFO:tensorflow:global_step/sec: 32.643
# INFO:tensorflow:loss = 23897.193, step = 24000 (3.063 sec)
# INFO:tensorflow:global_step/sec: 32.5592
# INFO:tensorflow:loss = 4067992.5, step = 24100 (3.071 sec)
# INFO:tensorflow:global_step/sec: 32.7304
# INFO:tensorflow:loss = 16558.75, step = 24200 (3.055 sec)
# INFO:tensorflow:global_step/sec: 32.6353
# INFO:tensorflow:loss = 13237.544, step = 24300 (4.045 sec)
# INFO:tensorflow:global_step/sec: 24.5501
# INFO:tensorflow:loss = 38412.047, step = 24400 (3.093 sec)
# INFO:tensorflow:global_step/sec: 32.6438
# INFO:tensorflow:loss = 27599.184, step = 24500 (3.063 sec)
# INFO:tensorflow:global_step/sec: 32.4186
# INFO:tensorflow:loss = 1971216.5, step = 24600 (3.085 sec)
# INFO:tensorflow:global_step/sec: 32.3375
# INFO:tensorflow:loss = 2065740.9, step = 24700 (3.092 sec)
# INFO:tensorflow:global_step/sec: 32.2504
# INFO:tensorflow:loss = 20845.166, step = 24800 (3.101 sec)
# INFO:tensorflow:global_step/sec: 32.8169
# INFO:tensorflow:loss = 20366.443, step = 24900 (3.047 sec)
# INFO:tensorflow:global_step/sec: 32.6133
# INFO:tensorflow:loss = 20967.299, step = 25000 (3.066 sec)
# INFO:tensorflow:global_step/sec: 32.2991
# INFO:tensorflow:loss = 2033806.6, step = 25100 (3.096 sec)
# INFO:tensorflow:global_step/sec: 32.3282
# INFO:tensorflow:loss = 20948.357, step = 25200 (3.093 sec)
# INFO:tensorflow:global_step/sec: 32.5331
# INFO:tensorflow:loss = 2058532.2, step = 25300 (3.074 sec)
# INFO:tensorflow:global_step/sec: 32.9979
# INFO:tensorflow:loss = 26430.025, step = 25400 (3.030 sec)
# INFO:tensorflow:global_step/sec: 32.4357
# INFO:tensorflow:loss = 18399.457, step = 25500 (3.083 sec)
# INFO:tensorflow:global_step/sec: 32.5176
# INFO:tensorflow:loss = 14646.832, step = 25600 (3.075 sec)
# INFO:tensorflow:Saving checkpoints for 25608 into gs://edml/ai-platform/models/edml_trainer_20200425_221104/model.ckpt.
# WARNING:tensorflow:From /opt/conda/lib/python3.7/site-packages/tensorflow_core/python/training/saver.py:963: remove_checkpoint (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to delete files with this prefix.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-04-25T22:27:03Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from gs://edml/ai-platform/models/edml_trainer_20200425_221104/model.ckpt-25608
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/3]
# INFO:tensorflow:Evaluation [2/3]
# INFO:tensorflow:Evaluation [3/3]
# INFO:tensorflow:Finished evaluation at 2020-04-25-22:27:20
# INFO:tensorflow:Saving dict for global step 25608: average_loss = 4223.0386, global_step = 25608, label/mean = 17.94455, loss = 138380530.0, prediction/mean = 5.7666755, rmse = 64.98491
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 25608: gs://edml/ai-platform/models/edml_trainer_20200425_221104/model.ckpt-25608
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['predict']
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Signatures EXCLUDED from export because they cannot be be served via TensorFlow Serving APIs:
# INFO:tensorflow:'serving_default' : Regression input must be a single string Tensor; got {'dayofweek': <tf.Tensor 'dayofweek:0' shape=(?,) dtype=int64>, 'hourofday': <tf.Tensor 'hourofday:0' shape=(?,) dtype=int64>, 'weekofyear': <tf.Tensor 'weekofyear:0' shape=(?,) dtype=int64>, 'pickup_zone_name': <tf.Tensor 'pickup_zone_name:0' shape=(?,) dtype=string>, 'dropoff_zone_name': <tf.Tensor 'dropoff_zone_name:0' shape=(?,) dtype=string>, 'passenger_count': <tf.Tensor 'passenger_count:0' shape=(?,) dtype=int64>, 'distance': <tf.Tensor 'distance:0' shape=(?,) dtype=float64>, 'uuid': <tf.Tensor 'uuid:0' shape=(?,) dtype=string>}
# INFO:tensorflow:'regression' : Regression input must be a single string Tensor; got {'dayofweek': <tf.Tensor 'dayofweek:0' shape=(?,) dtype=int64>, 'hourofday': <tf.Tensor 'hourofday:0' shape=(?,) dtype=int64>, 'weekofyear': <tf.Tensor 'weekofyear:0' shape=(?,) dtype=int64>, 'pickup_zone_name': <tf.Tensor 'pickup_zone_name:0' shape=(?,) dtype=string>, 'dropoff_zone_name': <tf.Tensor 'dropoff_zone_name:0' shape=(?,) dtype=string>, 'passenger_count': <tf.Tensor 'passenger_count:0' shape=(?,) dtype=int64>, 'distance': <tf.Tensor 'distance:0' shape=(?,) dtype=float64>, 'uuid': <tf.Tensor 'uuid:0' shape=(?,) dtype=string>}
# WARNING:tensorflow:Export includes no default signature!
# INFO:tensorflow:Restoring parameters from gs://edml/ai-platform/models/edml_trainer_20200425_221104/model.ckpt-25608
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: gs://edml/ai-platform/models/edml_trainer_20200425_221104/export/exporter/temp-b'1587853642'/saved_model.pb
# INFO:tensorflow:global_step/sec: 1.48302
# INFO:tensorflow:loss = 2080638.2, step = 25700 (67.430 sec)
# INFO:tensorflow:global_step/sec: 32.0161
# INFO:tensorflow:loss = 19966.965, step = 25800 (3.123 sec)
# INFO:tensorflow:global_step/sec: 32.3112
# INFO:tensorflow:loss = 14352.642, step = 25900 (3.095 sec)
# INFO:tensorflow:global_step/sec: 32.4723
# INFO:tensorflow:loss = 25033.227, step = 26000 (3.080 sec)
# INFO:tensorflow:global_step/sec: 32.4599
# INFO:tensorflow:loss = 32906.703, step = 26100 (4.185 sec)
# INFO:tensorflow:global_step/sec: 23.9315
# INFO:tensorflow:loss = 14896.242, step = 26200 (3.074 sec)
# INFO:tensorflow:global_step/sec: 32.8069
# INFO:tensorflow:loss = 25497.74, step = 26300 (3.048 sec)
# INFO:tensorflow:global_step/sec: 32.4761
# INFO:tensorflow:loss = 19793.373, step = 26400 (3.081 sec)
# INFO:tensorflow:global_step/sec: 32.2891
# INFO:tensorflow:loss = 1944882.2, step = 26500 (3.096 sec)
# INFO:tensorflow:global_step/sec: 32.1878
# INFO:tensorflow:loss = 18655.203, step = 26600 (3.106 sec)
# INFO:tensorflow:global_step/sec: 32.5691
# INFO:tensorflow:loss = 2001393.1, step = 26700 (3.071 sec)
# INFO:tensorflow:global_step/sec: 32.3074
# INFO:tensorflow:loss = 2058171.2, step = 26800 (3.097 sec)
# INFO:tensorflow:global_step/sec: 32.4558
# INFO:tensorflow:loss = 22004.27, step = 26900 (3.079 sec)
# INFO:tensorflow:global_step/sec: 32.6834
# INFO:tensorflow:loss = 2065031.6, step = 27000 (3.062 sec)
# INFO:tensorflow:global_step/sec: 32.2691
# INFO:tensorflow:loss = 4033585.0, step = 27100 (3.097 sec)
# INFO:tensorflow:global_step/sec: 32.354
# INFO:tensorflow:loss = 18449.666, step = 27200 (3.091 sec)
# INFO:tensorflow:global_step/sec: 32.2397
# INFO:tensorflow:loss = 31754.012, step = 27300 (3.102 sec)
# INFO:tensorflow:global_step/sec: 32.5137
# INFO:tensorflow:loss = 15319.527, step = 27400 (3.076 sec)
# INFO:tensorflow:global_step/sec: 32.4454
# INFO:tensorflow:loss = 24506.428, step = 27500 (3.082 sec)
# INFO:tensorflow:global_step/sec: 32.5881
# INFO:tensorflow:loss = 2070876.6, step = 27600 (3.069 sec)
# INFO:tensorflow:global_step/sec: 32.7019
# INFO:tensorflow:loss = 21817.281, step = 27700 (3.058 sec)
# INFO:tensorflow:global_step/sec: 32.7282
# INFO:tensorflow:loss = 20453.104, step = 27800 (3.056 sec)
# INFO:tensorflow:global_step/sec: 32.6824
# INFO:tensorflow:loss = 26307.078, step = 27900 (3.060 sec)
# INFO:tensorflow:global_step/sec: 32.2678
# INFO:tensorflow:loss = 22902.973, step = 28000 (3.099 sec)
# INFO:tensorflow:global_step/sec: 32.4459
# INFO:tensorflow:loss = 25125.736, step = 28100 (3.082 sec)
# INFO:tensorflow:global_step/sec: 32.5758
# INFO:tensorflow:loss = 18159.4, step = 28200 (3.070 sec)
# INFO:tensorflow:global_step/sec: 32.7364
# INFO:tensorflow:loss = 29535.543, step = 28300 (3.055 sec)
# INFO:tensorflow:global_step/sec: 32.6615
# INFO:tensorflow:loss = 1937522.8, step = 28400 (3.064 sec)
# INFO:tensorflow:global_step/sec: 32.3001
# INFO:tensorflow:loss = 26021.564, step = 28500 (3.094 sec)
# INFO:tensorflow:global_step/sec: 32.4607
# INFO:tensorflow:loss = 32013.91, step = 28600 (3.080 sec)
# INFO:tensorflow:global_step/sec: 32.8442
# INFO:tensorflow:loss = 19443.744, step = 28700 (3.045 sec)
# INFO:tensorflow:global_step/sec: 32.1859
# INFO:tensorflow:loss = 22927.742, step = 28800 (3.107 sec)
# INFO:tensorflow:global_step/sec: 32.46
# INFO:tensorflow:loss = 17403.477, step = 28900 (3.081 sec)
# INFO:tensorflow:global_step/sec: 32.4697
# INFO:tensorflow:loss = 14851.279, step = 29000 (3.080 sec)
# INFO:tensorflow:global_step/sec: 32.9146
# INFO:tensorflow:loss = 20610.879, step = 29100 (3.038 sec)
# INFO:tensorflow:global_step/sec: 32.3661
# INFO:tensorflow:loss = 17956.959, step = 29200 (3.090 sec)
# INFO:tensorflow:global_step/sec: 32.4059
# INFO:tensorflow:loss = 17501.418, step = 29300 (3.086 sec)
# INFO:tensorflow:global_step/sec: 32.6177
# INFO:tensorflow:loss = 17138.82, step = 29400 (3.066 sec)
# INFO:tensorflow:global_step/sec: 32.8373
# INFO:tensorflow:loss = 25237.855, step = 29500 (3.045 sec)
# INFO:tensorflow:global_step/sec: 29.5969
# INFO:tensorflow:loss = 18929.764, step = 29600 (3.379 sec)
# INFO:tensorflow:global_step/sec: 27.4664
# INFO:tensorflow:loss = 28814.79, step = 29700 (3.641 sec)
# INFO:tensorflow:global_step/sec: 27.6351
# INFO:tensorflow:loss = 16300.506, step = 29800 (3.619 sec)
# INFO:tensorflow:global_step/sec: 31.0161
# INFO:tensorflow:loss = 20864.127, step = 29900 (3.223 sec)
# INFO:tensorflow:global_step/sec: 32.4713
# INFO:tensorflow:loss = 21400.596, step = 30000 (4.081 sec)
# INFO:tensorflow:global_step/sec: 24.3238
# INFO:tensorflow:loss = 15667.282, step = 30100 (3.110 sec)
# INFO:tensorflow:global_step/sec: 32.7505
# INFO:tensorflow:loss = 17799.785, step = 30200 (3.054 sec)
# INFO:tensorflow:global_step/sec: 32.2757
# INFO:tensorflow:loss = 20574.176, step = 30300 (3.098 sec)
# INFO:tensorflow:global_step/sec: 32.5846
# INFO:tensorflow:loss = 1631256.5, step = 30400 (3.069 sec)
# INFO:tensorflow:global_step/sec: 32.6187
# INFO:tensorflow:loss = 21801.422, step = 30500 (3.065 sec)
# INFO:tensorflow:global_step/sec: 32.5293
# INFO:tensorflow:loss = 2056862.2, step = 30600 (3.074 sec)
# INFO:tensorflow:global_step/sec: 32.4115
# INFO:tensorflow:loss = 20217.178, step = 30700 (3.085 sec)
# INFO:tensorflow:global_step/sec: 32.4479
# INFO:tensorflow:loss = 2068583.1, step = 30800 (3.082 sec)
# INFO:tensorflow:global_step/sec: 32.2469
# INFO:tensorflow:loss = 2047583.1, step = 30900 (3.101 sec)
# INFO:tensorflow:global_step/sec: 32.5147
# INFO:tensorflow:loss = 15878.166, step = 31000 (3.076 sec)
# INFO:tensorflow:global_step/sec: 32.2387
# INFO:tensorflow:loss = 22650.287, step = 31100 (3.101 sec)
# INFO:tensorflow:global_step/sec: 32.6088
# INFO:tensorflow:loss = 20429.527, step = 31200 (3.067 sec)
# INFO:tensorflow:global_step/sec: 32.6623
# INFO:tensorflow:loss = 13486.455, step = 31300 (3.062 sec)
# INFO:tensorflow:global_step/sec: 32.1673
# INFO:tensorflow:loss = 10968.143, step = 31400 (3.109 sec)
# INFO:tensorflow:global_step/sec: 32.4149
# INFO:tensorflow:loss = 19751.309, step = 31500 (3.085 sec)
# INFO:tensorflow:global_step/sec: 32.8726
# INFO:tensorflow:loss = 15426.969, step = 31600 (3.042 sec)
# INFO:tensorflow:global_step/sec: 32.6245
# INFO:tensorflow:loss = 14311.694, step = 31700 (3.065 sec)
# INFO:tensorflow:global_step/sec: 32.0551
# INFO:tensorflow:loss = 1304743.8, step = 31800 (3.120 sec)
# INFO:tensorflow:global_step/sec: 32.8238
# INFO:tensorflow:loss = 18673.305, step = 31900 (3.047 sec)
# INFO:tensorflow:global_step/sec: 32.5673
# INFO:tensorflow:loss = 14551.28, step = 32000 (3.071 sec)
# INFO:tensorflow:global_step/sec: 32.5369
# INFO:tensorflow:loss = 15939.775, step = 32100 (3.073 sec)
# INFO:tensorflow:global_step/sec: 32.4189
# INFO:tensorflow:loss = 26442.186, step = 32200 (3.085 sec)
# INFO:tensorflow:global_step/sec: 32.2913
# INFO:tensorflow:loss = 12435.0205, step = 32300 (3.097 sec)
# INFO:tensorflow:global_step/sec: 32.367
# INFO:tensorflow:loss = 13492.725, step = 32400 (3.090 sec)
# INFO:tensorflow:global_step/sec: 32.7317
# INFO:tensorflow:loss = 2057100.0, step = 32500 (3.055 sec)
# INFO:tensorflow:global_step/sec: 31.9974
# INFO:tensorflow:loss = 1921167.4, step = 32600 (3.125 sec)
# INFO:tensorflow:global_step/sec: 32.5228
# INFO:tensorflow:loss = 14767.432, step = 32700 (3.075 sec)
# INFO:tensorflow:global_step/sec: 32.049
# INFO:tensorflow:loss = 15132.254, step = 32800 (3.120 sec)
# INFO:tensorflow:global_step/sec: 32.7115
# INFO:tensorflow:loss = 32650.324, step = 32900 (3.057 sec)
# INFO:tensorflow:global_step/sec: 32.123
# INFO:tensorflow:loss = 15870.663, step = 33000 (3.113 sec)
# INFO:tensorflow:global_step/sec: 32.7944
# INFO:tensorflow:loss = 20118.385, step = 33100 (3.049 sec)
# INFO:tensorflow:Saving checkpoints for 33142 into gs://edml/ai-platform/models/edml_trainer_20200425_221104/model.ckpt.
# INFO:tensorflow:Skip the current checkpoint eval due to throttle secs (300 secs).
# INFO:tensorflow:global_step/sec: 4.89524
# INFO:tensorflow:loss = 14130.823, step = 33200 (20.428 sec)
# INFO:tensorflow:global_step/sec: 32.44
# INFO:tensorflow:loss = 1940841.8, step = 33300 (4.068 sec)
# INFO:tensorflow:global_step/sec: 22.8123
# INFO:tensorflow:loss = 16763.906, step = 33400 (3.398 sec)
# INFO:tensorflow:global_step/sec: 27.639
# INFO:tensorflow:loss = 12450.676, step = 33500 (3.618 sec)
# INFO:tensorflow:global_step/sec: 32.7254
# INFO:tensorflow:loss = 22678.951, step = 33600 (3.056 sec)
# INFO:tensorflow:global_step/sec: 32.7464
# INFO:tensorflow:loss = 22053.84, step = 33700 (3.054 sec)
# INFO:tensorflow:global_step/sec: 32.8964
# INFO:tensorflow:loss = 29850.047, step = 33800 (3.040 sec)
# INFO:tensorflow:global_step/sec: 32.5573
# INFO:tensorflow:loss = 21811.352, step = 33900 (3.072 sec)
# INFO:tensorflow:global_step/sec: 32.3676
# INFO:tensorflow:loss = 21973.768, step = 34000 (3.089 sec)
# INFO:tensorflow:global_step/sec: 32.3198
# INFO:tensorflow:loss = 23060.87, step = 34100 (3.094 sec)
# INFO:tensorflow:global_step/sec: 32.5366
# INFO:tensorflow:loss = 19918.875, step = 34200 (3.074 sec)
# INFO:tensorflow:global_step/sec: 32.6291
# INFO:tensorflow:loss = 18799.746, step = 34300 (3.065 sec)
# INFO:tensorflow:global_step/sec: 32.4695
# INFO:tensorflow:loss = 32992.336, step = 34400 (3.080 sec)
# INFO:tensorflow:global_step/sec: 32.4359
# INFO:tensorflow:loss = 18097.611, step = 34500 (3.083 sec)
# INFO:tensorflow:global_step/sec: 32.033
# INFO:tensorflow:loss = 22157.52, step = 34600 (3.122 sec)
# INFO:tensorflow:global_step/sec: 32.4842
# INFO:tensorflow:loss = 529802.8, step = 34700 (3.078 sec)
# INFO:tensorflow:global_step/sec: 32.4763
# INFO:tensorflow:loss = 1994338.2, step = 34800 (3.079 sec)
# INFO:tensorflow:global_step/sec: 32.1302
# INFO:tensorflow:loss = 27009.723, step = 34900 (3.113 sec)
# INFO:tensorflow:global_step/sec: 32.3195
# INFO:tensorflow:loss = 23044.18, step = 35000 (3.094 sec)
# INFO:tensorflow:global_step/sec: 32.2955
# INFO:tensorflow:loss = 18131.201, step = 35100 (3.097 sec)
# INFO:tensorflow:global_step/sec: 32.2394
# INFO:tensorflow:loss = 20844.998, step = 35200 (3.102 sec)
# INFO:tensorflow:global_step/sec: 32.7589
# INFO:tensorflow:loss = 1929517.2, step = 35300 (3.052 sec)
# INFO:tensorflow:global_step/sec: 32.4302
# INFO:tensorflow:loss = 17262.21, step = 35400 (3.084 sec)
# INFO:tensorflow:global_step/sec: 32.4124
# INFO:tensorflow:loss = 18343.031, step = 35500 (3.085 sec)
# INFO:tensorflow:global_step/sec: 32.4745
# INFO:tensorflow:loss = 18896.637, step = 35600 (3.079 sec)
# INFO:tensorflow:global_step/sec: 32.659
# INFO:tensorflow:loss = 4086633.0, step = 35700 (3.063 sec)
# INFO:tensorflow:global_step/sec: 32.3727
# INFO:tensorflow:loss = 25358.195, step = 35800 (3.088 sec)
# INFO:tensorflow:global_step/sec: 32.4577
# INFO:tensorflow:loss = 20772.652, step = 35900 (3.081 sec)
# INFO:tensorflow:global_step/sec: 32.2476
# INFO:tensorflow:loss = 2047829.8, step = 36000 (3.101 sec)
# INFO:tensorflow:global_step/sec: 33.0539
# INFO:tensorflow:loss = 19378.66, step = 36100 (3.026 sec)
# INFO:tensorflow:global_step/sec: 32.3251
# INFO:tensorflow:loss = 2023624.5, step = 36200 (3.093 sec)
# INFO:tensorflow:global_step/sec: 32.5092
# INFO:tensorflow:loss = 12283.063, step = 36300 (3.076 sec)
# ...
# INFO:tensorflow:loss = 9691.393, step = 90900 (3.106 sec)
# INFO:tensorflow:global_step/sec: 32.1298
# INFO:tensorflow:loss = 16933.312, step = 91000 (3.112 sec)
# INFO:tensorflow:global_step/sec: 31.6837
# INFO:tensorflow:loss = 13774.169, step = 91100 (3.156 sec)
# INFO:tensorflow:global_step/sec: 32.1685
# INFO:tensorflow:loss = 14278.824, step = 91200 (3.109 sec)
# INFO:tensorflow:global_step/sec: 32.1867
# INFO:tensorflow:loss = 15032.502, step = 91300 (3.106 sec)
# INFO:tensorflow:global_step/sec: 32.1395
# INFO:tensorflow:loss = 11664.768, step = 91400 (3.111 sec)
# INFO:tensorflow:global_step/sec: 31.6037
# INFO:tensorflow:loss = 3946293.5, step = 91500 (3.164 sec)
# INFO:tensorflow:global_step/sec: 32.0519
# INFO:tensorflow:loss = 16899.816, step = 91600 (3.120 sec)
# INFO:tensorflow:global_step/sec: 31.8664
# INFO:tensorflow:loss = 26153.055, step = 91700 (3.138 sec)
# INFO:tensorflow:global_step/sec: 32.2312
# INFO:tensorflow:loss = 10352.598, step = 91800 (4.363 sec)
# INFO:tensorflow:global_step/sec: 22.9434
# INFO:tensorflow:loss = 17426.137, step = 91900 (3.098 sec)
# INFO:tensorflow:global_step/sec: 31.972
# INFO:tensorflow:loss = 15999.133, step = 92000 (3.128 sec)
# INFO:tensorflow:global_step/sec: 31.3772
# INFO:tensorflow:loss = 22716.254, step = 92100 (3.187 sec)
# INFO:tensorflow:global_step/sec: 31.5639
# INFO:tensorflow:loss = 2035501.0, step = 92200 (3.168 sec)
# INFO:tensorflow:global_step/sec: 32.2077
# INFO:tensorflow:loss = 2022896.4, step = 92300 (3.105 sec)
# INFO:tensorflow:global_step/sec: 32.0313
# INFO:tensorflow:loss = 7484.2734, step = 92400 (3.122 sec)
# INFO:tensorflow:global_step/sec: 32.1377
# INFO:tensorflow:loss = 10580.718, step = 92500 (3.112 sec)
# INFO:tensorflow:global_step/sec: 31.7941
# INFO:tensorflow:loss = 15204.647, step = 92600 (3.145 sec)
# INFO:tensorflow:global_step/sec: 31.9573
# INFO:tensorflow:loss = 10139.553, step = 92700 (3.129 sec)
# INFO:tensorflow:global_step/sec: 32.3536
# INFO:tensorflow:loss = 9918.829, step = 92800 (3.091 sec)
# INFO:tensorflow:global_step/sec: 32.1829
# INFO:tensorflow:loss = 6718.791, step = 92900 (3.107 sec)
# INFO:tensorflow:global_step/sec: 32.0776
# INFO:tensorflow:loss = 11497.657, step = 93000 (3.118 sec)
# INFO:tensorflow:global_step/sec: 32.2668
# INFO:tensorflow:loss = 11546.895, step = 93100 (3.099 sec)
# INFO:tensorflow:global_step/sec: 32.2566
# INFO:tensorflow:loss = 382221.97, step = 93200 (3.100 sec)
# INFO:tensorflow:global_step/sec: 32.3386
# INFO:tensorflow:loss = 16310.026, step = 93300 (3.092 sec)
# INFO:tensorflow:global_step/sec: 32.1233
# INFO:tensorflow:loss = 11214.692, step = 93400 (3.113 sec)
# INFO:tensorflow:global_step/sec: 31.5952
# INFO:tensorflow:loss = 14959.091, step = 93500 (3.165 sec)
# INFO:tensorflow:global_step/sec: 31.8827
# INFO:tensorflow:loss = 14220.084, step = 93600 (3.137 sec)
# INFO:tensorflow:global_step/sec: 32.0346
# INFO:tensorflow:loss = 7802.453, step = 93700 (3.122 sec)
# INFO:tensorflow:global_step/sec: 32.0646
# INFO:tensorflow:loss = 11379.274, step = 93800 (3.119 sec)
# INFO:tensorflow:global_step/sec: 32.2363
# INFO:tensorflow:loss = 1989029.1, step = 93900 (3.102 sec)
# INFO:tensorflow:global_step/sec: 32.0226
# INFO:tensorflow:loss = 13318.409, step = 94000 (3.123 sec)
# INFO:tensorflow:global_step/sec: 31.7265
# INFO:tensorflow:loss = 11474.804, step = 94100 (3.152 sec)
# INFO:tensorflow:global_step/sec: 32.1804
# INFO:tensorflow:loss = 9195.027, step = 94200 (3.107 sec)
# INFO:tensorflow:global_step/sec: 32.272
# INFO:tensorflow:loss = 2040266.0, step = 94300 (3.099 sec)
# INFO:tensorflow:global_step/sec: 31.9083
# INFO:tensorflow:loss = 14217.949, step = 94400 (3.134 sec)
# INFO:tensorflow:global_step/sec: 30.7927
# INFO:tensorflow:loss = 17050.48, step = 94500 (3.248 sec)
# INFO:tensorflow:global_step/sec: 27.2248
# INFO:tensorflow:loss = 19512.979, step = 94600 (3.673 sec)
# INFO:tensorflow:global_step/sec: 27.2521
# INFO:tensorflow:loss = 15520.189, step = 94700 (3.669 sec)
# INFO:tensorflow:global_step/sec: 28.9913
# INFO:tensorflow:loss = 14702.514, step = 94800 (3.449 sec)
# INFO:tensorflow:global_step/sec: 32.0588
# INFO:tensorflow:loss = 10441.967, step = 94900 (3.119 sec)
# INFO:tensorflow:global_step/sec: 31.7869
# INFO:tensorflow:loss = 12030.3955, step = 95000 (3.146 sec)
# INFO:tensorflow:global_step/sec: 32.1084
# INFO:tensorflow:loss = 12282.416, step = 95100 (3.114 sec)
# INFO:tensorflow:global_step/sec: 31.7578
# INFO:tensorflow:loss = 1953165.1, step = 95200 (3.149 sec)
# INFO:tensorflow:global_step/sec: 31.8688
# INFO:tensorflow:loss = 15487.491, step = 95300 (3.138 sec)
# INFO:tensorflow:Saving checkpoints for 95307 into gs://edml/ai-platform/models/edml_trainer_20200425_221104/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-04-25T23:12:04Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from gs://edml/ai-platform/models/edml_trainer_20200425_221104/model.ckpt-95307
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/3]
# INFO:tensorflow:Evaluation [2/3]
# INFO:tensorflow:Evaluation [3/3]
# INFO:tensorflow:Finished evaluation at 2020-04-25-23:12:21
# INFO:tensorflow:Saving dict for global step 95307: average_loss = 4419.723, global_step = 95307, label/mean = 18.17868, loss = 144825490.0, prediction/mean = 10.230006, rmse = 66.480995
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 95307: gs://edml/ai-platform/models/edml_trainer_20200425_221104/model.ckpt-95307
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['predict']
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Signatures EXCLUDED from export because they cannot be be served via TensorFlow Serving APIs:
# INFO:tensorflow:'serving_default' : Regression input must be a single string Tensor; got {'dayofweek': <tf.Tensor 'dayofweek:0' shape=(?,) dtype=int64>, 'hourofday': <tf.Tensor 'hourofday:0' shape=(?,) dtype=int64>, 'weekofyear': <tf.Tensor 'weekofyear:0' shape=(?,) dtype=int64>, 'pickup_zone_name': <tf.Tensor 'pickup_zone_name:0' shape=(?,) dtype=string>, 'dropoff_zone_name': <tf.Tensor 'dropoff_zone_name:0' shape=(?,) dtype=string>, 'passenger_count': <tf.Tensor 'passenger_count:0' shape=(?,) dtype=int64>, 'distance': <tf.Tensor 'distance:0' shape=(?,) dtype=float64>, 'uuid': <tf.Tensor 'uuid:0' shape=(?,) dtype=string>}
# INFO:tensorflow:'regression' : Regression input must be a single string Tensor; got {'dayofweek': <tf.Tensor 'dayofweek:0' shape=(?,) dtype=int64>, 'hourofday': <tf.Tensor 'hourofday:0' shape=(?,) dtype=int64>, 'weekofyear': <tf.Tensor 'weekofyear:0' shape=(?,) dtype=int64>, 'pickup_zone_name': <tf.Tensor 'pickup_zone_name:0' shape=(?,) dtype=string>, 'dropoff_zone_name': <tf.Tensor 'dropoff_zone_name:0' shape=(?,) dtype=string>, 'passenger_count': <tf.Tensor 'passenger_count:0' shape=(?,) dtype=int64>, 'distance': <tf.Tensor 'distance:0' shape=(?,) dtype=float64>, 'uuid': <tf.Tensor 'uuid:0' shape=(?,) dtype=string>}
# WARNING:tensorflow:Export includes no default signature!
# INFO:tensorflow:Restoring parameters from gs://edml/ai-platform/models/edml_trainer_20200425_221104/model.ckpt-95307
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: gs://edml/ai-platform/models/edml_trainer_20200425_221104/export/exporter/temp-b'1587856343'/saved_model.pb
# INFO:tensorflow:global_step/sec: 1.41737
# INFO:tensorflow:loss = 14444.523, step = 95400 (70.553 sec)
# INFO:tensorflow:global_step/sec: 26.6474
# INFO:tensorflow:loss = 11799.992, step = 95500 (3.753 sec)
# INFO:tensorflow:global_step/sec: 29.7727
# INFO:tensorflow:loss = 13540.496, step = 95600 (3.358 sec)
# INFO:tensorflow:global_step/sec: 31.4424
# INFO:tensorflow:loss = 16193.961, step = 95700 (3.180 sec)
# INFO:tensorflow:global_step/sec: 31.7889
# INFO:tensorflow:loss = 14639.842, step = 95800 (3.146 sec)
# INFO:tensorflow:global_step/sec: 32.0664
# INFO:tensorflow:loss = 2014357.4, step = 95900 (3.118 sec)
# INFO:tensorflow:global_step/sec: 31.9695
# INFO:tensorflow:loss = 10499.012, step = 96000 (3.128 sec)
# INFO:tensorflow:global_step/sec: 31.932
# INFO:tensorflow:loss = 18388.895, step = 96100 (3.132 sec)
# INFO:tensorflow:global_step/sec: 31.7158
# INFO:tensorflow:loss = 21317.96, step = 96200 (3.153 sec)
# INFO:tensorflow:global_step/sec: 32.196
# INFO:tensorflow:loss = 2033790.8, step = 96300 (3.106 sec)
# INFO:tensorflow:global_step/sec: 31.9406
# INFO:tensorflow:loss = 32550.035, step = 96400 (3.131 sec)
# INFO:tensorflow:global_step/sec: 31.7368
# INFO:tensorflow:loss = 14070.473, step = 96500 (3.151 sec)
# INFO:tensorflow:global_step/sec: 32.1839
# INFO:tensorflow:loss = 22367.664, step = 96600 (3.107 sec)
# INFO:tensorflow:global_step/sec: 32.3292
# INFO:tensorflow:loss = 9954.213, step = 96700 (3.094 sec)
# INFO:tensorflow:global_step/sec: 32.015
# INFO:tensorflow:loss = 18832.89, step = 96800 (3.123 sec)
# INFO:tensorflow:global_step/sec: 32.1973
# INFO:tensorflow:loss = 16870.523, step = 96900 (3.106 sec)
# INFO:tensorflow:global_step/sec: 32.1619
# INFO:tensorflow:loss = 16239.143, step = 97000 (3.109 sec)
# INFO:tensorflow:global_step/sec: 32.0884
# INFO:tensorflow:loss = 1938595.4, step = 97100 (3.116 sec)
# INFO:tensorflow:global_step/sec: 31.7426
# INFO:tensorflow:loss = 11442.951, step = 97200 (3.150 sec)
# INFO:tensorflow:global_step/sec: 32.0017
# INFO:tensorflow:loss = 19844.41, step = 97300 (3.125 sec)
# INFO:tensorflow:global_step/sec: 32.0985
# INFO:tensorflow:loss = 14559.067, step = 97400 (3.115 sec)
# INFO:tensorflow:global_step/sec: 32.092
# INFO:tensorflow:loss = 18462.793, step = 97500 (3.118 sec)
# INFO:tensorflow:global_step/sec: 32.0655
# INFO:tensorflow:loss = 15296.0, step = 97600 (4.107 sec)
# INFO:tensorflow:global_step/sec: 24.2737
# INFO:tensorflow:loss = 9655.693, step = 97700 (3.129 sec)
# INFO:tensorflow:global_step/sec: 31.661
# INFO:tensorflow:loss = 18063.41, step = 97800 (3.158 sec)
# INFO:tensorflow:global_step/sec: 31.7769
# INFO:tensorflow:loss = 24593.094, step = 97900 (3.147 sec)
# INFO:tensorflow:global_step/sec: 31.8678
# INFO:tensorflow:loss = 1957213.5, step = 98000 (3.138 sec)
# INFO:tensorflow:global_step/sec: 32.2274
# INFO:tensorflow:loss = 10864.863, step = 98100 (3.103 sec)
# INFO:tensorflow:global_step/sec: 32.0749
# INFO:tensorflow:loss = 7852.0137, step = 98200 (3.118 sec)
# INFO:tensorflow:global_step/sec: 32.1709
# INFO:tensorflow:loss = 16153.469, step = 98300 (3.108 sec)
# INFO:tensorflow:global_step/sec: 31.7701
# INFO:tensorflow:loss = 15216.698, step = 98400 (3.148 sec)
# INFO:tensorflow:global_step/sec: 32.1959
# INFO:tensorflow:loss = 8710.295, step = 98500 (3.106 sec)
# INFO:tensorflow:global_step/sec: 31.8547
# INFO:tensorflow:loss = 1913099.5, step = 98600 (3.139 sec)
# INFO:tensorflow:global_step/sec: 31.8441
# INFO:tensorflow:loss = 11452.777, step = 98700 (3.140 sec)
# INFO:tensorflow:global_step/sec: 31.6163
# INFO:tensorflow:loss = 8699.855, step = 98800 (3.163 sec)
# INFO:tensorflow:global_step/sec: 32.148
# INFO:tensorflow:loss = 1907516.1, step = 98900 (3.110 sec)
# INFO:tensorflow:global_step/sec: 31.8327
# INFO:tensorflow:loss = 12935.281, step = 99000 (3.142 sec)
# INFO:tensorflow:global_step/sec: 32.0075
# INFO:tensorflow:loss = 17269.797, step = 99100 (3.124 sec)
# INFO:tensorflow:global_step/sec: 32.0959
# INFO:tensorflow:loss = 20698.602, step = 99200 (3.116 sec)
# INFO:tensorflow:global_step/sec: 32.0759
# INFO:tensorflow:loss = 10684.414, step = 99300 (3.117 sec)
# INFO:tensorflow:global_step/sec: 31.9052
# INFO:tensorflow:loss = 12963.52, step = 99400 (3.135 sec)
# INFO:tensorflow:global_step/sec: 31.7309
# INFO:tensorflow:loss = 10785.703, step = 99500 (3.151 sec)
# INFO:tensorflow:global_step/sec: 31.924
# INFO:tensorflow:loss = 11381.931, step = 99600 (3.132 sec)
# INFO:tensorflow:global_step/sec: 31.8366
# INFO:tensorflow:loss = 15059.367, step = 99700 (3.141 sec)
# INFO:tensorflow:global_step/sec: 31.6475
# INFO:tensorflow:loss = 22835.982, step = 99800 (3.160 sec)
# INFO:tensorflow:global_step/sec: 31.8984
# INFO:tensorflow:loss = 2011704.4, step = 99900 (3.135 sec)
# INFO:tensorflow:Saving checkpoints for 100000 into gs://edml/ai-platform/models/edml_trainer_20200425_221104/model.ckpt.
# INFO:tensorflow:Skip the current checkpoint eval due to throttle secs (300 secs).
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-04-25T23:15:40Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from gs://edml/ai-platform/models/edml_trainer_20200425_221104/model.ckpt-100000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/3]
# INFO:tensorflow:Evaluation [2/3]
# INFO:tensorflow:Evaluation [3/3]
# INFO:tensorflow:Finished evaluation at 2020-04-25-23:15:57
# INFO:tensorflow:Saving dict for global step 100000: average_loss = 4522.2466, global_step = 100000, label/mean = 18.250763, loss = 148184980.0, prediction/mean = 10.435887, rmse = 67.24765
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 100000: gs://edml/ai-platform/models/edml_trainer_20200425_221104/model.ckpt-100000
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['predict']
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Signatures EXCLUDED from export because they cannot be be served via TensorFlow Serving APIs:
# INFO:tensorflow:'serving_default' : Regression input must be a single string Tensor; got {'dayofweek': <tf.Tensor 'dayofweek:0' shape=(?,) dtype=int64>, 'hourofday': <tf.Tensor 'hourofday:0' shape=(?,) dtype=int64>, 'weekofyear': <tf.Tensor 'weekofyear:0' shape=(?,) dtype=int64>, 'pickup_zone_name': <tf.Tensor 'pickup_zone_name:0' shape=(?,) dtype=string>, 'dropoff_zone_name': <tf.Tensor 'dropoff_zone_name:0' shape=(?,) dtype=string>, 'passenger_count': <tf.Tensor 'passenger_count:0' shape=(?,) dtype=int64>, 'distance': <tf.Tensor 'distance:0' shape=(?,) dtype=float64>, 'uuid': <tf.Tensor 'uuid:0' shape=(?,) dtype=string>}
# INFO:tensorflow:'regression' : Regression input must be a single string Tensor; got {'dayofweek': <tf.Tensor 'dayofweek:0' shape=(?,) dtype=int64>, 'hourofday': <tf.Tensor 'hourofday:0' shape=(?,) dtype=int64>, 'weekofyear': <tf.Tensor 'weekofyear:0' shape=(?,) dtype=int64>, 'pickup_zone_name': <tf.Tensor 'pickup_zone_name:0' shape=(?,) dtype=string>, 'dropoff_zone_name': <tf.Tensor 'dropoff_zone_name:0' shape=(?,) dtype=string>, 'passenger_count': <tf.Tensor 'passenger_count:0' shape=(?,) dtype=int64>, 'distance': <tf.Tensor 'distance:0' shape=(?,) dtype=float64>, 'uuid': <tf.Tensor 'uuid:0' shape=(?,) dtype=string>}
# WARNING:tensorflow:Export includes no default signature!
# INFO:tensorflow:Restoring parameters from gs://edml/ai-platform/models/edml_trainer_20200425_221104/model.ckpt-100000
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: gs://edml/ai-platform/models/edml_trainer_20200425_221104/export/exporter/temp-b'1587856559'/saved_model.pb
# INFO:tensorflow:Loss for final step: 22272.35.
# ({'average_loss': 4522.2466,
#   'label/mean': 18.250763,
#   'loss': 148184980.0,
#   'prediction/mean': 10.435887,
#   'rmse': 67.24765,
#   'global_step': 100000},
#  [b'gs://edml/ai-platform/models/edml_trainer_20200425_221104/export/exporter/1587856559'])

# %%
# ({'average_loss': 4725.116,
#   'label/mean': 18.190115,
#   'loss': 154832600.0,
#   'prediction/mean': 0.98749757,
#   'rmse': 68.73948,
#   'global_step': 1000},
#  [b'gs://edml/ai-platform/models/edml_trainer_20200421_103536/export/exporter/1587465469'])
