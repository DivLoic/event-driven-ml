# %%
import pandas as pd
import tensorflow as tf

TRAIN_URL = "http://download.tensorflow.org/data/iris_training.csv"
TEST_URL = "http://download.tensorflow.org/data/iris_test.csv"

CSV_COLUMN_NAMES = ['SepalLength', 'SepalWidth',
                    'PetalLength', 'PetalWidth', 'Species']
SPECIES = ['Setosa', 'Versicolor', 'Virginica']

def maybe_download():
    train_path = tf.keras.utils.get_file(TRAIN_URL.split('/')[-1], TRAIN_URL)
    test_path = tf.keras.utils.get_file(TEST_URL.split('/')[-1], TEST_URL)

    return train_path, test_path

def load_data(y_name='Species'):
    """Returns the iris dataset as (train_x, train_y), (test_x, test_y)."""
    train_path, test_path = maybe_download()

    train = pd.read_csv(train_path, names=CSV_COLUMN_NAMES, header=0)
    train_x, train_y = train, train.pop(y_name)

    test = pd.read_csv(test_path, names=CSV_COLUMN_NAMES, header=0)
    test_x, test_y = test, test.pop(y_name)

    return (train_x, train_y), (test_x, test_y)


def train_input_fn(features, labels, batch_size):
    """An input function for training"""
    # Convert the inputs to a Dataset.
    dataset = tf.data.Dataset.from_tensor_slices((dict(features), labels))

    # Shuffle, repeat, and batch the examples.
    dataset = dataset.shuffle(1000).repeat().batch(batch_size)

    # Return the dataset.
    return dataset


def eval_input_fn(features, labels, batch_size):
    """An input function for evaluation or prediction"""
    features=dict(features)
    if labels is None:
        # No labels, use only features.
        inputs = features
    else:
        inputs = (features, labels)

    # Convert the inputs to a Dataset.
    dataset = tf.data.Dataset.from_tensor_slices(inputs)

    # Batch the examples
    assert batch_size is not None, "batch_size must not be None"
    dataset = dataset.batch(batch_size)

    # Return the dataset.
    return dataset


# The remainder of this file contains a simple example of a csv parser,
#     implemented using the `Dataset` class.

# `tf.parse_csv` sets the types of the outputs to match the examples given in
#     the `record_defaults` argument.
CSV_TYPES = [[0.0], [0.0], [0.0], [0.0], [0]]

def _parse_line(line):
    # Decode the line into its fields
    fields = tf.decode_csv(line, record_defaults=CSV_TYPES)

    # Pack the result into a dictionary
    features = dict(zip(CSV_COLUMN_NAMES, fields))

    # Separate the label from the features
    label = features.pop('Species')

    return features, label


def csv_input_fn(csv_path, batch_size):
    # Create a dataset containing the text lines.
    dataset = tf.data.TextLineDataset(csv_path).skip(1)

    # Parse each line.
    dataset = dataset.map(_parse_line)

    # Shuffle, repeat, and batch the examples.
    dataset = dataset.shuffle(1000).repeat().batch(batch_size)

    # Return the dataset.
    return dataset

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import argparse
import tensorflow as tf

parser = argparse.ArgumentParser()
parser.add_argument('--batch_size', default=100, type=int, help='batch size')
parser.add_argument('--train_steps', default=1000, type=int,
                    help='number of training steps')

def main(argv):

    # Fetch the data
    (train_x, train_y), (test_x, test_y) = load_data()

    # Feature columns describe how to use the input.
    my_feature_columns = []
    for key in train_x.keys():
        my_feature_columns.append(tf.feature_column.numeric_column(key=key))

    # Build 2 hidden layer DNN with 10, 10 units respectively.
    classifier = tf.estimator.DNNClassifier(
        feature_columns=my_feature_columns,
        # Two hidden layers of 10 nodes each.
        hidden_units=[10, 10],
        # The model must choose between 3 classes.
        n_classes=3)

    # Train the Model.
    classifier.train(
        input_fn=lambda:train_input_fn(
            train_x, 
            train_y,
            10 #args.batch_size
        ),
        steps=100 #args.train_steps
    )
    
    feature_spec = {
        'PetalLength': tf.FixedLenFeature(shape=(1,), dtype=tf.float32),
        'PetalWidth': tf.FixedLenFeature(shape=(1,), dtype=tf.float32),
        'SepalLength': tf.FixedLenFeature(shape=(1,), dtype=tf.float32),
        'SepalWidth': tf.FixedLenFeature(shape=(1,), dtype=tf.float32)
    }
    
    def serving_input_receiver_fn():
        serialized_tf_example = tf.placeholder(dtype=tf.string, shape=[None, 4], name='input_example_tensor')
        receiver_tensors = {'features': serialized_tf_example}
        features = tf.parse_example(serialized_tf_example, feature_spec)
        return tf.estimator.export.ServingInputReceiver(features=features, receiver_tensors=receiver_tensors)
    
    classifier.export_saved_model('../edml-streaming/build/setosa/', serving_input_receiver_fn)

    # Evaluate the model.
    eval_result = classifier.evaluate(
        input_fn=lambda:eval_input_fn(test_x, test_y, 10) #args.batch_size
                                     )

    print('\nTest set accuracy: {accuracy:0.3f}\n'.format(**eval_result))

    # Generate predictions from the model
    expected = ['Setosa', 'Versicolor', 'Virginica']
    predict_x = {
        'SepalLength': [5.1, 5.9, 6.9],
        'SepalWidth': [3.3, 3.0, 3.1],
        'PetalLength': [1.7, 4.2, 5.4],
        'PetalWidth': [0.5, 1.5, 2.1],
    }

    predictions = classifier.predict(
        input_fn=lambda:eval_input_fn(predict_x,
                                                labels=None,
                                                batch_size= 10)#args.batch_size
    )

    template = ('\nPrediction is "{}" ({:.1f}%), expected "{}"')

    for pred_dict, expec in zip(predictions, expected):
        class_id = pred_dict['class_ids'][0]
        probability = pred_dict['probabilities'][class_id]

        print(template.format(SPECIES[class_id], 100 * probability, expec))

# %%
tf.logging.set_verbosity(tf.logging.INFO)
tf.app.run(main)
# Out:
# I0814 18:43:01.542145 4541666752 estimator.py:1790] Using default config.
# W0814 18:43:01.543203 4541666752 estimator.py:1811] Using temporary folder as model directory: /var/folders/lf/ysbnmsbd0gg366_zqx3vlvkm0000gn/T/tmp_t5oaree
# I0814 18:43:01.544155 4541666752 estimator.py:209] Using config: {'_model_dir': '/var/folders/lf/ysbnmsbd0gg366_zqx3vlvkm0000gn/T/tmp_t5oaree', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x64aaeb4e0>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# I0814 18:43:01.578130 4541666752 estimator.py:1145] Calling model_fn.
# I0814 18:43:01.875145 4541666752 estimator.py:1147] Done calling model_fn.
# I0814 18:43:01.876057 4541666752 basic_session_run_hooks.py:541] Create CheckpointSaverHook.
# I0814 18:43:02.073323 4541666752 monitored_session.py:240] Graph was finalized.
# I0814 18:43:02.193235 4541666752 session_manager.py:500] Running local_init_op.
# I0814 18:43:02.208641 4541666752 session_manager.py:502] Done running local_init_op.
# I0814 18:43:02.526533 4541666752 basic_session_run_hooks.py:606] Saving checkpoints for 0 into /var/folders/lf/ysbnmsbd0gg366_zqx3vlvkm0000gn/T/tmp_t5oaree/model.ckpt.
# I0814 18:43:03.037715 4541666752 basic_session_run_hooks.py:262] loss = 11.955141, step = 1
# I0814 18:43:03.430342 4541666752 basic_session_run_hooks.py:606] Saving checkpoints for 100 into /var/folders/lf/ysbnmsbd0gg366_zqx3vlvkm0000gn/T/tmp_t5oaree/model.ckpt.
# I0814 18:43:03.517889 4541666752 estimator.py:368] Loss for final step: 0.7932017.
# I0814 18:43:03.534454 4541666752 estimator.py:1145] Calling model_fn.
# I0814 18:43:03.709980 4541666752 estimator.py:1147] Done calling model_fn.
# W0814 18:43:03.710877 4541666752 deprecation.py:323] From /Users/loicmdivad/lmdadm/lib/anaconda/lib/python3.7/site-packages/tensorflow/python/saved_model/signature_def_utils_impl.py:145: build_tensor_info (from tensorflow.python.saved_model.utils_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This function will only be available through the v1 compatibility library as tf.compat.v1.saved_model.utils.build_tensor_info or tf.compat.v1.saved_model.build_tensor_info.
# I0814 18:43:03.712505 4541666752 export_utils.py:170] Signatures INCLUDED in export for Classify: ['serving_default', 'classification']
# I0814 18:43:03.713318 4541666752 export_utils.py:170] Signatures INCLUDED in export for Regress: None
# I0814 18:43:03.713886 4541666752 export_utils.py:170] Signatures INCLUDED in export for Predict: ['predict']
# I0814 18:43:03.714831 4541666752 export_utils.py:170] Signatures INCLUDED in export for Train: None
# I0814 18:43:03.715342 4541666752 export_utils.py:170] Signatures INCLUDED in export for Eval: None
# W0814 18:43:03.772118 4541666752 deprecation.py:323] From /Users/loicmdivad/lmdadm/lib/anaconda/lib/python3.7/site-packages/tensorflow/python/training/saver.py:1276: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# I0814 18:43:03.774277 4541666752 saver.py:1280] Restoring parameters from /var/folders/lf/ysbnmsbd0gg366_zqx3vlvkm0000gn/T/tmp_t5oaree/model.ckpt-100
# I0814 18:43:03.811881 4541666752 builder_impl.py:661] Assets added to graph.
# I0814 18:43:03.812659 4541666752 builder_impl.py:456] No assets to write.
# I0814 18:43:03.899637 4541666752 builder_impl.py:421] SavedModel written to: ../edml-streaming/build/setosa/temp-b'1565800983'/saved_model.pb
# I0814 18:43:03.923059 4541666752 estimator.py:1145] Calling model_fn.
# I0814 18:43:04.184645 4541666752 estimator.py:1147] Done calling model_fn.
# I0814 18:43:04.207656 4541666752 evaluation.py:255] Starting evaluation at 2019-08-14T18:43:04Z
# I0814 18:43:04.324182 4541666752 monitored_session.py:240] Graph was finalized.
# I0814 18:43:04.327564 4541666752 saver.py:1280] Restoring parameters from /var/folders/lf/ysbnmsbd0gg366_zqx3vlvkm0000gn/T/tmp_t5oaree/model.ckpt-100
# I0814 18:43:04.410526 4541666752 session_manager.py:500] Running local_init_op.
# I0814 18:43:04.441827 4541666752 session_manager.py:502] Done running local_init_op.
# I0814 18:43:04.777690 4541666752 evaluation.py:275] Finished evaluation at 2019-08-14-18:43:04
# I0814 18:43:04.778420 4541666752 estimator.py:2039] Saving dict for global step 100: accuracy = 0.93333334, average_loss = 0.2902082, global_step = 100, loss = 2.9020817
# I0814 18:43:04.863952 4541666752 estimator.py:2099] Saving 'checkpoint_path' summary for global step 100: /var/folders/lf/ysbnmsbd0gg366_zqx3vlvkm0000gn/T/tmp_t5oaree/model.ckpt-100
# I0814 18:43:04.884327 4541666752 estimator.py:1145] Calling model_fn.
# Test set accuracy: 0.933
# I0814 18:43:05.068010 4541666752 estimator.py:1147] Done calling model_fn.
# I0814 18:43:05.174974 4541666752 monitored_session.py:240] Graph was finalized.
# I0814 18:43:05.177620 4541666752 saver.py:1280] Restoring parameters from /var/folders/lf/ysbnmsbd0gg366_zqx3vlvkm0000gn/T/tmp_t5oaree/model.ckpt-100
# I0814 18:43:05.247704 4541666752 session_manager.py:500] Running local_init_op.
# I0814 18:43:05.257139 4541666752 session_manager.py:502] Done running local_init_op.
# Prediction is "Setosa" (95.8%), expected "Setosa"
#
# Prediction is "Versicolor" (57.5%), expected "Versicolor"
#
# Prediction is "Virginica" (84.9%), expected "Virginica"
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# /Users/loicmdivad/lmdadm/lib/anaconda/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3333: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
